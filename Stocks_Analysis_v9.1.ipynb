# %% [markdown]
# # Analyzing Stock Market Data to Build a Portfolio

# %% [markdown]
# ## Project Goal

# %% [markdown]
# ### Analyze share price data from various listings to answer the following questions:

# %% [markdown]
# 1. What kind of Growth % do we expect from the various listings? <br>
# 2. How do the Growth % of the different listings correlate to each other? <br>
# 3. What is the estimated listing share price at a future date (prediction)? <br>
# 4. What kind of volatility do the listings have? <br>
# 5. How can we use our analysis to form a balanced investment portfolio? <br>

# %% [markdown]
# ### Overall Methodology:

# %% [markdown]
# 1. Import and organize data for the various listings <br>
# 2. Make observations about the data <br>
# 3. Use these observations to answer the questions <br>

# %% [markdown]
# ## References

# %% [markdown]
# Share price information obtained from: [Yahoo Finance](https://finance.yahoo.com/) <br>
# Yahoo Finance library: [yfinance](https://pypi.org/project/yfinance/) <br>
# Robinhood Stocks library: [robin_stocks](http://www.robin-stocks.com/en/latest/functions.html) <br>

# %% [markdown]
# ## Inputs

# %% [markdown]
# ### Below are the inputs to perform the analysis

# %%
s_list='AM AAPL AMZN FB NVDA NFLX MSFT QCOM PYPL GOOGL TWTR TSLA ZNGA INFY JCI JMIA SSL INTC AMD TSM HRB KO ALTR SQ SPCE INO NIO WKHS SOLO MVIS MRNA JNJ CLX PFE RBLX FCEL CLNE UUUU CARR EH XPEV HON RTX V MA OTIS IDEX GEVO NOK BB SLV PAAS HGSH AG ACB DG DUK SOXX VEGI IEHS MCD IYJ IYR VICE XHS XHB PK IAK SLVP SKYY MSOS ARKG ARKK ARKX ARKQ VXRT SNDL PLTR POTX M WMT KSS NFLX DKS UBER UONE GNUS TOPS DIS ABNB SBUX LYFT GSAT SENS CPRX NBEV PPBT COST SPY NDAQ INDF VWO GOVT BND VT IEF VTI VOO DIA VGK XLK IAU QQQ BETZ COIN GLD GLDG H T NCLH RKT F GM AAL UAL BA BAC JPM AXP GE FUBO SNAP BRK-B QSR XLE XES AMC GRPN GME TTM H MRO OSK TLRY KOSS GPRO VWAGY MMM DMYI AMRS DMLRY BTC-USD ETH-USD DOGE-USD RIOT MARA KO PEP AWK'  # List of "listings" to be analyzed
#s_list='BTC-USD ETH-USD DOGE-USD'
total_investment=7001  # Total investment value in USD
#start='11/27/2020'  # Start date of interest
start='5w'
end='07/01/2020'  # End date of interest
datetime_query=['12/28/2021'] # Datetime query values (for prediction)
pricetype='Close' # Open, Close, Low, High
reverse_data='Y' # Reverse Data
reverse_weights='N' # Go from lowest weight to highest weight instead of normal highest to lowest
save_port='N' # Save portfolio to csv? 'Y' / 'N'
save_mean='N' # Save mean equity values? 'Y' / 'N'

# %% [markdown]
# ## Import Libraries

# %%
# Python Version
import sys
sys.version
# Out:
# '3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53) \n[GCC 9.4.0]'

# %%
#Update python standard libraries install
# !pip install --upgrade pip

# library to for array handling
import numpy as np 

# library for dataframes
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Linear Model
import sklearn as sk

# List Functions module
# !pip install listfun
from listfun import Listoper as lst

# Math Module
import math as m

# Matplotlib and associated plotting modules
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# Machine-Learning and analysis modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

! pip install expsolver;
from expsolver import Solver as solve

# Module to handle XML and HTML 
! pip install lxml;

#Finance information import (Link in "Yahoo Finance" Markdown Cell in the "References" Section)
# !pip install yfinance;
import yfinance as yf;

#Robinhood stocks functions
# !pip install robin_stocks;
import robin_stocks as r;

print('Libraries imported.')
# Out:
# Requirement already satisfied: pip in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (22.0.3)
# Requirement already satisfied: listfun in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (1.2)
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1097: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1480: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:320: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:580: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=None,
# Requirement already satisfied: expsolver in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.5)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.6.4)
# Requirement already satisfied: yfinance in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: lxml>=4.5.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (4.6.4)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (1.21.4)
# Requirement already satisfied: requests>=2.26 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.26->yfinance) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2.0.8)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: robin_stocks in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: python-dotenv in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from robin_stocks) (0.19.2)
# Requirement already satisfied: pyotp in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from robin_stocks) (2.6.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from robin_stocks) (2.26.0)
# Requirement already satisfied: cryptography in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from robin_stocks) (36.0.0)
# Requirement already satisfied: cffi>=1.12 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from cryptography->robin_stocks) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->robin_stocks) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->robin_stocks) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->robin_stocks) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->robin_stocks) (2.0.8)
# Requirement already satisfied: pycparser in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from cffi>=1.12->cryptography->robin_stocks) (2.21)
# Libraries imported.

# %% [markdown]
# ## Import Data into DataFrame

# %%
# Sample interval = 1 day
sample_interval ='1d'

# %%
end=pd.to_datetime(end)
if len(start)<=4:
    start=end-pd.to_timedelta(start)
else:
    start=pd.to_datetime(start)
print('Start: {}, End: {}'.format(start,end))
# Out:
# Start: 2020-05-27 00:00:00, End: 2020-07-01 00:00:00

# %%
# Calculate number of days
num_days=m.floor(pd.to_timedelta(end-start).total_seconds()/(24*3600))
num_days
# Out:
# 35

# %%
smooth_window=m.floor(num_days/7)
if smooth_window<1:
    smooth_window=1
#sample_interval='{}d'.format(sample_interval)
smooth_window=1;
print(smooth_window)
# Out:
# 1

# %% [markdown]
# ### Create basic dataframe "df_info" containing all the available stocks information

# %%
# Create list of stock names as specified by the User
s_list=s_list.split(' ')
s_list=list(set(s_list))

# %%
# Initialize Basic Dataframe as empty
df_info=pd.DataFrame() 

# Add Shares information for List of stock names
for item in s_list:
    try:
        data=yf.Ticker(item)
        df_data=data.history(start=start ,end=end )
        df_data=df_data.reset_index()
        df_data['Name']=pd.DataFrame([item for i in range(0,len(df_data))])
    except:
        print(item)
        continue
    df_info=pd.concat([df_info,df_data])
### Display Initial basic information ####
df_info.head()
# Out:
# - RBLX: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# RBLX
# - RKT: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# RKT
# - XPEV: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# XPEV
# - MSOS: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# MSOS
# - PLTR: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# PLTR
# - COIN: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# COIN
# - ARKX: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# ARKX
# - INDF: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# INDF
# - DMYI: No data found, symbol may be delisted
# DMYI
# - ABNB: Data doesn't exist for startDate = 1590537600, endDate = 1593561600
# ABNB
#         Date        Open        High         Low       Close    Volume  \
# 0 2020-05-27  159.419998  161.339996  159.199997  161.179993  13063500
# 1 2020-05-28  162.119995  162.460007  160.899994  161.720001   9758500
# 2 2020-05-29  162.580002  163.399994  162.320007  162.910004  12581800
# 3 2020-06-01  162.919998  163.740005  162.389999  163.660004   8140200
# 4 2020-06-02  163.889999  164.080002  161.860001  162.600006  10388900
#
#    Dividends  Stock Splits Name
# 0        0.0           0.0  GLD
# 1        0.0           0.0  GLD
# 2        0.0           0.0  GLD
# 3        0.0           0.0  GLD
# 4        0.0           0.0  GLD

# %%
# Reverse?#
if reverse_data=='Y':
    df_info=df_info[::-1];
# Display basic information
df_info.head()
# Out:
#          Date       Open       High        Low      Close  Volume  Dividends  \
# 24 2020-06-30  12.399986  12.957937  12.226829  12.880979  203500        0.0
# 23 2020-06-29  12.351886  12.351886  12.159489  12.342266  127700        0.0
# 22 2020-06-26  12.082532  12.217209  11.755457  12.178730   83500        0.0
# 21 2020-06-25  11.938234  12.101771  11.822796  12.101771   68900        0.0
# 20 2020-06-24  12.034433  12.342268  11.784316  11.976713  146900        0.0
#
#     Stock Splits  Name
# 24           0.0  SLVP
# 23           0.0  SLVP
# 22           0.0  SLVP
# 21           0.0  SLVP
# 20           0.0  SLVP

# %%
# Size of Data:
print('Size of the full dataset is: {} by {}'.format(df_info.shape[0],df_info.shape[1]))
# Out:
# Size of the full dataset is: 3677 by 9

# %% [markdown]
# ## Exploratory Pre-Processing Analysis

# %% [markdown]
# ### Create Dataframe (df) of Relevant share Price vs. date, which will be the data looked at in this analysis

# %%
# Create new Dataframe of relevant Share Prices
if reverse_data=='Y':
    datevalues=df_info['Date'].sort_values(ascending=False).drop_duplicates().tolist()
else:
    datevalues=df_info['Date'].sort_values().drop_duplicates().tolist()
    
df=pd.DataFrame(index=datevalues,columns=s_list)
for item in s_list:
    df_item=df_info[df_info['Name']==item]
    for ind in df.index.tolist():
    #df[['Date',item]]=df_info.loc[df_info['Name']==item,['Date',pricetype]]
        try:
            df.loc[ind,item]=df_item.loc[df_item['Date']==ind,pricetype].values[0]
        except:
            pass
    df[item].fillna(method='bfill',inplace=True)
    df[item].fillna(method='ffill',inplace=True)
df['Mean']=df.mean(axis=1)

# Smoothing

df_unsmoothed=df.copy()

df=df.rolling(window=smooth_window).mean()

df.dropna(how='all',axis=1,inplace=True)
df.dropna(how='any',axis=0,inplace=True)

df_price=df.copy()

# Display initial few contents of the Dataset
df.head(10)
# Out:
#                    GLD        AMD         M         F  SOLO      BTC-USD  \
# 2020-07-01  167.369995  52.610001  6.789999  6.018595  2.25  9228.325195
# 2020-06-30  167.369995  52.610001  6.789999  6.018595  2.25  9137.993164
# 2020-06-29  166.630005  50.279999  6.533400  5.949302  2.56  9190.854492
# 2020-06-28  166.539993  50.099998  5.941248  5.850312  1.83  9143.582031
# 2020-06-27  166.539993  50.099998  5.941248  5.850312  1.83  9045.390625
# 2020-06-26  166.539993  50.099998  5.941248  5.850312  1.83  9162.917969
# 2020-06-25  165.800003  51.930000  6.414969  5.969100  1.91  9264.813477
# 2020-06-24  165.899994  52.389999  6.691307  5.889908  1.98  9313.610352
# 2020-06-23  166.479996  53.990002  7.056466  6.087888  1.88  9629.658203
# 2020-06-22  165.089996  54.759998  6.987381  6.216576  1.69  9648.717773
#
#                   INO         CLX      VWAGY         KO     PK        COST  \
# 2020-07-01  26.950001  210.522949  15.383236  42.632378   9.89  291.600372
# 2020-06-30  26.950001  210.522949  15.383236  42.632378   9.89  291.600372
# 2020-06-29  31.690001  208.805161  15.226314  42.327045  10.13  290.042419
# 2020-06-28  29.980000  206.617096  15.102676  41.573254   9.50  285.205017
# 2020-06-27  29.980000  206.617096  15.102676  41.573254   9.50  285.205017
# 2020-06-26  29.980000  206.617096  15.102676  41.573254   9.50  285.205017
# 2020-06-25  31.250000  206.252411  15.435544  42.870922  10.01  289.023071
# 2020-06-24  23.870001  203.478973  15.045613  42.603756  10.01  286.609131
# 2020-06-23  21.570000  204.774521  15.502117  43.548382  10.56  289.753998
# 2020-06-22  15.300000  208.152542  15.335684  43.643799  10.33  288.946136
#
#             MARA  GSAT   FUBO         WMT  DOGE-USD       ARKQ       ALTR  \
# 2020-07-01  0.91  0.33  10.45  116.994621  0.002354  46.531853  39.750000
# 2020-06-30  0.91  0.33  10.45  116.994621  0.002320  46.531853  39.750000
# 2020-06-29  0.89  0.31  10.49  116.291351  0.002313  45.302414  38.790001
# 2020-06-28  0.92  0.31  11.15  115.568565  0.002326  44.515568  38.139999
# 2020-06-27  0.92  0.31  11.15  115.568565  0.002313  44.515568  38.139999
# 2020-06-26  0.92  0.31  11.15  115.568565  0.002359  44.515568  38.139999
_row0_col25, #T_0983e_row0_col26, #T_0983e_row0_col27, #T_0983e_row0_col28, #T_0983e_row0_col29, #T_0983e_row0_col30, #T_0983e_row0_col31, #T_0983e_row0_col32, #T_0983e_row0_col33, #T_0983e_row0_col34, #T_0983e_row0_col35, #T_0983e_row0_col36, #T_0983e_row0_col37, #T_0983e_row0_col38, #T_0983e_row0_col39, #T_0983e_row0_col40, #T_0983e_row0_col41, #T_0983e_row0_col42, #T_0983e_row0_col43, #T_0983e_row0_col44, #T_0983e_row0_col45, #T_0983e_row0_col46, #T_0983e_row0_col47, #T_0983e_row0_col48, #T_0983e_row0_col49, #T_0983e_row0_col50, #T_0983e_row0_col51, #T_0983e_row0_col52, #T_0983e_row0_col53, #T_0983e_row0_col54, #T_0983e_row0_col55, #T_0983e_row0_col56, #T_0983e_row0_col57, #T_0983e_row0_col58, #T_0983e_row0_col59, #T_0983e_row0_col60, #T_0983e_row0_col61, #T_0983e_row0_col62, #T_0983e_row0_col63, #T_0983e_row0_col64, #T_0983e_row0_col65, #T_0983e_row0_col66, #T_0983e_row0_col67, #T_0983e_row0_col68, #T_0983e_row0_col69, #T_0983e_row0_col70, #T_0983e_row0_col71, #T_0983e_row0_col72, #T_0983e_row0_col73, #T_0983e_row0_col74, #T_0983e_row0_col75, #T_0983e_row0_col76, #T_0983e_row0_col77, #T_0983e_row0_col78, #T_0983e_row0_col79, #T_0983e_row0_col80, #T_0983e_row0_col81, #T_0983e_row0_col82, #T_0983e_row0_col83, #T_0983e_row0_col84, #T_0983e_row0_col85, #T_0983e_row0_col86, #T_0983e_row0_col87, #T_0983e_row0_col88, #T_0983e_row0_col89, #T_0983e_row0_col90, #T_0983e_row0_col91, #T_0983e_row0_col92, #T_0983e_row0_col93, #T_0983e_row0_col94, #T_0983e_row0_col95, #T_0983e_row0_col96, #T_0983e_row0_col97, #T_0983e_row0_col98, #T_0983e_row0_col99, #T_0983e_row0_col100, #T_0983e_row0_col101, #T_0983e_row0_col102, #T_0983e_row0_col103, #T_0983e_row0_col104, #T_0983e_row0_col105, #T_0983e_row0_col106, #T_0983e_row0_col107, #T_0983e_row0_col108, #T_0983e_row0_col109, #T_0983e_row0_col110, #T_0983e_row0_col111, #T_0983e_row0_col112, #T_0983e_row0_col113, #T_0983e_row0_col114, #T_0983e_row0_col115, #T_0983e_row0_col116, #T_0983e_row0_col117, #T_0983e_row0_col118, #T_0983e_row0_col119, #T_0983e_row0_col120, #T_0983e_row0_col121, #T_0983e_row0_col122, #T_0983e_row0_col123, #T_0983e_row0_col124, #T_0983e_row0_col125, #T_0983e_row0_col126, #T_0983e_row0_col127, #T_0983e_row0_col128, #T_0983e_row0_col129, #T_0983e_row0_col130, #T_0983e_row0_col131, #T_0983e_row0_col132, #T_0983e_row0_col133, #T_0983e_row0_col134, #T_0983e_row0_col135, #T_0983e_row0_col136, #T_0983e_row0_col137, #T_0983e_row0_col138, #T_0983e_row0_col139, #T_0983e_row0_col140, #T_0983e_row0_col141, #T_0983e_row0_col142, #T_0983e_row0_col143, #T_0983e_row0_col144, #T_0983e_row0_col145, #T_0983e_row0_col146, #T_0983e_row1_col2, #T_0983e_row1_col3, #T_0983e_row1_col4, #T_0983e_row1_col6, #T_0983e_row1_col8, #T_0983e_row1_col10, #T_0983e_row1_col12, #T_0983e_row1_col13, #T_0983e_row1_col14, #T_0983e_row1_col16, #T_0983e_row1_col19, #T_0983e_row1_col21, #T_0983e_row1_col23, #T_0983e_row1_col24, #T_0983e_row1_col25, #T_0983e_row1_col28, #T_0983e_row1_col32, #T_0983e_row1_col33, #T_0983e_row1_col35, #T_0983e_row1_col36, #T_0983e_row1_col39, #T_0983e_row1_col40, #T_0983e_row1_col41, #T_0983e_row1_col42, #T_0983e_row1_col46, #T_0983e_row1_col48, #T_0983e_row1_col49, #T_0983e_row1_col50, #T_0983e_row1_col55, #T_0983e_row1_col57, #T_0983e_row1_col58, #T_0983e_row1_col61, #T_0983e_row1_col65, #T_0983e_row1_col68, #T_0983e_row1_col71, #T_0983e_row1_col72, #T_0983e_row1_col73, #T_0983e_row1_col78, #T_0983e_row1_col79, #T_0983e_row1_col81, #T_0983e_row1_col83, #T_0983e_row1_col84, ...

# %% [markdown]
# ### Create basic Time plot to look at pertinent information

# %%
df_info.head()
# Out:
#          Date       Open       High        Low      Close  Volume  Dividends  \
# 24 2020-06-30  12.399986  12.957937  12.226829  12.880979  203500        0.0
# 23 2020-06-29  12.351886  12.351886  12.159489  12.342266  127700        0.0
# 22 2020-06-26  12.082532  12.217209  11.755457  12.178730   83500        0.0
# 21 2020-06-25  11.938234  12.101771  11.822796  12.101771   68900        0.0
# 20 2020-06-24  12.034433  12.342268  11.784316  11.976713  146900        0.0
#
#     Stock Splits  Name
# 24           0.0  SLVP
# 23           0.0  SLVP
# 22           0.0  SLVP
# 21           0.0  SLVP
# 20           0.0  SLVP

# %%
# Plot Open price vs. Time
ax= plt.subplot()
for item in df_price.columns:
    plt.plot(df_price[item])
if reverse_data=='Y':
    ax.invert_xaxis()
    
plt.xticks(rotation=45)
ax.legend(df_price.columns)
plt.ylabel('Share Price [USD]')
ax.grid(True)

# %% [markdown]
# ## What kind of Growth % do we see with the various listings?

# %% [markdown]
# ### Normalize the opening price to determine Growth % over the period of interest

# %% [markdown]
# Normalize w.r.t. start price (df_start) <br>
# Normalization used: (price-start_price)/start_price*100 to obtain df_norm

# %%
# Normalization Function
def df_normalize(df):
    df_strt=df.iloc[0,:]
    df_norm=(df.iloc[:,:]-df_strt)/df_strt*100
    df_strt=pd.DataFrame(df_strt).transpose()
    df_strt.set_axis(['start_price'],axis=0,inplace=True)
    return [df_norm,df_strt]

# Store Normalized values in DataFrame and display results                          
[df_norm,df_start]=df_normalize(df)
df_norm.head()
# Out:
#                  GLD       AMD          M         F       SOLO   BTC-USD  \
# 2020-07-01  0.000000  0.000000   0.000000  0.000000   0.000000  0.000000
# 2020-06-30  0.000000  0.000000   0.000000  0.000000   0.000000 -0.978856
# 2020-06-29 -0.442128 -4.428819  -3.779072 -1.151316  13.777775 -0.406040
# 2020-06-28 -0.495908 -4.770960 -12.500004 -2.796059 -18.666665 -0.918294
# 2020-06-27 -0.495908 -4.770960 -12.500004 -2.796059 -18.666665 -1.982316
#
#                   INO       CLX     VWAGY        KO        PK      COST  \
# 2020-07-01   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 
# 2020-06-29 -1.723633 -4.182233 -1.099206
# 2020-06-28 -4.052023 -5.451826 -2.109923
# 2020-06-27 -4.052023 -5.451826 -2.552339

# %%
# Size of Data:
print('Size of the data is: {} by {}'.format(df_norm.shape[0],df_norm.shape[1]))
# Out:
# Size of the data is: 36 by 147

# %%
# Display basic statistics of the normalized prices
# Darker cells denote higher values
df_norm.describe().loc[['count','mean','min','max'],:].style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style type="text/css">
# #T_510d4_row0_col0, #T_510d4_row0_col1, #T_510d4_row0_col2, #T_510d4_row0_col3, #T_510d4_row0_col4, #T_510d4_row0_col5, #T_510d4_row0_col6, #T_510d4_row0_col7, #T_510d4_row0_col8, #T_510d4_row0_col9, #T_510d4_row0_col10, #T_510d4_row0_col11, #T_510d4_row0_col12, #T_510d4_row0_col13, #T_510d4_row0_col14, #T_510d4_row0_col15, #T_510d4_row0_col16, #T_510d4_row0_col17, #T_510d4_row0_col18, #T_510d4_row0_col19, #T_510d4_row0_col20, #T_510d4_row0_col21, #T_510d4_row0_col22, #T_510d4_row0_col23, #T_510d4_row0_col24, #T_510d4_row0_col25, #T_510d4_row0_col26, #T_510d4_row0_col27, #T_510d4_row0_col28, #T_510d4_row0_col29, #T_510d4_row0_col30, #T_510d4_row0_col31, #T_510d4_row0_col32, #T_510d4_row0_col33, #T_510d4_row0_col34, #T_510d4_row0_col35, #T_510d4_row0_col36, #T_510d4_row0_col37, #T_510d4_row0_col38, #T_510d4_row0_col39, #T_510d4_row0_col40, #T_510d4_row0_col41, #T_510d4_row0_col42, #T_510d4_row0_col43, #T_510d4_row0_col44, #T_510d4_row0_col45, #T_510d4_row0_col46, #T_510d4_row0_col47, #T_510d4_row0_col48, #T_510d4_row0_col49, #T_510d4_row0_col50, #T_510d4_row0_col51, #T_510d4_row0_col52, #T_510d4_row0_col53, #T_510d4_row0_col54, #T_510d4_row0_col55, #T_510d4_row0_col56, #T_510d4_row0_col57, #T_510d4_row0_col58, #T_510d4_row0_col59, #T_510d4_row0_col60, #T_510d4_row0_col61, #T_510d4_row0_col62, #T_510d4_row0_col63, #T_510d4_row0_col64, #T_510d4_row0_col65, #T_510d4_row0_col66, #T_510d4_row0_col67, #T_510d4_row0_col68, #T_510d4_row0_col69, #T_510d4_row0_col70, #T_510d4_row0_col71, #T_510d4_row0_col72, #T_510d4_row0_col73, #T_510d4_row0_col74, #T_510d4_row0_col75, #T_510d4_row0_col76, #T_510d4_row0_col77, #T_510d4_row0_col78, #T_510d4_row0_col79, #T_510d4_row0_col80, #T_510d4_row0_col81, #T_510d4_row0_col82, #T_510d4_row0_col83, #T_510d4_row0_col84, #T_510d4_row0_col85, #T_510d4_row0_col86, #T_510d4_row0_col87, #T_510d4_row0_col88, #T_510d4_row0_col89, #T_510d4_row0_col90, #T_510d4_row0_col91, #T_510d4_row0_col92, #T_510d4_row0_col93, #T_510d4_row0_col94, #T_510d4_row0_col95, #T_510d4_row0_col96, #T_510d4_row0_col97, #T_510d4_row0_col98, #T
#   color: #f1f1f1;
# }
# #T_510d4_row1_col6, #T_510d4_row3_col39, #T_510d4_row3_col41 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_510d4_row1_col7, #T_510d4_row1_col21, #T_510d4_row1_col22, #T_510d4_row2_col103 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col8, #T_510d4_row1_col100, #T_510d4_row1_col121, #T_510d4_row1_col133, #T_510d4_row1_col134 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col9, #T_510d4_row1_col56, #T_510d4_row1_col89, #T_510d4_row1_col102 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col10 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col11, #T_510d4_row1_col12, #T_510d4_row1_col29, #T_510d4_row1_col52, #T_510d4_row1_col54, #T_510d4_row1_col70, #T_510d4_row1_col77, #T_510d4_row1_col130, #T_510d4_row1_col146 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col13, #T_510d4_row1_col47, #T_510d4_row1_col62, #T_510d4_row1_col68, #T_510d4_row1_col98 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col14, #T_510d4_row1_col107 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col15, #T_510d4_row1_col36, #T_510d4_row1_col138 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col16, #T_510d4_row1_col20, #T_510d4_row1_col25, #T_510d4_row1_col57, #T_510d4_row1_col61, #T_510d4_row1_col71, #T_510d4_row1_col88, #T_510d4_row1_col116 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col17, #T_510d4_row1_col53, #T_510d4_row1_col64, #T_510d4_row1_col106, #T_510d4_row1_col115, #T_510d4_row1_col131 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col24, #T_510d4_row2_col35, #T_510d4_row2_col55, #T_510d4_row2_col65, #T_510d4_row2_col90, #T_510d4_row2_col105, #T_510d4_row2_col127, #T_510d4_row2_col143, #T_510d4_row3_col24 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col26, #T_510d4_row1_col34, #T_510d4_row1_col38, #T_510d4_row1_col66, #T_510d4_row1_col101, #T_510d4_row1_col141 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col27, #T_510d4_row1_col139 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col28, #T_510d4_row1_col42 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col31, #T_510d4_row1_col33, #T_510d4_row1_col99, #T_510d4_row1_col122 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col32, #T_510d4_row1_col37, #T_510d4_row1_col74, #T_510d4_row1_col76, #T_510d4_row1_col132 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col35, #T_510d4_row1_col78, #T_510d4_row1_col91, #T_510d4_row1_col124 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col39, #T_510d4_row1_col105, #T_510d4_row1_col136 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col41 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_510d4_row1_col43, #T_510d4_row1_col63 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col44 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col45 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col48, #T_510d4_row1_col72 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_510d4_row1_col50, #T_510d4_row1_col111 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_510d4_row1_col51, #T_510d4_row1_col137 {
#   background-

# %% [markdown]
# ### Plot trends in Normalized values

# %% [markdown]
# Time Plot

# %%
# Display Growth % over time
ax= plt.subplot()
for item in df_norm.columns:
    plt.plot(df_norm[item])

plt.xticks(rotation=45)
ax.legend(df.columns,loc='upper center')
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## How do the price gains of the listings correlate to each other?

# %% [markdown]
# Correlation Matrix

# %%
sns.heatmap(df_norm.corr());

# %%
ax= plt.subplot()
for item in df_norm.columns:
    plt.scatter(df_norm.iloc[:,0],df_norm[item])

ax.legend(df_norm.columns,loc='upper center')
plt.xlabel('{} Growth %'.format(df_norm.columns[0]))
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## Calculate percent and absolute estimate and bounds of Growth

# %% [markdown]
# ### Create a linear regression fit for the data with thrice the standard dev. of obs.-est. to determine the boundaries

# %% [markdown]
# <b> Linear Regression object, score and price boundaries for each listing </b>

# %%
def lin_obj(df):
    df_lin=df.iloc[0:1,:]
    df_lin.reindex(['fit_obj','score','bound'])
    df_lin.drop(index=df_lin.index[0],inplace=True)
    for item in df_lin.columns:
        # ... (intercept and coeff.) of the fits
        X=np.array(pd.to_numeric(df.index)).reshape(-1, 1)
        Y=(df[item].values).reshape(-1, 1)
        lin_list_coeff=[]
        lin_list_intercept=[]
        for i in range(0,1):
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0)
            lin_obj=LinearRegression()
            lin_obj.fit(X_train,y_train)
            lin_list_coeff.append(lin_obj.coef_)
            lin_list_intercept.append(lin_obj.intercept_)
        linobj = LinearRegression()
        linobj.coef_=np.array(np.array(lin_list_coeff).mean()).reshape(-1)
        linobj.intercept_=np.array(np.array(lin_list_intercept).mean()).reshape(-1)
        score=linobj.score(X,Y)
        df_lin.loc['fit_obj',item]=linobj
        df_lin.loc['score',item]=score

    # Calculate price bounds
    df_est=pd.DataFrame()
    df_est.rename_axis(index='Datetime')
    df_est['Datetime']=df.index
    df_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_lin.loc['fit_obj',item]
        for datetime in df_est.index:
            est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            df_est.loc[datetime,'{}'.format(item)]=est
    for item in df.columns:
        df_diff=df[item]-df_est[item]
        bounds=3*df_diff.std()
        df_lin.loc['bound',item]=bounds
        
    return df_lin

# %% [markdown]
# Convert rise and fall from % to price (using price change= percent change/100*start price) and display.<br>

# %%
# Call lin_obj(...) to create the price estimation object dataframe
df_norm_price_est_obj=lin_obj(df_norm)
df_price_bounds_dict={}
for item in df_norm.columns:
    df_price_bounds_dict[item]=df_norm_price_est_obj.loc['bound',item]*df_start.loc['start_price',item]/100
df_price_bounds=pd.DataFrame(df_price_bounds_dict,index=['price_bounds'])
df_norm_price_est_obj=df_norm_price_est_obj.append(df_price_bounds)
df_norm_price_est_obj
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
#                                                             GLD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.562428
# bound                                                  3.076093
# price_bounds                                           5.148457
#
#                                                             AMD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.094499
# bound                                                  8.489792
# price_bounds                                           4.466479
#
#                                                               M  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.111421
# bound                                                 36.012062
# price_bounds                                           2.445218
#
#                                                               F  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.019887
# bound                                                 24.386071
# price_bounds                                           1.467699
#
#                                                            SOLO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.658335
# bound                                                 30.772629
# price_bounds                                           0.692384
#
#                                                         BTC-USD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.35855
# bound                                                  6.458645
# price_bounds                                         596.024741
#
#                                                             INO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.55915
# bound                                                 49.272323
# price_bounds                                          13.278891
#
#                                                             CLX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.664341
# bound                                                  5.336506
# price_bounds                                           11.23457
#
#                                                           VWAGY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.153682
# bound                                                 11.183928
# price_bounds                                            1.72045
#
#                                                              KO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.417612
# bound                                                  7.656885
# price_bounds                                           3.264312
#
#                                                              PK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.112433
# bound                                                 38.234004
# price_bounds                                           3.781343
#
#                                                            COST  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.554813
# bound                                                  3.268293
# price_bounds                                           9.530355
#
#                                                            MARA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.149963
# bound                                                 37.046858
# price_bounds                                           0.337126
#
#                                                            GSAT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.000574
# bound                                                  22.62968
# price_bounds                                           0.074678
#
#                                                            FUBO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.199827
# bound                                                 17.498363
# price_bounds                                           1.828579
#
#                                                             WMT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.548252
# bound                                                  3.489808
# price_bounds                                           4.082888
#
#                                                        DOGE-USD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.732936
# bound                                                  6.240924
# price_bounds                                           0.000147
#
#                                                            ARKQ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.05325
# bound                                                  5.838885
# price_bounds                                           2.716941
#
#                                                            ALTR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.002821
# bound                                                  7.756627
# price_bounds                                           3.083259
#
#                                                            VICE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.28143
# bound                                                  6.054789
# price_bounds                                           1.362546
#
#                                                             AXP  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.132186
# bound                                                 16.193151
# price_bounds                                          15.068494
#
#                                                              AG  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.20998
# bound                                                 14.424514
# price_bounds                                           1.433569
#
#                                                            QCOM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.537326
# bound                                                  8.757437
# price_bounds                                           7.767789
#
#                                                            SPCE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.204703
# bound                                                 13.939684
# price_bounds                                           2.277744
#
#                                                            GNUS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.09309
# bound                                                192.076303
# price_bounds                                           4.321717
#
#                                                            UUUU  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.769719
# bound                                                  8.300185
# price_bounds                                           0.125333
#
#                                                              DG  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.069342
# bound                                                  3.922087
# price_bounds                                           7.374591
#
#                                                             XHB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.002694
# bound                                                  8.688355
# price_bounds                                            3.77793
#
#                                                             KSS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.059677
# bound                                                 35.685579
# price_bounds                                            7.27975
#
#                                                             IYJ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.064135
# bound                                                  8.884982
# price_bounds                                            6.61114
#
#                                                             MMM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.167393
# bound                                                  7.939577
# price_bounds                                          11.793623
#
#                                                              GE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.097767
# bound                                                  20.48116
# price_bounds                                          11.127061
#
#                                                            GOVT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.182406
# bound                                                  1.280792
# price_bounds                                           0.349532
#
#                                                             UAL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.021625
# bound                                                 42.943556
# price_bounds                                          14.862765
#
#                                                              BA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.098287
# bound                                                 32.382032
# price_bounds                                          59.356266
#
#                                                            POTX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.496219
# bound                                                  12.98994
# price_bounds                                           1.263324
#
#                                                            VEGI  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.025411
# bound                                                  8.400182
# price_bounds                                           2.040637
#
#                                                             BND  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.694857
# bound                                                  0.545053
# price_bounds                                           0.464313
#
#                                                            OTIS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.143456
# bound                                                 10.816668
# price_bounds                                           6.041707
#
#                                                            NCLH  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.06407
# bound                                                 49.027702
# price_bounds                                           8.055252
#
#                                                             TTM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.056277
# bound                                                 23.158661
# price_bounds                                           1.521524
#
#                                                            IDEX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.676994
# bound                                                 74.233097
# price_bounds                                           1.492085
#
#                                                              GM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.300689
# bound                                                 18.072825
# price_bounds                                           4.572425
#
#                                                            NFLX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.666608
# bound                                                   6.51941
# price_bounds                                          29.665925
#
#                                                            AAPL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.897412
# bound                                                  4.207256
# price_bounds                                           3.800088
#
#                                                            ARKK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.692249
# bound                                                  7.329816
# price_bounds                                           5.102459
#
#                                                             SSL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.157253
# bound                                                  49.19291
# price_bounds                                           3.792773
#
#                                                           GOOGL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.133117
# bound                                                  4.921755
# price_bounds                                          69.792955
#
#                                                            PPBT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.600157
# bound                                                 47.095556
# price_bounds                                           5.227607
#
#                                                            AMRS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.000141
# bound                                                  31.95818
# price_bounds                                           1.364614
#
#                                                            PAAS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.031202
# bound                                                 12.852558
# price_bounds                                           3.845951
#
#                                                            TSLA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.749269
# bound                                                  9.782769
# price_bounds                                          21.127064
#
#                                                             VOO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.010029
# bound                                                  5.936036
# price_bounds                                          16.455549
#
#                                                            SOXX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.278399
# bound                                                  7.234098
# price_bounds                                          19.340671
#
#                                                              VT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.010934
# bound                                                   6.16132
# price_bounds                                           4.472543
#
#                                                            GRPN  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.461447
# bound                                                 51.977507
# price_bounds                                           9.418325
#
#                                                           BRK-B  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.39511
# bound                                                  9.959091
# price_bounds                                          17.777974
#
#                                                            LYFT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.009255
# bound                                                 23.501695
# price_bounds                                           7.757909
#
#                                                             IAU  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.575518
# bound                                                  3.028604
# price_bounds                                            1.02912
#
#                                                             IYR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.043814
# bound                                                  9.770991
# price_bounds                                           7.427062
#
#                                                             DIS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.495269
# bound                                                  9.409995
# price_bounds                                          10.493085
#
#                                                            NBEV  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.01753
# bound                                                 22.630954
# price_bounds                                           0.346254
#
#                                                             DIA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.037266
# bound                                                  7.576664
# price_bounds                                          19.008898
#
#                                                            NVDA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.710384
# bound                                                  4.604746
# price_bounds                                           4.367059
#
#                                                             QQQ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.625814
# bound                                                  3.929701
# price_bounds                                            9.66577
#
#                                                            SENS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.566701
# bound                                                 18.138665
# price_bounds                                           0.070741
#
#                                                             VWO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.370179
# bound                                                  6.328896
# price_bounds                                           2.405441
#
#                                                              SQ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.878982
# bound                                                  8.400751
# price_bounds                                           8.815749
#
#                                                            IEHS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.402656
# bound                                                  5.436598
# price_bounds                                           1.661534
#
#                                                             IAK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.062771
# bound                                                 12.887282
# price_bounds                                           6.842939
#
#                                                             VGK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.025022
# bound                                                  7.406883
# price_bounds                                           3.548015
#
#                                                            FCEL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.031661
# bound                                                  35.69553
# price_bounds                                           0.806719
#
#                                                            UONE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.588706
# bound                                                 115.32318
# price_bounds                                          23.352944
#
#                                                              BB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.018297
# bound                                                 18.840248
# price_bounds                                           0.921288
#
#                                                             AWK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.078289
# bound                                                  6.620656
# price_bounds                                           8.337731
#
#                                                             MCD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.250753
# bound                                                  7.676151
# price_bounds                                          13.681408
#
#                                                             IEF  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.147399
# bound                                                  1.511087
# price_bounds                                           1.815494
#
#                                                             SPY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                    0.0106
# bound                                                  5.924069
# price_bounds                                          17.879072
#
#                                                            TWTR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.165197
# bound                                                 18.836014
# price_bounds                                           5.611249
#
#                                                            GLDG  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.690733
# bound                                                 17.357649
# price_bounds                                           0.302023
#
#                                                         ETH-USD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.023592
# bound                                                 11.512008
# price_bounds                                          26.605796
#
#                                                             NOK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.269223
# bound                                                  9.755848
# price_bounds                                           0.429257
#
#                                                            PYPL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.839038
# bound                                                  5.326793
# price_bounds                                           9.280871
#
#                                                            WKHS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.673709
# bound                                                   39.4435
# price_bounds                                           6.859224
#
#                                                             ACB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.640197
# bound                                                 12.426827
# ...
# score                                                  0.535437
# bound                                                  8.838229
# price_bounds                                           6.333801
#
#                                                            INTC  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.644928
# bound                                                  6.275091
# price_bounds                                           3.608564
#
#                                                             JCI  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.144324
# bound                                                 11.689177
# price_bounds                                           3.878762
#
#                                                            BETZ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.41313
# bound                                                   9.83263
# price_bounds                                           1.481686
#
#                                                            HGSH  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.611116
# bound                                                 50.000873
# price_bounds                                           0.800014
#
#                                                            CARR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.018751
# bound                                                 13.896091
# price_bounds                                           3.038718
#
#                                                              EH  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.33294
# bound                                                  14.06881
# price_bounds                                           1.474974
#
#                                                             SLV  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.048728
# bound                                                  4.482195
# price_bounds                                           0.762421
#
#                                                            UBER  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.707883
# bound                                                 13.306317
# price_bounds                                           4.135603
#
#                                                             JNJ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.733934
# bound                                                  3.819174
# price_bounds                                           5.168324
#
#                                                            SKYY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.548115
# bound                                                  4.751873
# price_bounds                                           3.509259
#
#                                                             HON  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.282846
# bound                                                 11.743105
# price_bounds                                          16.522758
#
#                                                            ARKG  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.498847
# bound                                                 11.823314
# price_bounds                                           6.080753
#
#                                                             JPM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.294181
# bound                                                 15.388942
# price_bounds                                          13.772855
#
#                                                            AMZN  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.904108
# bound                                                  3.858528
# price_bounds                                         106.449832
#
#                                                             TSM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.694663
# bound                                                  6.695815
# price_bounds                                           3.706707
#
#                                                            CPRX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.25191
# bound                                                  9.393668
# price_bounds                                           0.433987
#
#                                                             BAC  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.18182
# bound                                                 17.473629
# price_bounds                                           4.018392
#
#                                                             XLK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.639299
# bound                                                  4.054026
# price_bounds                                           4.184994
#
#                                                             AMC  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.322629
# bound                                                 36.168823
# price_bounds                                           1.551642
#
#                                                             QSR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.162608
# bound                                                  9.272649
# price_bounds                                           4.810858
#
#                                                             RTX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.317263
# bound                                                 14.902863
# price_bounds                                           8.835198
#
#                                                            JMIA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.041116
# bound                                                 35.682232
# price_bounds                                           1.958954
#
#                                                             GME  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.076045
# bound                                                 20.612181
# price_bounds                                           0.894569
#
#                                                             OSK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.184317
# bound                                                 17.104167
# price_bounds                                          12.006777
#
#                                                            TOPS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.024653
# bound                                                 62.869498
# price_bounds                                           2.200432
#
#                                                             NIO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.82756
# bound                                                 19.224119
# price_bounds                                           1.484102
#
#                                                            SNAP  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.881783
# bound                                                  8.107977
# price_bounds                                           1.904564
#
#                                                            SNDL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.023865
# bound                                                 32.055995
# price_bounds                                           0.256127
#
#                                                             HRB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.58689
# bound                                                 23.159481
# price_bounds                                            3.06264
#
#                                                            VXRT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.464659
# bound                                                 54.440665
# price_bounds                                           4.817999
#
#                                                           DMLRY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                       0.0
# bound                                                 15.444001
# price_bounds                                            1.50701
#
#                                                            ZNGA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.401183
# bound                                                  8.844543
# price_bounds                                           0.843769
#
#                                                             VTI  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.005026
# bound                                                  6.151569
# price_bounds                                            9.42648
#
#                                                              MA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.274234
# bound                                                  5.873581
# price_bounds                                           17.21768
#
#                                                               T  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.449781
# bound                                                  8.018675
# price_bounds                                           2.134059
#
#                                                            MRNA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.383937
# bound                                                  11.43738
# price_bounds                                           7.343941
#
#                                                             AAL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.006167
# bound                                                 63.896457
# price_bounds                                           8.351267
#
#                                                            MVIS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.721172
# bound                                                  25.68976
# price_bounds                                           0.349381
#
#                                                             XHS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.418257
# bound                                                  7.236417
# price_bounds                                           4.910214
#
#                                                            NDAQ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                    0.0002
# bound                                                  4.562013
# price_bounds                                           5.344288
#
#                                                             DUK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.547644
# bound                                                  9.646742
# price_bounds                                           7.255418
#
#                                                             PEP  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                    0.0149
# bound                                                  3.200344
# price_bounds                                           4.054372
#
#                                                            CLNE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.026233
# bound                                                 13.352014
# price_bounds                                           0.296415
#
#                                                            TLRY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.829535
# bound                                                 17.150565
# price_bounds                                           1.219405
#
#                                                             XES  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.06438
# bound                                                 33.160292
# price_bounds                                          10.750157
#
#                                                            SLVP  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.101773
# bound                                                  9.649638
# price_bounds                                           1.242968
#
#                                                            Mean
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.000203
# bound                                                   5.09349
# price_bounds                                           7.931189

# %% [markdown]
# ### Estimate the price and bounds vs. date using the fit object

# %%
# Function to estimate the price given the price dataframe, fit objects and datetime query
def price_est(df,df_norm_price_est_obj,df_strt,datetime_query):
    df_price_est=pd.DataFrame()
    df_price_est.rename_axis(index='Datetime')
    df_price_est['Datetime']=pd.to_datetime(datetime_query)
    df_price_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_norm_price_est_obj.loc['fit_obj',item]
        for datetime in df_price_est.index:
            norm_price_est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            price_est=norm_price_est*df_strt.loc['start_price',item]/100+df_strt.loc['start_price',item]
            df_price_est.loc[datetime,'{}'.format(item)]=price_est
            df_price_est.loc[datetime,'{}_low'.format(item)]=price_est-(df_norm_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_high'.format(item)]=price_est+(df_norm_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_lo_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_low'.format(item)]].mean()
            df_price_est.loc[datetime,'{}_hi_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_high'.format(item)]].mean()
            df_price_est.loc[datetime,'{}_lo_ratio'.format(item)]=df_price_est.loc[datetime,'{}_low'.format(item)]/price_est
    df_price_est.reindex(df_price_est.index.date)
    df_price_est=df_price_est
    return df_price_est

# %% [markdown]
# ## What is the predicted share price?

# %%
df_price_est=price_est(df_price,df_norm_price_est_obj,df_start,datetime_query)
df_price_est.style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style type="text/css">
# #T_c77e4_row0_col0, #T_c77e4_row0_col1, #T_c77e4_row0_col2, #T_c77e4_row0_col3, #T_c77e4_row0_col4, #T_c77e4_row0_col36, #T_c77e4_row0_col37, #T_c77e4_row0_col38, #T_c77e4_row0_col39, #T_c77e4_row0_col40, #T_c77e4_row0_col132, #T_c77e4_row0_col134, #T_c77e4_row0_col136, #T_c77e4_row0_col264, #T_c77e4_row0_col265, #T_c77e4_row0_col266, #T_c77e4_row0_col267, #T_c77e4_row0_col268, #T_c77e4_row0_col312, #T_c77e4_row0_col314, #T_c77e4_row0_col315, #T_c77e4_row0_col316, #T_c77e4_row0_col462, #T_c77e4_row0_col463, #T_c77e4_row0_col464, #T_c77e4_row0_col465, #T_c77e4_row0_col466, #T_c77e4_row0_col524, #T_c77e4_row0_col526 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c77e4_row0_col5, #T_c77e4_row0_col6, #T_c77e4_row0_col7, #T_c77e4_row0_col9, #T_c77e4_row0_col11, #T_c77e4_row0_col12, #T_c77e4_row0_col13, #T_c77e4_row0_col14, #T_c77e4_row0_col15, #T_c77e4_row0_col16, #T_c77e4_row0_col17, #T_c77e4_row0_col18, #T_c77e4_row0_col19, #T_c77e4_row0_col20, #T_c77e4_row0_col21, #T_c77e4_row0_col22, #T_c77e4_row0_col23, #T_c77e4_row0_col24, #T_c77e4_row0_col25, #T_c77e4_row0_col26, #T_c77e4_row0_col27, #T_c77e4_row0_col28, #T_c77e4_row0_col29, #T_c77e4_row0_col35, #T_c77e4_row0_col41, #T_c77e4_row0_col47, #T_c77e4_row0_col48, #T_c77e4_row0_col49, #T_c77e4_row0_col50, #T_c77e4_row0_col51, #T_c77e4_row0_col52, #T_c77e4_row0_col53, #T_c77e4_row0_col54, #T_c77e4_row0_col55, #T_c77e4_row0_col56, #T_c77e4_row0_col57, #T_c77e4_row0_col58, #T_c77e4_row0_col59, #T_c77e4_row0_col60, #T_c77e4_row0_col61, #T_c77e4_row0_col62, #T_c77e4_row0_col63, #T_c77e4_row0_col64, #T_c77e4_row0_col65, #T_c77e4_row0_col71, #T_c77e4_row0_col72, #T_c77e4_row0_col73, #T_c77e4_row0_col74, #T_c77e4_row0_col75, #T_c77e4_row0_col76, #T_c77e4_row0_col77, #T_c77e4_row0_col78, #T_c77e4_row0_col79, #T_c77e4_row0_col80, #T_c77e4_row0_col81, #T_c77e4_row0_col82, #T_c77e4_row0_col83, #T_c77e4_row0_col84, #T_c77e4_row0_col85, #T_c77e4_row0_col86, #T_c77e4_row0_col87, #T_c77e4_row0_col88, #T_c77e4_row0_col89, #T_c77e4_row0_col95, #T_c77e4_row0_col96, #T_c77e4_row0_col97, #T_c77e4_row0_col98, #T_c77e4_row0_col99, #T_c77e4_row0_col100, #T_c77e4_row0_col101, #T_c77e4_row0_col107, #T_c77e4_row0_col113, #T_c77e4_row0_col114, #T_c77e4_row0_col115, #T_c77e4_row0_col116, #T_c77e4_row0_col117, #T_c77e4_row0_col118, #T_c77e4_row0_col119, #T_c77e4_row0_col120, #T_c77e4_row0_col121, #T_c77e4_row0_col122, #T_c77e4_row0_col123, #T_c77e4_row0_col124, #T_c77e4_row0_col125, #T_c77e4_row0_col126, #T_c77e4_row0_col127, #T_c77e4_row0_col128, #T_c77e4_row0_col129, #T_c77e4_row0_col130, #T_c77e4_row0_col131, #T_c77e4_row0_col137, #T_c77e4_row0_col138, #T_c77e4_row0_col139, #T_c77e4_row0_col140, #T_c77e4_row0_col141, #T_c77e4_row0_col142, #T_c77e4_row0_col143, #T_c77e4_row0_col144, #T_c77e4_row0_col145, #T_c77e4_row0_col146, #T_c77e4_row0_col147, #T_c77e4_row0_col148, #T_c77e4_row0_col149, #T_c77e4_row0_col150, #T_c77e4_row0_col151, #T_c77e4_row0_col152, #T_c77e4_row0_col153, #T_c77e4_row0_col154, #T_c77e4_row0_col155, #T_c77e4_row0_col161, #T_c77e4_row0_col167, #T_c77e4_row0_col168, #T_c77e4_row0_col169, #T_c77e4_row0_col170, #T_c77e4_row0_col171, #T_c77e4_row0_col172, #T_c77e4_row0_col173, #T_c77e4_row0_col179, #T_c77e4_row0_col185, #T_c77e4_row0_col186, #T_c77e4_row0_col187, #T_c77e4_row0_col188, #T_c77e4_row0_col189, #T_c77e4_row0_col190, #T_c77e4_row0_col191, #T_c77e4_row0_col197, #T_c77e4_row0_col203, #T_c77e4_row0_col209, #T_c77e4_row0_col210, #T_c77e4_row0_col211, #T_c77e4_row0_col212, #T_c77e4_row0_col213, #T_c77e4_row0_col214, #T_c77e4_row0_col215, #T_c77e4_row0_col216, #T_c77e4_row0_col217, #T_c77e4_row0_col218, #T_c77e4_row0_col219, #T_c77e4_row0_col220, #T_c77e4_row0_col221, #T_c77e4_row0_col227, #T_c77e4_row0_col233, #T_c77e4_row0_col234, #T_c77e4_row0_col235, #T_c77e4_row0_col236, #T_c77e4_row0_col237, #T_c77e4_row0_col238, #T_c77e4_row0_col239, #T_c77e4_row0_col240, #T_c77e4_row0_col241, #T_c77e4_row0_col242, #T_c77e4_row0_col243, #T_c77e4_row0_col244, #T_c77e4_row0_col245, #T_c77e4_row0_col251, #T_c77e4_row0_col252, #T_c77e4_row0_col253, #T_c77e4_row0_col254, #T_c77e4_row0_col255, #T_c77e4_row0_col256, #T_c77e4_row0_col257, #T_c77e4_row0_col263, #T_c77e4_row0_col269, #T_c77e4_row0_col275, #T_c77e4_row0_col281, #T_c77e4_row0_col287, #T_c77e4_row0_col293, #T_c77e4_row0_col294, #T_c77e4_row0_col295, #T_c77e4_row0_col296, #T_c77e4_row0_col297, #T_c77e4_row0_col298, #T_c77e4_row0_col299, #T_c77e4_row0_col305, #T_c77e4_row0_col311, #T_c77e4_row0_col317, #T_c77e4_row0_col323, #T_c77e4_row0_col329, #T_c77e4_row0_col335, #T_c77e4_row0_col341, #T_c77e4_row0_col342, #T_c77e4_row0_col343, #T_c77e4_row0_col345, #T_c77e4_row0_col346, #T_c77e4_row0_col347, #T ...

# %% [markdown]
# ## What kind of volatility do the listings have?

# %% [markdown]
# ## How do we generate our investment portfolio?

# %% [markdown]
# ### Estimate the price history along with the bounds and plot the history and estimates for each listing

# %%
# Datetime history query values
datetime_query_start_end=pd.date_range(start=start,end=end)

# %%
# Generate and display estimates (listing, listing_low, listing_high)
df_price_est_start_end=price_est(df_price,df_norm_price_est_obj,df_start,datetime_query_start_end)
df_price_est_start_end.head().style.format("{:.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_faeb3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >GLD</th>
#       <th class="col_heading level0 col1" >GLD_low</th>
#       <th class="col_heading level0 col2" >GLD_high</th>
#       <th class="col_heading level0 col3" >GLD_lo_mid</th>
#       <th class="col_heading level0 col4" >GLD_hi_mid</th>
#       <th class="col_heading level0 col5" >GLD_lo_ratio</th>
#       <th class="col_heading level0 col6" >AMD</th>
#       <th class="col_heading level0 col7" >AMD_low</th>
#       <th class="col_heading level0 col8" >AMD_high</th>
#       <th class="col_heading level0 col9" >AMD_lo_mid</th>
#       <th class="col_heading level0 col10" >AMD_hi_mid</th>
#       <th class="col_heading level0 col11" >AMD_lo_ratio</th>
#       <th class="col_heading level0 col12" >M</th>
#       <th class="col_heading level0 col13" >M_low</th>
#       <th class="col_heading level0 col14" >M_high</th>
#       <th class="col_heading level0 col15" >M_lo_mid</th>
#       <th class="col_heading level0 col16" >M_hi_mid</th>
#       <th class="col_heading level0 col17" >M_lo_ratio</th>
#       <th class="col_heading level0 col18" >F</th>
#       <th class="col_heading level0 col19" >F_low</th>
#       <th class="col_heading level0 col20" >F_high</th>
#       <th class="col_heading level0 col21" >F_lo_mid</th>
#       <th class="col_heading level0 col22" >F_hi_mid</th>
#       <th class="col_heading level0 col23" >F_lo_ratio</th>
#       <th class="col_heading level0 col24" >SOLO</th>
#       <th class="col_heading level0 col25" >SOLO_low</th>
#       <th class="col_heading level0 col26" >SOLO_high</th>
#       <th class="col_heading level0 col27" >SOLO_lo_mid</th>
#       <th class="col_heading level0 col28" >SOLO_hi_mid</th>
#       <th class="col_heading level0 col29" >SOLO_lo_ratio</th>
#       <th class="col_heading level0 col30" >BTC-USD</th>
#       <th class="col_heading level0 col31" >BTC-USD_low</th>
#       <th class="col_heading level0 col32" >BTC-USD_high</th>
#       <th class="col_heading level0 col33" >BTC-USD_lo_mid</th>
#       <th class="col_heading level0 col34" >BTC-USD_hi_mid</th>
#       <th class="col_heading level0 col35" >BTC-USD_lo_ratio</th>
#       <th class="col_heading level0 col36" >INO</th>
#       <th class="col_heading level0 col37" >INO_low</th>
#       <th class="col_heading level0 col38" >INO_high</th>
#       <th class="col_heading level0 col39" >INO_lo_mid</th>
#       <th class="col_heading level0 col40" >INO_hi_mid</th>
#       <th class="col_heading level0 col41" >INO_lo_ratio</th>
#       <th class="col_heading level0 col42" >CLX</th>
#       <th class="col_heading level0 col43" >CLX_low</th>
#       <th class="col_heading level0 col44" >CLX_high</th>
#       <th class="col_heading level0 col45" >CLX_lo_mid</th>
#       <th class="col_heading level0 col46" >CLX_hi_mid</th>
#       <th class="col_heading level0 col47" >CLX_lo_ratio</th>
#       <th class="col_heading level0 col48" >VWAGY</th>
#       <th class="col_heading level0 col49" >VWAGY_low</th>
#       <th class="col_heading level0 col50" >VWAGY_high</th>
#       <th class="col_heading level0 col51" >VWAGY_lo_mid</th>
#       <th class="col_heading level0 col52" >VWAGY_hi_mid</th>
#       <th class="col_heading level0 col53" >VWAGY_lo_ratio</th>
#       <th class="col_heading level0 col54" >KO</th>
#       <th class="col_heading level0 col55" >KO_low</th>
#       <th class="col_heading level0 col56" >KO_high</th>
#       <th class="col_heading level0 col57" >KO_lo_mid</th>
#       <th class="col_heading level0 col58" >KO_hi_mid</th>
#       <th class="col_heading level0 col59" >KO_lo_ratio</th>
#       <th class="col_heading level0 col60" >PK</th>
#       <th class="col_heading level0 col61" >PK_low</th>
#       <th class="col_heading level0 col62" >PK_high</th>
#       <th class="col_heading level0 col63" >PK_lo_mid</th>
#       <th class="col_heading level0 col64" >PK_hi_mid</th>
#       <th class="col_heading level0 col65" >PK_lo_ratio</th>
#       <th class="col_heading level0 col66" >COST</th>
#       <th class="col_heading level0 col67" >COST_low</th>
#       <th class="col_heading level0 col68" >COST_high</th>
#       <th class="col_heading level0 col69" >COST_lo_mid</th>
#       <th class="col_heading level0 col70" >COST_hi_mid</th>
#       <th class="col_heading level0 col71" >COST_lo_ratio</th>
#       <th class="col_heading level0 col72" >MARA</th>
#       <th class="col_heading level0 col73" >MARA_low</th>
#       <th class="col_heading level0 col74" >MARA_high</th>
#       <th class="col_heading level0 col75" >MARA_lo_mid</th>
#       <th class="col_heading level0 col76" >MARA_hi_mid</th>
#       <th class="col_heading level0 col77" >MARA_lo_ratio</th>
#       <th class="col_heading level0 col78" >GSAT</th>
#       <th class="col_heading level0 col79" >GSAT_low</th>
#       <th class="col_heading level0 col80" >GSAT_high</th>
#       <th class="col_heading level0 col81" >GSAT_lo_mid</th>
#       <th class="col_heading level0 col82" >GSAT_hi_mid</th>
#       <th class="col_heading level0 col83" >GSAT_lo_ratio</th>
#       <th class="col_heading level0 col84" >FUBO</th>
#       <th class="col_heading level0 col85" >FUBO_low</th>
#       <th class="col_heading level0 col86" >FUBO_high</th>
#       <th class="col_heading level0 col87" >FUBO_lo_mid</th>
#       <th class="col_heading level0 col88" >FUBO_hi_mid</th>
#       <th class="col_heading level0 col89" >FUBO_lo_ratio</th>
#       <th class="col_heading level0 col90" >WMT</th>
#       <th class="col_heading level0 col91" >WMT_low</th>
#       <th class="col_heading level0 col92" >WMT_high</th>
#       <th class="col_heading level0 col93" >WMT_lo_mid</th>
#       <th class="col_heading level0 col94" >WMT_hi_mid</th>
#       <th class="col_heading level0 col95" >WMT_lo_ratio</th>
#       <th class="col_heading level0 col96" >DOGE-USD</th>
#       <th class="col_heading level0 col97" >DOGE-USD_low</th>
#       <th class="col_heading level0 col98" >DOGE-USD_high</th>
#       <th class="col_heading level0 col99" >DOGE-USD_lo_mid</th>
#       <th class="col_heading level0 col100" >DOGE-USD_hi_mid</th>
#       <th class="col_heading level0 col101" >DOGE-USD_lo_ratio</th>
#       <th class="col_heading level0 col102" >ARKQ</th>
#       <th class="col_heading level0 col103" >ARKQ_low</th>
#       <th class="col_heading level0 col104" >ARKQ_high</th>
#       <th class="col_heading level0 col105" >ARKQ_lo_mid</th>
#       <th class="col_heading level0 col106" >ARKQ_hi_mid</th>
#       <th class="col_heading level0 col107" >ARKQ_lo_ratio</th>
#       <th class="col_heading level0 col108" >ALTR</th>
#       <th class="col_heading level0 col109" >ALTR_low</th>
#       <th class="col_heading level0 col110" >ALTR_high</th>
#       <th class="col_heading level0 col111" >ALTR_lo_mid</th>
#       <th class="col_heading level0 col112" >ALTR_hi_mid</th>
#       <th class="col_heading level0 col113" >ALTR_lo_ratio</th>
#       <th class="col_heading level0 col114" >VICE</th>
#       <th class="col_heading level0 col115" >VICE_low</th>
#       <th class="col_heading level0 col116" >VICE_high</th>
#       <th class="col_heading level0 col117" >VICE_lo_mid</th>
#       <th class="col_heading level0 col118" >VICE_hi_mid</th>
#       <th class="col_heading level0 col119" >VICE_lo_ratio</th>
#       <th class="col_heading level0 col120" >AXP</th>
#       <th class="col_heading level0 col121" >AXP_low</th>
#       <th class="col_heading level0 col122" >AXP_high</th>
#       <th class="col_heading level0 col123" >AXP_lo_mid</th>
#       <th class="col_heading level0 col124" >AXP_hi_mid</th>
#       <th class="col_heading level0 col125" >AXP_lo_ratio</th>
#       <th class="col_heading level0 col126" >AG</th>
#       <th class="col_heading level0 col127" >AG_low</th>
#       <th class="col_heading level0 col128" >AG_high</th>
#       <th class="col_heading level0 col129" >AG_lo_mid</th>
#       <th class="col_heading level0 col130" >AG_hi_mid</th>
#       <th class="col_heading level0 col131" >AG_lo_ratio</th>
#       <th class="col_heading level0 col132" >QCOM</th>
#       <th class="col_heading leve

# %%
# Plot price vs. Time
num_plot=len(df.columns)
i=1
item = df_price.columns.tolist()[-1]
ax=plt.subplot()
plt.plot(df_price[item])
plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid']])
plt.legend([item,item+'_predicted',item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid'])
plt.ylabel('Share Price [USD]')
plt.xticks(rotation=45)
if  reverse_data=='Y':
    ax.invert_xaxis()
plt.grid(True)
plt.title(item)
i=i+1

# %% [markdown]
# ## Constructing the Portfolio

# %% [markdown]
# In order to balance the investments, we'd want to have the most benefit (reward) while minimizing volatility (risk).<br>
# 1. We can consider 'reward' to be the slope of the linear fit to share price (higher the slope, higher the gain).<br>
# 2. We can consider 'risk' to be the ratio between the price bounds and change in price over the duration of interest <br>
# 3. Hence we can compute a 'returns ratio' = 'reward'/'risk' for each listing; the higher this value, the more this investment is viable. <br>
# 4. Then we can compute the sum of the returns ratios for each listing and divide the returns ratio by the summed value, to determine the "weight" of each investment <br>
# 5. Finally we can multiply the "weight" by the total investment capital (total_investment) to obtain the recommended investment for each listing <br>

# %% [markdown]
# ### Use the Linear Regression object to construct the reward, volatility, returns ratio, weight and suggested investment values

# %%
mean_datetime=df.index.mean()
mean_price_est=price_est(df_price,df_norm_price_est_obj,df_start,[mean_datetime])

# %%
#Remove 'Mean' Columns
col_list=mean_price_est.columns.tolist()
for item in col_list:
    if 'Mean' in item:
        col_list.remove(item)
mean_price_est=mean_price_est.loc[:,col_list]

df_norm_price_est_obj.pop('Mean')
df.pop('Mean')
df_start.pop('Mean')
# Out:
# start_price    155.712261
# Name: Mean, dtype: float64

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
    
df_portfolio=df_norm_price_est_obj.copy()
df_portfolio=df_portfolio.reindex(['reward','risk','returns_ratio','weight','price_bound','suggested_investment'])
df_portfolio=df_portfolio.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_portfolio.columns):
    df_portfolio.loc['reward',item]=(df_norm_price_est_obj.loc['fit_obj',item].coef_[0])*10**17
    
# Update the "volatility" as the line fit score
for item in (df_portfolio.columns):
    df_portfolio.loc['risk',item]=1/(df_norm_price_est_obj.loc['score',item])
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_portfolio.columns):
    df_portfolio.loc['returns_ratio',item]=(df_portfolio.loc['reward',item]/
                                            df_portfolio.loc['risk',item])

    # Remove those listings with negative returns_ratio since those imply a falling stock
df_price_est_end=price_est(df,df_norm_price_est_obj,df_start,[df.index[-1].strftime('%m/%d/%y')])
for item in df_portfolio.columns:
    item_low_str=item+'_low'
    item_hi_str=item+'_high'
    if df_portfolio.loc['returns_ratio',item]<=0 or df[item].iloc[-1]>=df_price_est_end[item_hi_str].to_numpy()[0] or \
    df[item].iloc[-1]<=df_price_est_end[item_low_str].to_numpy()[0]:
        #if df_portfolio.loc['reward',item]<=201 or df_portfolio.loc['risk',item]>71:
        df_portfolio.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['returns_ratio',item]/df_portfolio.loc['returns_ratio',:].sum()
    
# Update stop loss limit
for item in (df_portfolio.columns):
    df_portfolio.loc['price_bound',item]=df_norm_price_est_obj.loc['price_bounds',item]
    
# Multiply the weight of each listing by the total investment capital to obtain the recommended investment
for item in (df_portfolio.columns):
    suggested_investment=df_portfolio.loc['weight',item]*total_investment
    if df_portfolio.loc['weight',item] <=0.01:
        df_portfolio.pop(item)
        
df_portfolio.loc['suggested_investment',:]=df_portfolio.loc['weight',:]*total_investment

## Sort in descending order #
df_portfolio=df_portfolio.sort_values(by='weight',axis=1,ascending=False);
if reverse_weights=='Y':
    df_portfolio.loc['weight',:]=df_portfolio.loc['weight',:][::-1].tolist()
# ## Sort in descending order #
df_portfolio.loc['suggested_investment',:]=df_portfolio.loc['weight',:]*total_investment
df_portfolio=df_portfolio.sort_values(axis=1,by='weight',ascending=False);

#Recalculate weights and suggested investments##
inv_ratio=df_portfolio.loc['suggested_investment'].sum()/total_investment;
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['weight',item]/inv_ratio
    suggested_investment=df_portfolio.loc['weight',item]*total_investment
    df_portfolio.loc['suggested_investment',item]=suggested_investment


# Display the portfolio dataframe
df_portfolio
# Out:
#                              UONE         IDEX         HGSH         WKHS  \
# Parameters
# reward                5052.348066  3935.394202  2295.264074  2075.452517
# risk                      1.69864     1.477118     1.636351      1.48432
# returns_ratio         2974.348149  2664.238395  1402.672024  1398.251486
# weight                   0.145468     0.130301     0.068601     0.068385
# price_bound             23.352944     1.492085     0.800014     6.859224
# suggested_investment  1018.422926   912.240709   480.277787   478.764186
#
#                               NIO         PPBT          INO         MVIS  \
# Parameters
# reward                1542.164114  2112.862033  2032.009225   1512.91445
# risk                     1.208372     1.666231     1.788427     1.386633
# returns_ratio         1276.233232  1268.048962  1136.198847  1091.070945
# weight                   0.062417     0.062017     0.055569     0.053362
# price_bound              1.484102     5.227607    13.278891     0.349381
# suggested_investment   436.984885   434.182574   389.036823   373.584937
#
#                              SOLO         VXRT          SQ        SNAP  \
# Parameters
# reward                 1564.19652  1857.284978  829.063117  810.881995
# risk                     1.518984     2.152117    1.137679    1.134065
# returns_ratio         1029.765286   863.003521  728.731938  715.022254
# weight                   0.050363     0.042207    0.035641     0.03497
# price_bound              0.692384     4.817999    8.815749    1.904564
# suggested_investment   352.593753   295.494181  249.519315  244.825091
#
#                             GLDG        TSLA         KOSS        AAPL  \
# Parameters
# reward                 949.90992  619.270836  1033.508985  455.670848
# risk                    1.447738    1.334633     2.516325    1.114315
# returns_ratio         656.133855  464.000682   410.721512  408.924714
# weight                   0.03209    0.022693     0.020087        0.02
# price_bound             0.302023   21.127064     0.472657    3.800088
# suggested_investment  224.661582  158.874788   140.631891  140.016664
#
#                             AMZN        PYPL         DKS        MSFT  \
# Parameters
# reward                433.855217  445.346776  464.330855  337.642826
# risk                    1.106062    1.191841    1.263112    1.163263
# returns_ratio         392.252101  373.662822  367.608524  290.254957
# weight                  0.019184    0.018275    0.017979    0.014196
# price_bound           106.449832    9.280871    2.505142    7.481251
# suggested_investment  134.307926  127.942919  125.869915   99.383895
#
#                             ARKK         TSM
# Parameters
# reward                402.557688  369.831858
# risk                    1.444567    1.439547
# returns_ratio         278.670206  256.908509
# weight                  0.013629    0.012565
# price_bound             5.102459    3.706707
# suggested_investment   95.417252   87.966002

# %%
stock_labels=df_portfolio.columns
values=df_portfolio.loc['suggested_investment',:]
plt.pie(values, labels=stock_labels,radius=3, autopct='%1.0f%%');

# %% [markdown]
# ## Save Portfolio Data

# %%
if save_port=='Y' or save_port==True:
    df_portfolio.sort_values(axis=1,by='weight',ascending=False).to_csv('portfolio.csv')
if save_mean=='Y' or save_mean==True:
    df_price.loc[:,'Mean'].to_csv('mean.csv')

# %% [markdown]
# ## Weighted Mean

# %% [markdown]
# ### Portfolio Weighted Mean

# %%
df_port_weights=df_portfolio.loc['weight',:]

weight_stocks=df_port_weights.index.tolist()
port_data=df_price.loc[:,weight_stocks]

port_weight_data=port_data.copy()
for ticker in port_weight_data.columns:
    port_weight_data.loc[:,ticker]=port_weight_data.loc[:,ticker]*df_port_weights[ticker]
port_weighted_mean_data=port_weight_data.sum(axis=1)
df_port_price_means=df_price.loc[:,'Mean']
df_port_price_means['Weighted_Mean']=port_weighted_mean_data

# %%
## Plot Weighted Mean ##
plt.figure()
plt.plot(df_port_price_means['Weighted_Mean'],'bo')
plt.ylabel('Share Price [USD]')
plt.xticks(rotation=45)
plt.grid(True)
plt.title('Portfolio Weighted_Mean')
# Out:
# Text(0.5, 1.0, 'Portfolio Weighted_Mean')

# %% [markdown]
# ### Saved Portfolio Weighted Mean (read data from 'portfolio.csv')

# %%
df_port_weights=pd.read_csv('portfolio.csv')
df_port_weights.set_index('Parameters',inplace=True)

weight_stocks=df_port_weights.columns.tolist()
port_data=df_price.loc[:,weight_stocks]

avg_weights=df_port_weights.loc['weight',:]
weight_data=port_data.copy()

for ticker in weight_data.columns:
    weight_data.loc[:,ticker]=weight_data.loc[:,ticker]*avg_weights.loc[ticker]
weighted_mean_data=weight_data.sum(axis=1)
df_price_means=df_price.loc[:,'Mean']
df_price_means['Weighted_Mean']=weighted_mean_data

# %%
weight_data.tail()
# Out:
#                 FCEL       TSLA      MRNA      NVDA       AMD      AAPL  \
# 2020-05-31  0.212369  13.245728  4.057559  5.655390  3.191787  3.164476
# 2020-05-30  0.212369  13.245728  4.057559  5.655390  3.191787  3.164476
# 2020-05-29  0.212369  13.245728  4.057559  5.655390  3.191787  3.164476
# 2020-05-28  0.210375  12.782683  3.664338  5.407842  3.069574  3.167561
# 2020-05-27  0.216357  13.011430  3.442657  5.432214  3.128901  3.166168
#
#                  INO      MSFT      PAAS      SPCE      GLDG      CARR  \
# 2020-05-31  0.570367  5.676796  0.886161  0.450614  0.026187  0.451227
# 2020-05-30  0.570367  5.676796  0.886161  0.450614  0.026187  0.451227
# 2020-05-29  0.570367  5.676796  0.886161  0.450614  0.026187  0.451227
# 2020-05-28  0.516230  5.619486  0.814481  0.435540  0.025018  0.432049
# 2020-05-27  0.510043  5.632187  0.789983  0.463307  0.025018  0.440646
#
#                  CLX      ZNGA       IAU       GLD        DG       TSM  \
# 2020-05-31  4.307087  0.195198  0.698897  3.406756  3.925909  1.001967
# 2020-05-30  4.307087  0.195198  0.698897  3.406756  3.925909  1.001967
# 2020-05-29  4.307087  0.195198  0.698897  3.406756  3.925909  1.001967
# 2020-05-28  4.280149  0.172158  0.694246  3.381871  3.774211  1.000972
# 2020-05-27  4.176570  0.170451  0.692555  3.370578  3.837555  1.030037
#
#                 VXRT      INTC      ARKQ      ARKG      NFLX       AMZN  \
# 2020-05-31  0.055088  1.165988  0.785676  0.800954  6.778324  39.291440
# 2020-05-30  0.055088  1.165988  0.785676  0.800954  6.778324  39.291440
# 2020-05-29  0.055088  1.165988  0.785676  0.800954  6.778324  39.291440
# 2020-05-28  0.054472  1.143198  0.774467  0.782806  6.676745  38.627512
# 2020-05-27  0.054061  1.177661  0.787427  0.797670  6.780908  38.776960
#
#                 ARKK       QQQ       XLK       IEF      SOXX      GOVT  \
# 2020-05-31  0.902941  3.378208  1.408078  1.561512  3.041025  0.306870
# 2020-05-30  0.902941  3.378208  1.408078  1.561512  3.041025  0.306870
# 2020-05-29  0.902941  3.378208  1.408078  1.561512  3.041025  0.306870
# 2020-05-28  0.887562  3.329423  1.390543  1.556517  2.965078  0.306212
# 2020-05-27  0.898486  3.333766  1.393274  1.557926  3.031245  0.306431
#
#                  NIO
# 2020-05-31  0.044054
# 2020-05-30  0.044054
# 2020-05-29  0.044054
# 2020-05-28  0.042393
# 2020-05-27  0.046157

# %%
## Plot Weighted Mean ##
plt.figure()
plt.plot(df_price_means['Weighted_Mean'],'bo')
plt.ylabel('Share Price [USD]')
if reverse_data=='Y':
    ax.invert_xaxis()
plt.xticks(rotation=45)
plt.grid(True)
plt.title('Saved Portfolio Weighted_Mean')
# Out:
# Text(0.5, 1.0, 'Saved Portfolio Weighted_Mean')

# %% [markdown]
# ## Compare with previous

# %%
df_saved=pd.read_csv('portfolio.csv')
df_saved.set_index('Parameters',inplace=True)

# %%
comm_stocks=list(set(df_saved.columns.tolist()).intersection(set(df_portfolio.columns.tolist())))

# %%
weight_diff={}
for i in range(len(comm_stocks)):
    ticker=comm_stocks[i]
    weight_diff[ticker]=(df_portfolio.loc['weight',
                                          ticker]-df_saved.loc['weight',ticker])/df_portfolio.loc['weight',ticker]*100
df_weight_diff=pd.DataFrame(weight_diff,index=['weight_diff'])
print('Sum: {}, Min.: {}, Max.: {}'.format(df_weight_diff.sum(axis=1),df_weight_diff.min(axis=1),df_weight_diff.max(axis=1)))
df_weight_diff.sort_values(axis=1,by='weight_diff').transpose().plot(kind='bar',figsize=(12,8));
# Out:
# Sum: weight_diff   -336.14857
# dtype: float64, Min.: weight_diff   -249.513903
# dtype: float64, Max.: weight_diff    82.266634
# dtype: float64

# %% [markdown]
# ## Lowest Trending

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
df_down=df_norm_price_est_obj
df_down=df_down.reindex(['reward','risk','returns_ratio','weight','price_bound'])
df_down=df_down.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_down.columns):
    df_down.loc['reward',item]=(df_norm_price_est_obj.loc['fit_obj',item].coef_[0])*10**17
    
# Update the "volatility" as the line fit score
for item in (df_down.columns):
    df_down.loc['risk',item]=1/(df_norm_price_est_obj.loc['score',item])
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_down.columns):
    df_down.loc['returns_ratio',item]=(df_down.loc['reward',item]/
                                            df_down.loc['risk',item])
    
# Remove those listings with negative returns_ratio since those imply a falling stock
df_price_est_end=price_est(df,df_norm_price_est_obj,df_start,[df.index[-1].strftime('%m/%d/%y')])
for item in df_down.columns:
    item_low_str=item+'_low'
    item_hi_str=item+'_high'
    if df_down.loc['returns_ratio',item]>=-21 or df[item].iloc[-1]>=df_price_est_end[item_hi_str].to_numpy()[0]:
        if df_down.loc['reward',item]>=-201:
            df_down.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_down.columns):
    df_down.loc['weight',item]=df_down.loc['returns_ratio',item]/df_down.loc['returns_ratio',:].sum()
    
# Update stop loss limit
for item in (df_down.columns):
    df_down.loc['price_bound',item]=df_norm_price_est_obj.loc['price_bounds',item]
    
# Display the portfolio dataframe
df_down.sort_values(axis=1,by='weight',ascending=False).style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c85bd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >TLRY</th>
#       <th class="col_heading level0 col1" >GEVO</th>
#       <th class="col_heading level0 col2" >GRPN</th>
#       <th class="col_heading level0 col3" >HRB</th>
#       <th class="col_heading level0 col4" >PFE</th>
#       <th class="col_heading level0 col5" >UBER</th>
#       <th class="col_heading level0 col6" >SENS</th>
#       <th class="col_heading level0 col7" >UUUU</th>
#       <th class="col_heading level0 col8" >ACB</th>
#       <th class="col_heading level0 col9" >H</th>
#       <th class="col_heading level0 col10" >AMC</th>
#       <th class="col_heading level0 col11" >DOGE-USD</th>
#       <th class="col_heading level0 col12" >POTX</th>
#       <th class="col_heading level0 col13" >DUK</th>
#       <th class="col_heading level0 col14" >GNUS</th>
#       <th class="col_heading level0 col15" >INTC</th>
#       <th class="col_heading level0 col16" >SBUX</th>
#       <th class="col_heading level0 col17" >JNJ</th>
#       <th class="col_heading level0 col18" >DIS</th>
#       <th class="col_heading level0 col19" >GM</th>
#       <th class="col_heading level0 col20" >BETZ</th>
#       <th class="col_heading level0 col21" >EH</th>
#       <th class="col_heading level0 col22" >T</th>
#       <th class="col_heading level0 col23" >RTX</th>
#       <th class="col_heading level0 col24" >BRK-B</th>
#       <th class="col_heading level0 col25" >JPM</th>
#       <th class="col_heading level0 col26" >KO</th>
#       <th class="col_heading level0 col27" >XHS</th>
#       <th class="col_heading level0 col28" >WMT</th>
#       <th class="col_heading level0 col29" >HON</th>
#       <th class="col_heading level0 col30" >COST</th>
#       <th class="col_heading level0 col31" >IEHS</th>
#       <th class="col_heading level0 col32" >XLE</th>
#       <th class="col_heading level0 col33" >FUBO</th>
#       <th class="col_heading level0 col34" >BTC-USD</th>
#       <th class="col_heading level0 col35" >AG</th>
#       <th class="col_heading level0 col36" >PK</th>
#       <th class="col_heading level0 col37" >OSK</th>
#       <th class="col_heading level0 col38" >BAC</th>
#       <th class="col_heading level0 col39" >SPCE</th>
#       <th class="col_heading level0 col40" >M</th>
#       <th class="col_heading level0 col41" >TWTR</th>
#       <th class="col_heading level0 col42" >MCD</th>
#       <th class="col_heading level0 col43" >VICE</th>
#       <th class="col_heading level0 col44" >MA</th>
#       <th class="col_heading level0 col45" >AXP</th>
#       <th class="col_heading level0 col46" >NCLH</th>
#       <th class="col_heading level0 col47" >VWAGY</th>
#       <th class="col_heading level0 col48" >QSR</th>
#       <th class="col_heading level0 col49" >GE</th>
#       <th class="col_heading level0 col50" >MMM</th>
#       <th class="col_heading level0 col51" >XES</th>
#       <th class="col_heading level0 col52" >KSS</th>
#       <th class="col_heading level0 col53" >TOPS</th>
#       <th class="col_heading level0 col54" >FCEL</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parameters</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#       <th class="blank col40" >&nbsp;</th>
#       <th class="blank col41" >&nbsp;</th>
#       <th class="blank col42" >&nbsp;</th>
#       <th class="blank col43" >&nbsp;</th>
#       <th class="blank col44" >&nbsp;</th>
#       <th class="blank col45" >&nbsp;</th>
#       <th class="blank col46" >&nbsp;</th>
#       <th class="blank col47" >&nbsp;</th>
#       <th class="blank col48" >&nbsp;</th>
#       <th class="blank col49" >&nbsp;</th>
#       <th class="blank col50" >&nbsp;</th>
#       <th class="blank col51" >&nbsp;</th>
#       <th class="blank col52" >&nbsp;</th>
#       <th class="blank col53" >&nbsp;</th>
#       <th class="blank col54" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c85bd_level0_row0" class="row_heading level0 row0" >reward</th>
#       <td id="T_c85bd_row0_col0" class="data row0 col0" >-1385.42</td>
#       <td id="T_c85bd_row0_col1" class="data row0 col1" >-1697.37</td>
#       <td id="T_c85bd_row0_col2" class="data row0 col2" >-1761.84</td>
#       <td id="T_c85bd_row0_col3" class="data row0 col3" >-1010.83</td>
#       <td id="T_c85bd_row0_col4" class="data row0 col4" >-628.91</td>
#       <td id="T_c85bd_row0_col5" class="data row0 col5" >-758.51</td>
#       <td id="T_c85bd_row0_col6" class="data row0 col6" >-759.61</td>
#       <td id="T_c85bd_row0_col7" class="data row0 col7" >-555.68</td>
#       <td id="T_c85bd_row0_col8" class="data row0 col8" >-607.00</td>
#       <td id="T_c85bd_row0_col9" class="data row0 col9" >-732.28</td>
#       <td id="T_c85bd_row0_col10" class="data row0 col10" >-914.06</td>
#       <td id="T_c85bd_row0_col11" class="data row0 col11" >-378.60</td>
#       <td id="T_c85bd_row0_col12" class="data row0 col12" >-472.09</td>
#       <td id="T_c85bd_row0_col13" class="data row0 col13" >-388.68</td>
#       <td id="T_c85bd_row0_col14" class="data row0 col14" >-2253.44</td>
#       <td id="T_c85bd_row0_col15" class="data row0 col15" >-309.69</td>
#       <td id="T_c85bd_row0_col16" class="data row0 col16" >-347.46</td>
#       <td id="T_c85bd_row0_col17" class="data row0 col17" >-232.28</td>
#       <td id="T_c85bd_row0_col18" class="data row0 col18" >-341.34</td>
#       <td id="T_c85bd_row0_col19" class="data row0 col19" >-433.96</td>
#       <td id="T_c85bd_row0_col20" class="data row0 col20" >-302.10</td>
#       <td id="T_c85bd_row0_col21" class="data row0 col21" >-363.97</td>
#       <td id="T_c85bd_row0_col22" class="data row0 col22" >-265.48</td>
#       <td id="T_c85bd_row0_col23" class="data row0 col23" >-372.01</td>
#       <td id="T_c85bd_row0_col24" class="data row0 col24" >-294.74</td>
#       <td id="T_c85bd_row0_col25" class="data row0 col25" >-363.81</td>
#       <td id="T_c85bd_row0_col26" class="data row0 col26" >-237.43</td>
#       <td id="T_c85bd_row0_col27" class="data row0 col27" >-224.69</td>
#       <td id="T_c85bd_row0_col28" class="data row0 col28" >-140.78</td>
#       <td id="T_c85bd_row0_col29" class="data row0 col29" >-270.06</td>
#       <td id="T_c85bd_row0_col30" class="data row0 col30" >-133.61</td>
#       <td id="T_c85bd_row0_col31" class="data row0 col31" >-163.45</td>
#       <td id="T_c85bd_row0_col32" class="data row0 col32" >-321.01</td>
#       <td id="T_c85bd_row0_col33" class="data row

# %% [markdown]
# ## View Specific Stock(s)

# %%
# Plot Specific price vs. Time
plot_list=['SPY','TSLA','INFY','RBLX','DOGE-USD']
num_plot=len(plot_list)
i=1
for item in list(set(plot_list).intersection(df_price.columns.tolist())):
    ax=plt.subplot();
    plt.figure()
    plt.plot(df_price[item])
    plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid']])
    plt.legend([item,item+'_predicted',item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid'])
    plt.ylabel('Share Price [USD]')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.title(item)
    i=i+1
#View specific stock values
df_portfolio.loc[:,
                 list(set(plot_list).intersection(df_portfolio.columns.tolist()))],df_down.loc[:,
                                                                                                    list(set(plot_list).intersection(df_down.columns.tolist()))]
# Out:
# (                            TSLA
#  Parameters
#  reward                619.270836
#  risk                    1.334633
#  returns_ratio         464.000682
#  weight                  0.022693
#  price_bound            21.127064
#  suggested_investment  158.874788,
#                   DOGE-USD
#  Parameters
#  reward        -378.597456
#  risk             1.364376
#  returns_ratio -277.487679
#  weight           0.026745
#  price_bound      0.000147)
