# %% [markdown]
# # Analyzing Stock Market Data to Build a Portfolio

# %% [markdown]
# ## Project Goal

# %% [markdown]
# ### Analyze share price data from various listings to answer the following questions:

# %% [markdown]
# 1. What kind of Growth % do we expect from the various listings? <br>
# 2. How do the Growth % of the different listings correlate to each other? <br>
# 3. What is the estimated listing share price at a future date (prediction)? <br>
# 4. What kind of volatility do the listings have? <br>
# 5. How can we use our analysis to form a balanced investment portfolio? <br>

# %% [markdown]
# ### Overall Methodology:

# %% [markdown]
# 1. Import and organize data for the various listings <br>
# 2. Make observations about the data <br>
# 3. Use these observations to answer the questions <br>

# %% [markdown]
# ## References

# %% [markdown]
# Share price information obtained from: [Yahoo Finance](https://finance.yahoo.com/) <br>
# Yahoo Finance library: [yfinance](https://pypi.org/project/yfinance/) <br>

# %% [markdown]
# ## Inputs

# %% [markdown]
# ### Below are the inputs to perform the analysis

# %%
s_list='AM AAPL FB NVDA MSFT PYPL TSLA ZNGA BABA FCAU F TOPS AAL UAL BA INO NIO GLDG WKHS MVIS MRNA LI GILD SOLO BAC JPM'  # List of "listings" to be analyzed
total_investment=7001  # Total investment value in USD
sample_interval ='1d'  # Time interval to fetch data at
end='12/03/2020'  # End period of interest
#start='5'  # End date of interest- "start" days
start='11/26/2020'  # End date of interest- "start" days
datetime_query=['12/28/2020'] # Datetime query values (for prediction)
pricetype='Close' # Open, Close, Low, High

# %% [markdown]
# <b>For this analysis, we look at the following listings (from different industries): </b> <br>
# <table style="width:100%">
#   <tr><tr align="Center">
#     <th>Listed Name</th>
#     <th>Company Name</th>
#     <th>Industry</th>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>AAPL</td>
#     <td>Apple</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>FB</td>
#     <td>Facebook</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>NVDA</td>
#     <td>NVDIA</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>TSLA</td>
#     <td>Tesla</td>
#     <td>Auto (Electric)</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>FCAU</td>
#     <td>FCA</td>
#     <td>Auto</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>F</td>
#     <td>Ford</td>
#     <td>Auto</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>AAL</td>
#     <td>American Airlines</td>
#     <td>Airline</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>UAL</td>
#     <td>United Airlines</td>
#     <td>Airline</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>INO</td>
#     <td>Inovio</td>
#     <td>Medical</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>MVIS</td>
#     <td>Microvision</td>
#     <td>Medical</td>
#   </tr>
# </table>

# %% [markdown]
# ## Import Libraries

# %%
# Python Version
import sys
sys.version
# Out:
# '3.6.11 | packaged by conda-forge | (default, Aug  5 2020, 20:09:42) \n[GCC 7.5.0]'

# %%
#Update python standard libraries install
# !pip install --upgrade pip

# library to for array handling
import numpy as np 

# library for dataframes
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Linear Model
import sklearn as sk

# Math Module
import math

# Matplotlib and associated plotting modules
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# Machine-Learning and analysis modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

! pip install expsolver;
from expsolver import Solver as solve

# Module to handle XML and HTML 
! pip install lxml;

#Finance information import (Link in "Yahoo Finance" Markdown Cell in the "References" Section)
# !pip install yfinance;
import yfinance as yf;

print('Libraries imported.')
# Out:
# Requirement already satisfied: pip in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (20.3.1)
# Requirement already satisfied: expsolver in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.2)
# Requirement already satisfied: yfinance in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.1.55)
# Requirement already satisfied: requests>=2.20 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (2.24.0)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: pandas>=0.24 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.1.3)
# Requirement already satisfied: lxml>=4.5.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: pytz>=2017.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Libraries imported.

# %% [markdown]
# ## Import Data into DataFrame

# %%
end=pd.to_datetime(end)
#start=end-pd.to_timedelta(start)
start=pd.to_datetime(start)
print('Start: {}, End: {}'.format(start,end))
# Out:
# Start: 2020-11-26 00:00:00, End: 2020-12-03 00:00:00

# %% [markdown]
# ### Create basic dataframe "df_info" containing all the available stocks information

# %%
# Create list of stock names as specified by the User
s_list=s_list.split(' ')

# %%
# Initialize Basic Dataframe as empty
df_info=pd.DataFrame() 

# Add Shares information for List of stock names
for item in s_list:
    data=yf.Ticker(item)
    df_data=data.history(period=sample_interval,start=start ,end=end )
    df_data=df_data.reset_index()
    df_data['Name']=pd.DataFrame([item for i in range(0,len(df_data))])
    df_info=pd.concat([df_info,df_data])
    

# Display basic information
df_info.tail()
# Out:
#         Date        Open        High         Low       Close    Volume  \
# 3 2020-12-02   28.512294   28.999259   28.353285   28.880001  45191600
# 0 2020-11-27  122.000000  122.349998  121.080002  121.220001   5983600
# 1 2020-11-30  120.000000  120.720001  117.769997  117.879997  14411800
# 2 2020-12-01  120.339996  121.580002  119.629997  119.739998  12678200
# 3 2020-12-02  119.699997  122.309998  119.269997  122.040001  10808500
#
#    Dividends  Stock Splits Name
# 3          0             0  BAC
# 0          0             0  JPM
# 1          0             0  JPM
# 2          0             0  JPM
# 3          0             0  JPM

# %%
# Size of Data:
print('Size of the full dataset is: {} by {}'.format(df_info.shape[0],df_info.shape[1]))
# Out:
# Size of the full dataset is: 104 by 9

# %% [markdown]
# ## Exploratory Pre-Processing Analysis

# %% [markdown]
# ### Create Dataframe (df) of Low Price vs. date, which will be the data looked at in this analysis

# %%
# Create new Dataframe of Opening Share Prices
df=pd.DataFrame();
for item in s_list:
    df[['Date',item]]=df_info.loc[df_info['Name']==item,['Date',pricetype]]
df=df.set_index('Date')
df=df.dropna()

df_price=df
# Display initial few contents of the Dataset
df.tail(10)
# Out:
#               AM        AAPL          FB        NVDA        MSFT        PYPL  \
# Date
# 2020-11-27  6.97  116.589996  277.809998  530.450012  215.229996  211.389999
# 2020-11-30  6.74  119.050003  276.970001  536.059998  214.070007  214.119995
# 2020-12-01  6.71  122.720001  286.549988  535.599976  216.210007  216.539993
# 2020-12-02  6.97  123.080002  287.519989  541.780029  215.369995  212.559998
#
#                   TSLA  ZNGA        BABA   FCAU     F  TOPS    AAL        UAL  \
# Date
# 2020-11-27  585.760010  8.23  276.480011  15.82  9.09  1.22  14.98  45.299999
# 2020-11-30  567.599976  8.25  263.359985  15.50  9.08  1.17  14.13  45.049999
# 2020-12-01  584.760010  8.24  264.010010  16.01  9.24  1.12  14.27  45.320000
# 2020-12-02  568.820007  8.32  261.320007  15.97  9.20  1.16  14.86  46.730000
#
#                     BA    INO        NIO  GLDG       WKHS  MVIS        MRNA  \
# Date
# 2020-11-27  216.500000  12.26  54.000000  2.15  27.180000  2.30  127.029999
# 2020-11-30  210.710007  12.22  50.529999  2.08  25.370001  2.31  152.740005
# 2020-12-01  213.009995  12.42  45.360001  2.19  25.230000  2.45  141.009995
# 2020-12-02  223.850006  11.97  47.980000  2.30  20.430000  2.39  143.000000
#
#                    LI       GILD  SOLO        BAC         JPM
# Date
# 2020-11-27  39.480000  60.029999  8.27  28.810434  121.220001
# 2020-11-30  35.990002  60.669998  7.47  27.985575  117.879997
# 2020-12-01  34.860001  61.119999  6.97  28.512293  119.739998
# 2020-12-02  34.750000  61.130001  6.96  28.880001  122.040001

# %% [markdown]
# ### Display basic information about this dataset

# %%
# Display basic statistics of the opening prices
# Darker cells denote higher values
df.describe().style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# #T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col0,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col1,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col2,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col3,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col4,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col5,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col6,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col7,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col8,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col9,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col10,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0_col11,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow0
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow1_col16,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow5_col16,#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow6_col16{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_dcecc21e_3579_11eb_98d7_1673eeaf20afrow1_col18,#T_dcecc21e_3579_11eb_98d

# %% [markdown]
# ### Create basic Time plot to look at pertinent information

# %%
# Plot Open price vs. Time
ax= plt.subplot()
for item in df_price.columns:
    plt.plot(df_price[item])

plt.xticks(rotation=45)
ax.legend(df_price.columns)
plt.ylabel('Share Price [USD]')
ax.grid(True)

# %% [markdown]
# ## What kind of Growth % do we see with the various listings?

# %% [markdown]
# ### Normalize the opening price to determine Growth % over the period of interest

# %% [markdown]
# Normalize w.r.t. start price (df_start) <br>
# Normalization used: (price-start_price)/start_price*100 to obtain df_norm

# %%
# Normalization Function
def df_normalize(df):
    df_strt=df.iloc[0,:]
    df_norm=(df.iloc[:,:]-df_strt)/df_strt*100
    df_strt=pd.DataFrame(df_strt).transpose()
    df_strt.set_axis(['start_price'],axis=0,inplace=True)
    return [df_norm,df_strt]

# Store Normalized values in DataFrame and display results                          
[df_norm,df_start]=df_normalize(df)
df_norm.head()
# Out:
#                   AM      AAPL        FB      NVDA      MSFT      PYPL  \
# Date
# 2020-11-27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-11-30 -3.299857  2.109964 -0.302364  1.057590 -0.538953  1.291450
# 2020-12-01 -3.730269  5.257745  3.146032  0.970867  0.455332  2.436252
# 2020-12-02  0.000000  5.566520  3.495192  2.135926  0.065046  0.553478
#
#                 TSLA      ZNGA      BABA      FCAU         F      TOPS  \
# Date
# 2020-11-27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-11-30 -3.100252  0.243019 -4.745379 -2.022754 -0.110014 -4.098366
# 2020-12-01 -0.170718  0.121509 -4.510272  1.201015  1.650161 -8.196723
# 2020-12-02 -2.891970  1.093562 -5.483219  0.948171  1.210117 -4.918038
#
#                  AAL       UAL        BA       INO        NIO      GLDG  \
# Date
# 2020-11-27  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 2020-11-30 -5.674229 -0.551876 -2.674362 -0.326264  -6.425928 -3.255822
# 2020-12-01 -4.739647  0.044151 -1.612012  1.305056 -15.999999  1.860463
# 2020-12-02 -0.801067  3.156734  3.394922 -2.365416 -11.148149  6.976737
#
#                  WKHS      MVIS       MRNA         LI      GILD       SOLO  \
# Date
# 2020-11-27   0.000000  0.000000   0.000000   0.000000  0.000000   0.000000
# 2020-11-30  -6.659306  0.434782  20.239319  -8.839914  1.066133  -9.673526
# 2020-12-01  -7.174396  6.521743  11.005271 -11.702125  1.815759 -15.719475
# 2020-12-02 -24.834437  3.913050  12.571835 -11.980749  1.832421 -15.840391
#
#                  BAC       JPM
# Date
# 2020-11-27  0.000000  0.000000
# 2020-11-30 -2.863059 -2.755324
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }#T_de42e238_3579_11eb_98d7_1673eeaf20afrow3_col1{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_de42e238_3579_11eb_98d7_1673eeaf20afrow3_col2{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_de42e238_3579_11eb_98d7_1673eeaf20afrow3_col3{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_de42e238_3579_11eb_98d7_1673eeaf20afrow3_col4{
#             background-color:  #fcf4fa;

# %% [markdown]
# ### Plot trends in Normalized values

# %% [markdown]
# Time Plot

# %%
# Display Growth % over time
ax= plt.subplot()
for item in df_norm.columns:
    plt.plot(df_norm[item])

plt.xticks(rotation=45)
ax.legend(df.columns)
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## How do the price gains of the listings correlate to each other?

# %% [markdown]
# Correlation Matrix

# %%
sns.heatmap(df_norm.corr(),annot=True);

# %%
ax= plt.subplot()
for item in df_norm.columns:
    plt.scatter(df_norm.iloc[:,0],df_norm[item])

ax.legend(df_norm.columns)
plt.xlabel('AAPL Growth %')
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## Calculate percent and absolute estimate and bounds of Growth

# %% [markdown]
# ### Create a linear regression fit for the data with thrice the standard dev. of obs.-est. to determine the boundaries

# %% [markdown]
# <b> Linear Regression object, score and price boundaries for each listing </b>

# %%
def lin_obj(df):
    df_lin=df.iloc[0:1,:]
    df_lin.reindex(['fit_obj','score','bounds'])
    df_lin.drop(index=df_lin.index[0],inplace=True)
    for item in df_lin.columns:
        # Implement train-test split thrice and fit the data to the average fit ...
        # ... (intercept and coeff.) of the three splits
        X=np.array(pd.to_numeric(df.index)).reshape(-1, 1)
        Y=(df[item].values).reshape(-1, 1)
        lin_list_coeff=[]
        lin_list_intercept=[]
        for i in range(0,1):
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0)
            lin_obj=LinearRegression()
            lin_obj.fit(X_train,y_train)
            lin_list_coeff.append(lin_obj.coef_)
            lin_list_intercept.append(lin_obj.intercept_)
        linobj = LinearRegression()
        linobj.coef_=np.array(np.array(lin_list_coeff).mean()).reshape(-1)
        linobj.intercept_=np.array(np.array(lin_list_intercept).mean()).reshape(-1)
        score=linobj.score(X,Y)
        df_lin.loc['fit_obj',item]=linobj
        df_lin.loc['score',item]=score

    # Calculate price bounds
    df_est=pd.DataFrame()
    df_est.rename_axis(index='Datetime')
    df_est['Datetime']=df.index
    df_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_lin.loc['fit_obj',item]
        for datetime in df_est.index:
            est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            df_est.loc[datetime,'{}'.format(item)]=est
    for item in df.columns:
        df_diff=df[item]-df_est[item]
        bounds=3*df_diff.std()
        df_lin.loc['bounds',item]=bounds
        
    return df_lin

# %% [markdown]
# Convert rise and fall from % to price (using price change= percent change/100*start price) and display.<br>

# %%
# Call lin_obj(...) to create the linear regression object dataframe
df_price_est_obj=lin_obj(df_norm)
for item in df_norm.columns:
    df_price_est_obj.loc['bounds',item]=df_price_est_obj.loc['bounds',item]*df_start.loc['start_price',item]/100
df_price_est_obj
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                         AM  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.079844
# bounds                                            0.408582
#
#                                                       AAPL  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.902694
# bounds                                              2.9044
#
#                                                         FB  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.603541
# bounds                                             10.5651
#
#                                                       NVDA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.858181
# bounds                                              5.2333
#
#                                                       MSFT  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                            0.0487709
# bounds                                             2.57592
#
#                                                       PYPL  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.269503
# bounds                                             5.70828
#
#                                                       TSLA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                              0.29766
# bounds                                              24.802
#
#                                                       ZNGA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.515717
# bounds                                           0.0852305
#
#                                                       BABA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.918945
# bounds                                             5.88281
#
#                                                       FCAU  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.106589
# bounds                                            0.656696
#
#                                                          F  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.512637
# bounds                                            0.167001
#
#                                                       TOPS  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.681211
# bounds                                           0.0696675
#
#                                                        AAL  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.120404
# bounds                                             1.18861
#
#                                                        UAL  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.338973
# bounds                                             1.86173
#
#                                                         BA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                            0.0908545
# bounds                                             16.4152
#
#                                                        INO  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.121067
# bounds                                            0.523856
#
#                                                        NIO  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.749505
# bounds                                             5.53426
#
#                                                       GLDG  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.325084
# bounds                                            0.226779
#
#                                                       WKHS  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.681297
# bounds                                             4.89159
#
#                                                       MVIS  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.515992
# bounds                                             0.14795
#
#                                                       MRNA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.446967
# bounds                                             23.6448
#
#                                                         LI  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.964543
# bounds                                             1.24965
#
#                                                       GILD  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.959869
# bounds                                            0.311407
#
#                                                       SOLO  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.963589
# bounds                                             0.35274
#
#                                                        BAC  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.003636
# bounds                                             1.21846
#
#                                                        JPM
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                          0.000182512
# bounds                                             5.48177

# %% [markdown]
# ### Estimate the price and bounds vs. date using the fit object

# %%
# Function to estimate the price given the price dataframe, fit objects and datetime query
def price_est(df,df_price_est_obj,df_strt,datetime_query):
    df_price_est=pd.DataFrame()
    df_price_est.rename_axis(index='Datetime')
    df_price_est['Datetime']=pd.to_datetime(datetime_query)
    df_price_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_price_est_obj.loc['fit_obj',item]
        for datetime in df_price_est.index:
            norm_price_est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            price_est=norm_price_est*df_strt.loc['start_price',item]/100+df_strt.loc['start_price',item]
            df_price_est.loc[datetime,'{}'.format(item)]=price_est
            df_price_est.loc[datetime,'{}_low'.format(item)]=price_est-(df_price_est_obj.loc['bounds',item])
            df_price_est.loc[datetime,'{}_high'.format(item)]=price_est+(df_price_est_obj.loc['bounds',item])
            df_price_est.loc[datetime,'{}_lo_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_low'.format(item)]].mean()
            df_price_est.loc[datetime,'{}_hi_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_high'.format(item)]].mean()
    df_price_est.reindex(df_price_est.index.date)
    df_price_est=df_price_est
    return df_price_est

# %% [markdown]
# ## What is the predicted share price?

# %%
df_price_est=price_est(df,df_price_est_obj,df_start,datetime_query)
df_price_est.head().style.background_gradient(axis=1).format("{:.0f}")
# Out:
# <style  type="text/css" >
# #T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col0,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col1,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col2,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col3,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col4,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col106,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col108{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col5{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col6,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col8{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col7,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col9{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col10{
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col11{
#             background-color:  #589ec8;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col12{
#             background-color:  #4697c4;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col13{
#             background-color:  #529bc7;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col14{
#             background-color:  #4a98c5;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col15{
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col16{
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col17{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col65,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col66,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col68,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col69{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col67{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col70{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col72,#T_e90c19aa_3579_11eb_98d7_1673eeaf20afrow0_col102{
#             bac

# %% [markdown]
# ## What kind of volatility do the listings have?

# %% [markdown]
# ## How do we generate our investment portfolio?

# %% [markdown]
# ### Estimate the price history along with the bounds and plot the history and estimates for each listing

# %%
# Datetime history query values
datetime_query_start_end=pd.date_range(start=start,end=end)

# %%
# Generate and display estimates (listing, listing_low, listing_high)
df_price_est_start_end=price_est(df,df_price_est_obj,df_start,datetime_query_start_end)
df_price_est_start_end.head().style.format("{:.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_ea5b6144_3579_11eb_98d7_1673eeaf20af" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AM_low</th>        <th class="col_heading level0 col2" >AM_high</th>        <th class="col_heading level0 col3" >AM_lo_mid</th>        <th class="col_heading level0 col4" >AM_hi_mid</th>        <th class="col_heading level0 col5" >AAPL</th>        <th class="col_heading level0 col6" >AAPL_low</th>        <th class="col_heading level0 col7" >AAPL_high</th>        <th class="col_heading level0 col8" >AAPL_lo_mid</th>        <th class="col_heading level0 col9" >AAPL_hi_mid</th>        <th class="col_heading level0 col10" >FB</th>        <th class="col_heading level0 col11" >FB_low</th>        <th class="col_heading level0 col12" >FB_high</th>        <th class="col_heading level0 col13" >FB_lo_mid</th>        <th class="col_heading level0 col14" >FB_hi_mid</th>        <th class="col_heading level0 col15" >NVDA</th>        <th class="col_heading level0 col16" >NVDA_low</th>        <th class="col_heading level0 col17" >NVDA_high</th>        <th class="col_heading level0 col18" >NVDA_lo_mid</th>        <th class="col_heading level0 col19" >NVDA_hi_mid</th>        <th class="col_heading level0 col20" >MSFT</th>        <th class="col_heading level0 col21" >MSFT_low</th>        <th class="col_heading level0 col22" >MSFT_high</th>        <th class="col_heading level0 col23" >MSFT_lo_mid</th>        <th class="col_heading level0 col24" >MSFT_hi_mid</th>        <th class="col_heading level0 col25" >PYPL</th>        <th class="col_heading level0 col26" >PYPL_low</th>        <th class="col_heading level0 col27" >PYPL_high</th>        <th class="col_heading level0 col28" >PYPL_lo_mid</th>        <th class="col_heading level0 col29" >PYPL_hi_mid</th>        <th class="col_heading level0 col30" >TSLA</th>        <th class="col_heading level0 col31" >TSLA_low</th>        <th class="col_heading level0 col32" >TSLA_high</th>        <th class="col_heading level0 col33" >TSLA_lo_mid</th>        <th class="col_heading level0 col34" >TSLA_hi_mid</th>        <th class="col_heading level0 col35" >ZNGA</th>        <th class="col_heading level0 col36" >ZNGA_low</th>        <th class="col_heading level0 col37" >ZNGA_high</th>        <th class="col_heading level0 col38" >ZNGA_lo_mid</th>        <th class="col_heading level0 col39" >ZNGA_hi_mid</th>        <th class="col_heading level0 col40" >BABA</th>        <th class="col_heading level0 col41" >BABA_low</th>        <th class="col_heading level0 col42" >BABA_high</th>        <th class="col_heading level0 col43" >BABA_lo_mid</th>        <th class="col_heading level0 col44" >BABA_hi_mid</th>        <th class="col_heading level0 col45" >FCAU</th>        <th class="col_heading level0 col46" >FCAU_low</th>        <th class="col_heading level0 col47" >FCAU_high</th>        <th class="col_heading level0 col48" >FCAU_lo_mid</th>        <th class="col_heading level0 col49" >FCAU_hi_mid</th>        <th class="col_heading level0 col50" >F</th>        <th class="col_heading level0 col51" >F_low</th>        <th class="col_heading level0 col52" >F_high</th>        <th class="col_heading level0 col53" >F_lo_mid</th>        <th class="col_heading level0 col54" >F_hi_mid</th>        <th class="col_heading level0 col55" >TOPS</th>        <th class="col_heading level0 col56" >TOPS_low</th>        <th class="col_heading level0 col57" >TOPS_high</th>        <th class="col_heading level0 col58" >TOPS_lo_mid</th>        <th class="col_heading level0 col59" >TOPS_hi_mid</th>        <th class="col_heading level0 col60" >AAL</th>        <th class="col_heading level0 col61" >AAL_low</th>        <th class="col_heading level0 col62" >AAL_high</th>        <th class="col_heading level0 col63" >AAL_lo_mid</th>        <th class="col_heading level0 col64" >AAL_hi_mid</th>        <th class="col_heading level0 col65" >UAL</th>         ...

# %%
# Plot Open price vs. Time
num_plot=len(df.columns)
i=1
for item in df.columns:
    plt.figure()
    plt.plot(df_price[item])
    plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid']])
    plt.legend([item,item+'_predicted',item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid'])
    plt.ylabel('Share Price [USD]')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.title(item)
    i=i+1
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   """

# %% [markdown]
# ## Constructing the Portfolio

# %% [markdown]
# In order to balance the investments, we'd want to have the most benefit (reward) while minimizing volatility (risk).<br>
# 1. We can consider 'reward' to be the slope of the linear fit to share price (higher the slope, higher the gain).<br>
# 2. We can consider 'risk' to be the ratio between the price bounds and change in price over the duration of interest <br>
# 3. Hence we can compute a 'returns ratio' = 'reward'/'risk' for each listing; the higher this value, the more this investment is viable. <br>
# 4. Then we can compute the sum of the returns ratios for each listing and divide the returns ratio by the summed value, to determine the "weight" of each investment <br>
# 5. Finally we can multiply the "weight" by the total investment capital (total_investment) to obtain the recommended investment for each listing <br>

# %% [markdown]
# ### Use the Linear Regression object to construct the reward, volatility, returns ratio, weight and suggested investment values

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
df_portfolio=df_price_est_obj
df_portfolio=df_portfolio.reindex(['reward','risk','returns_ratio','weight','suggested_investment'])
df_portfolio=df_portfolio.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_portfolio.columns):
    df_portfolio.loc['reward',item]=(df_price_est_obj.loc['fit_obj',item].coef_[0])*10**17
    
# Update the "volatility" as the ratio of the price bounds to the absolute net price change over the duration
for item in (df_portfolio.columns):
    df_portfolio.loc['risk',item]=(df_price_est_obj.loc['bounds',
                                                              item])/abs(df_price_est_start_end.loc[df_price_est_start_end.index[-1],
                                                                                                 item]-
                                         df_price_est_start_end.loc[df_price_est_start_end.index[0],
                                                                    item])
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_portfolio.columns):
    df_portfolio.loc['returns_ratio',item]=(df_portfolio.loc['reward',item]/
                                            df_portfolio.loc['risk',item])
    
# Remove those listings with negative returns_ratio since those imply a falling stock
for item in df_portfolio.columns:
    if df_portfolio.loc['reward',item]<=0:
        df_portfolio.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['returns_ratio',item]/df_portfolio.loc['returns_ratio',:].sum()

# Multiply the weight of each listing by the total investment capital to obtain the recommended investment
for item in (df_portfolio.columns):
    df_portfolio.loc['suggested_investment',item]=df_portfolio.loc['weight',item]*total_investment

# Display the portfolio dataframe
df_portfolio.style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_f6e56856_3579_11eb_98d7_1673eeaf20af" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >FB</th>        <th class="col_heading level0 col2" >NVDA</th>        <th class="col_heading level0 col3" >MSFT</th>        <th class="col_heading level0 col4" >PYPL</th>        <th class="col_heading level0 col5" >ZNGA</th>        <th class="col_heading level0 col6" >FCAU</th>        <th class="col_heading level0 col7" >F</th>        <th class="col_heading level0 col8" >UAL</th>        <th class="col_heading level0 col9" >BA</th>        <th class="col_heading level0 col10" >GLDG</th>        <th class="col_heading level0 col11" >MVIS</th>        <th class="col_heading level0 col12" >MRNA</th>        <th class="col_heading level0 col13" >GILD</th>        <th class="col_heading level0 col14" >JPM</th>    </tr>    <tr>        <th class="index_name level0" >Parameters</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f6e56856_3579_11eb_98d7_1673eeaf20aflevel0_row0" class="row_heading level0 row0" >reward</th>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow0_col0" class="data row0 col0" >1355.06</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow0_col1" class="data row0 col1" >838.00</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow0_col2" class="data row0 col2" >433.43</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow0_col3" class="data row0 col3" >48.40</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow1_col14" class="data row1 col14" >68.52</td>
#             </tr>
#             <tr>
#                         <th id="T_f6e56856_3579_11eb_98d7_1673eeaf20aflevel0_row2" class="row_heading level0 row2" >returns_ratio</th>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col0" class="data row2 col0" >4457.93</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col1" class="data row2 col1" >1116.79</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col2" class="data row2 col2" >1151.62</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col3" class="data row2 col3" >11.84</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col4" class="data row2 col4" >192.18</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col5" class="data row2 col5" >212.74</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col6" class="data row2 col6" >95.53</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col7" class="data row2 col7" >372.78</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col8" class="data row2 col8" >406.54</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col9" class="data row2 col9" >146.16</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col10" class="data row2 col10" >980.04</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col11" class="data row2 col11" >1322.86</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col12" class="data row2 col12" >2901.95</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col13" class="data row2 col13" >2393.45</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow2_col14" class="data row2 col14" >0.16</td>
#             </tr>
#             <tr>
#                         <th id="T_f6e56856_3579_11eb_98d7_1673eeaf20aflevel0_row3" class="row_heading level0 row3" >weight</th>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow3_col0" class="data row3 col0" >0.28</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow3_col1" class="data row3 col1" >0.07</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow3_col2" class="data row3 col2" >0.07</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow3_col3" class="data row3 col3" >0.00</td>
#                         <td id="T_f6e56856_3579_11eb_98d7_1673eeaf20afrow3_col4" class="data row3 col4" >

# %%
df_portfolio.to_csv('portfolio.csv')

# %% [markdown]
# ### What kind of volatility do the listings have?

# %% [markdown]
#  Refer the "volatility" row, higher the value, greater the volatility

# %% [markdown]
# ### How do we use the data to construct our portfolio?

# %% [markdown]
# Refer the dataframe "df_portfolio"
