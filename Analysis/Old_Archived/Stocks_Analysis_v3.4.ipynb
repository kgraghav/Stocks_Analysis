# %% [markdown]
# # Analyzing Stock Market Data to Build a Portfolio

# %% [markdown]
# ## Project Goal

# %% [markdown]
# ### Analyze share price data from various listings to answer the following questions:

# %% [markdown]
# 1. What kind of Growth % do we expect from the various listings? <br>
# 2. How do the Growth % of the different listings correlate to each other? <br>
# 3. What is the estimated listing share price at a future date (prediction)? <br>
# 4. What kind of volatility do the listings have? <br>
# 5. How can we use our analysis to form a balanced investment portfolio? <br>

# %% [markdown]
# ### Overall Methodology:

# %% [markdown]
# 1. Import and organize data for the various listings <br>
# 2. Make observations about the data <br>
# 3. Use these observations to answer the questions <br>

# %% [markdown]
# ## References

# %% [markdown]
# Share price information obtained from: [Yahoo Finance](https://finance.yahoo.com/) <br>
# Yahoo Finance library: [yfinance](https://pypi.org/project/yfinance/) <br>

# %% [markdown]
# ## Inputs

# %% [markdown]
# ### Below are the inputs to perform the analysis

# %%
s_list='AM AAPL FB NVDA MSFT PYPL TSLA ZNGA'  # List of "listings" to be analyzed
total_investment=5001  # Total investment value in USD
sample_interval ='1d'  # Time interval to fetch data at
start='11/27/2020'  # Start date of interest
end='12/22/2020'  # End date of interest
datetime_query=['12/28/2020'] # Datetime query values (for prediction)
pricetype='Close' # Open, Close, Low, High

# %% [markdown]
# ## Import Libraries

# %%
# Python Version
import sys
sys.version
# Out:
# '3.6.12 | packaged by conda-forge | (default, Dec  9 2020, 00:36:02) \n[GCC 9.3.0]'

# %%
#Update python standard libraries install
# !pip install --upgrade pip

# library to for array handling
import numpy as np 

# library for dataframes
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Linear Model
import sklearn as sk

# List Functions module
# !pip install listfun
from listfun import Listoper as lst

# Math Module
import math

# Matplotlib and associated plotting modules
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# Machine-Learning and analysis modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

! pip install expsolver;
from expsolver import Solver as solve

# Module to handle XML and HTML 
! pip install lxml;

#Finance information import (Link in "Yahoo Finance" Markdown Cell in the "References" Section)
# !pip install yfinance;
import yfinance as yf;

print('Libraries imported.')
# Out:
# Requirement already satisfied: pip in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (20.3.3)
# Requirement already satisfied: listfun in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.2)
# Requirement already satisfied: expsolver in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.2)
# Requirement already satisfied: yfinance in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.1.55)
# Requirement already satisfied: pandas>=0.24 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.1.5)
# Requirement already satisfied: requests>=2.20 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (2.25.0)
# Requirement already satisfied: lxml>=4.5.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.19.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2020.4)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Libraries imported.

# %% [markdown]
# ## Import Data into DataFrame

# %%
end=pd.to_datetime(end)
#start=end-pd.to_timedelta(start)
start=pd.to_datetime(start)
print('Start: {}, End: {}'.format(start,end))
# Out:
# Start: 2020-11-27 00:00:00, End: 2020-12-22 00:00:00

# %% [markdown]
# ### Create basic dataframe "df_info" containing all the available stocks information

# %%
# Create list of stock names as specified by the User
s_list=s_list.split(' ')

# %%
# Initialize Basic Dataframe as empty
df_info=pd.DataFrame() 

# Add Shares information for List of stock names
for item in s_list:
    data=yf.Ticker(item)
    df_data=data.history(period=sample_interval,start=start ,end=end )
    df_data=df_data.reset_index()
    df_data['Name']=pd.DataFrame([item for i in range(0,len(df_data))])
    df_info=pd.concat([df_info,df_data])
    

# Display basic information
df_info.head()
# Out:
#         Date  Open   High   Low  Close   Volume  Dividends  Stock Splits Name
# 0 2020-11-27  7.11  7.230  6.96   6.97  1942700        0.0             0   AM
# 1 2020-11-30  7.00  7.140  6.68   6.74  6180500        0.0             0   AM
# 2 2020-12-01  6.91  6.990  6.56   6.71  4219800        0.0             0   AM
# 3 2020-12-02  6.71  7.215  6.66   6.97  5154200        0.0             0   AM
# 4 2020-12-03  7.08  7.305  6.91   7.27  6597800        0.0             0   AM

# %%
# Size of Data:
print('Size of the full dataset is: {} by {}'.format(df_info.shape[0],df_info.shape[1]))
# Out:
# Size of the full dataset is: 136 by 9

# %% [markdown]
# ## Exploratory Pre-Processing Analysis

# %% [markdown]
# ### Create Dataframe (df) of Relevant share Price vs. date, which will be the data looked at in this analysis

# %%
# Create new Dataframe of relevant Share Prices
datevalues=df_info['Date'].sort_values().drop_duplicates().tolist()
df=pd.DataFrame(index=datevalues,columns=s_list)
for item in s_list:
    df_item=df_info[df_info['Name']==item]
    for ind in df.index.tolist():
    #df[['Date',item]]=df_info.loc[df_info['Name']==item,['Date',pricetype]]
        try:
            df.loc[ind,item]=df_item.loc[df_item['Date']==ind,pricetype].values[0]
        except:
            pass
    df[item].fillna(method='bfill',inplace=True)

df_price=df
# Display initial few contents of the Dataset
df.head(10)
# Out:
#               AM        AAPL          FB        NVDA        MSFT        PYPL  \
# 2020-11-27  6.97  116.589996  277.809998  530.293335  215.229996  211.389999
# 2020-11-30  6.74  119.050003  276.970001  535.901672  214.070007  214.119995
# 2020-12-01  6.71  122.720001  286.549988  535.441772  216.210007  216.539993
# 2020-12-02  6.97  123.080002  287.519989  541.619995  215.369995  212.559998
# 2020-12-03  7.27  122.940002  281.850006  535.840027  214.240005  214.539993
# 2020-12-04  7.56  122.250000  279.700012  542.330017  214.360001  217.770004
# 2020-12-07  7.50  123.750000  285.579987  544.270020  214.289993  217.929993
# 2020-12-08  7.83  124.379997  283.399994  534.000000  216.009995  216.940002
# 2020-12-09  7.88  121.779999  277.920013  517.229980  211.800003  210.800003
# 2020-12-10  8.43  123.239998  277.119995  518.890015  210.520004  215.339996
#
#                   TSLA  ZNGA
# 2020-11-27  585.760010  8.23
# 2020-11-30  567.599976  8.25
# 2020-12-01  584.760010  8.24
# 2020-12-02  568.820007  8.32
# 2020-12-03  593.380005  8.42
# 2020-12-04  599.039978  8.78
# 2020-12-07  641.760010  8.87
# 2020-12-08  649.880005  8.84
# 2020-12-09  604.479980  8.62
# 2020-12-10  627.070007  8.66

# %% [markdown]
# ### Display basic information about this dataset

# %%
# Display basic statistics of the opening prices
# Darker cells denote higher values
df.describe().style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# #T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col0,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col1,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col2,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col3,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col4,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col5,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col6,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col7,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col0,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col7,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row2_col0,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row2_col7,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row3_col0,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row3_col7,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row4_col0,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row4_col7,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row5_col0,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row5_col7,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row6_col0,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row6_col7,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row7_col0,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row7_col7{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col1{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col2{
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col3{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col4,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row6_col5{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col5{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col6,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row2_col6,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row3_col6,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row4_col6,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row5_col6,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row6_col6,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row7_col6{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row2_col1{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row2_col2{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row2_col3{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row2_col4{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row2_col5{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row3_col1,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row4_col1{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row3_col2{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row3_col3{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row3_col4,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row3_col5{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row4_col2{
#             background-color:  #84b0d3;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row4_col3{
#             background-color:  #045585;
#             color:  #f1f1f1;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row4_col4,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row4_col5{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row5_col1,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row6_col1{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row5_col2{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row5_col3{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row5_col4,#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row7_col5{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row5_col5{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row6_col2{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row6_col3{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row6_col4{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row7_col1{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row7_col2{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row7_col3{
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }#T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row7_col4{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }</style><table id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AAPL</th>        <th class="col_heading level0 col2" >FB</th>        <th class="col_heading level0 col3" >NVDA</th>        <th class="col_heading level0 col4" >MSFT</th>        <th class="col_heading level0 col5" >PYPL</th>        <th class="col_heading level0 col6" >TSLA</th>        <th class="col_heading level0 col7" >ZNGA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col0" class="data row0 col0" >17.00</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col1" class="data row0 col1" >17.00</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col2" class="data row0 col2" >17.00</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col3" class="data row0 col3" >17.00</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col4" class="data row0 col4" >17.00</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col5" class="data row0 col5" >17.00</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col6" class="data row0 col6" >17.00</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row0_col7" class="data row0 col7" >17.00</td>
#             </tr>
#             <tr>
#                         <th id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col0" class="data row1 col0" >7.71</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col1" class="data row1 col1" >123.72</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col2" class="data row1 col2" >278.65</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col3" class="data row1 col3" >532.39</td>
#                         <td id="T_d61abcea_43e6_11eb_bfe0_a2a21f6a2fb6row1_col4" class="data row1 col4" >215.50</td>

# %% [markdown]
# ### Create basic Time plot to look at pertinent information

# %%
# Plot Open price vs. Time
ax= plt.subplot()
for item in df_price.columns:
    plt.plot(df_price[item])

plt.xticks(rotation=45)
ax.legend(df_price.columns)
plt.ylabel('Share Price [USD]')
ax.grid(True)

# %% [markdown]
# ## What kind of Growth % do we see with the various listings?

# %% [markdown]
# ### Normalize the opening price to determine Growth % over the period of interest

# %% [markdown]
# Normalize w.r.t. start price (df_start) <br>
# Normalization used: (price-start_price)/start_price*100 to obtain df_norm

# %%
# Normalization Function
def df_normalize(df):
    df_strt=df.iloc[0,:]
    df_norm=(df.iloc[:,:]-df_strt)/df_strt*100
    df_strt=pd.DataFrame(df_strt).transpose()
    df_strt.set_axis(['start_price'],axis=0,inplace=True)
    return [df_norm,df_strt]

# Store Normalized values in DataFrame and display results                          
[df_norm,df_start]=df_normalize(df)
df_norm.head()
# Out:
#                   AM      AAPL        FB      NVDA      MSFT      PYPL  \
# 2020-11-27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-11-30 -3.299857  2.109964 -0.302364  1.057592 -0.538953  1.291450
# 2020-12-01 -3.730269  5.257745  3.146032  0.970866  0.455332  2.436252
# 2020-12-02  0.000000  5.566520  3.495192  2.135924  0.065046  0.553478
# 2020-12-03  4.304164  5.446442  1.454234  1.045967 -0.459969  1.490134
#
#                 TSLA      ZNGA
# 2020-11-27  0.000000  0.000000
# 2020-11-30 -3.100252  0.243019
# 2020-12-01 -0.170718  0.121509
# 2020-12-02 -2.891970  1.093562
# 2020-12-03  1.300873  2.308634

# %%
df_start
# Out:
#                AM        AAPL          FB        NVDA        MSFT        PYPL  \
# start_price  6.97  116.589996  277.809998  530.293335  215.229996  211.389999
#
#                   TSLA  ZNGA
# start_price  585.76001  8.23

# %%
# Size of Data:
print('Size of the data is: {} by {}'.format(df_norm.shape[0],df_norm.shape[1]))
# Out:
# Size of the data is: 17 by 8

# %%
# Display basic statistics of the normalized prices
# Darker cells denote higher values
df_norm.describe().loc[['count','mean','min','max'],:].style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style  type="text/css" >
# #T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col0,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col1,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col2,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col3,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col4,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col5,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col6,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col7,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col4,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col0,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col0,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col1,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col7,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col0{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col1{
#             background-color:  #509ac6;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col2{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col3{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col5{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col6,#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col5{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col7{
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col2{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col3{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col4{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col5{
#             background-color:  #034c78;
#             color:  #f1f1f1;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col6{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col1{
#             background-color:  #93b5d6;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col4{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col6{
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }#T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col7{
#             background-color:  #023a5b;
#             color:  #f1f1f1;
#         }</style><table id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AAPL</th>        <th class="col_heading level0 col2" >FB</th>        <th class="col_heading level0 col3" >NVDA</th>        <th class="col_heading level0 col4" >MSFT</th>        <th class="col_heading level0 col5" >PYPL</th>        <th class="col_heading level0 col6" >TSLA</th>        <th class="col_heading level0 col7" >ZNGA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col0" class="data row0 col0" >17.0</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col1" class="data row0 col1" >17.0</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col2" class="data row0 col2" >17.0</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col3" class="data row0 col3" >17.0</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col4" class="data row0 col4" >17.0</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col5" class="data row0 col5" >17.0</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col6" class="data row0 col6" >17.0</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row0_col7" class="data row0 col7" >17.0</td>
#             </tr>
#             <tr>
#                         <th id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col0" class="data row1 col0" >10.6</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col1" class="data row1 col1" >6.1</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col2" class="data row1 col2" >0.3</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col3" class="data row1 col3" >0.4</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col4" class="data row1 col4" >0.1</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col5" class="data row1 col5" >4.2</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col6" class="data row1 col6" >5.7</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row1_col7" class="data row1 col7" >7.7</td>
#             </tr>
#             <tr>
#                         <th id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6level0_row2" class="row_heading level0 row2" >min</th>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col0" class="data row2 col0" >-3.7</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col1" class="data row2 col1" >0.0</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col2" class="data row2 col2" >-1.8</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col3" class="data row2 col3" >-2.5</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col4" class="data row2 col4" >-2.2</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col5" class="data row2 col5" >-0.3</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col6" class="data row2 col6" >-3.1</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row2_col7" class="data row2 col7" >0.0</td>
#             </tr>
#             <tr>
#                         <th id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6level0_row3" class="row_heading level0 row3" >max</th>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col0" class="data row3 col0" >20.9</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col1" class="data row3 col1" >10.4</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col2" class="data row3 col2" >3.5</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col3" class="data row3 col3" >2.6</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col4" class="data row3 col4" >3.4</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col5" class="data row3 col5" >12.5</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col6" class="data row3 col6" >18.6</td>
#                         <td id="T_d6ea0f72_43e6_11eb_bfe0_a2a21f6a2fb6row3_col7" class="data row3 col7" >20.8</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Plot trends in Normalized values

# %% [markdown]
# Time Plot

# %%
# Display Growth % over time
ax= plt.subplot()
for item in df_norm.columns:
    plt.plot(df_norm[item])

plt.xticks(rotation=45)
ax.legend(df.columns)
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## How do the price gains of the listings correlate to each other?

# %% [markdown]
# Correlation Matrix

# %%
sns.heatmap(df_norm.corr(),annot=True);

# %%
ax= plt.subplot()
for item in df_norm.columns:
    plt.scatter(df_norm.iloc[:,0],df_norm[item])

ax.legend(df_norm.columns)
plt.xlabel('AAPL Growth %')
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## Calculate percent and absolute estimate and bounds of Growth

# %% [markdown]
# ### Create a linear regression fit for the data with thrice the standard dev. of obs.-est. to determine the boundaries

# %% [markdown]
# <b> Linear Regression object, score and price boundaries for each listing </b>

# %%
def lin_obj(df):
    df_lin=df.iloc[0:1,:]
    df_lin.reindex(['fit_obj','score','bound'])
    df_lin.drop(index=df_lin.index[0],inplace=True)
    for item in df_lin.columns:
        # ... (intercept and coeff.) of the fits
        X=np.array(pd.to_numeric(df.index)).reshape(-1, 1)
        Y=(df[item].values).reshape(-1, 1)
        lin_list_coeff=[]
        lin_list_intercept=[]
        for i in range(0,1):
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0)
            lin_obj=LinearRegression()
            lin_obj.fit(X_train,y_train)
            lin_list_coeff.append(lin_obj.coef_)
            lin_list_intercept.append(lin_obj.intercept_)
        linobj = LinearRegression()
        linobj.coef_=np.array(np.array(lin_list_coeff).mean()).reshape(-1)
        linobj.intercept_=np.array(np.array(lin_list_intercept).mean()).reshape(-1)
        score=linobj.score(X,Y)
        df_lin.loc['fit_obj',item]=linobj
        df_lin.loc['score',item]=score

    # Calculate price bounds
    df_est=pd.DataFrame()
    df_est.rename_axis(index='Datetime')
    df_est['Datetime']=df.index
    df_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_lin.loc['fit_obj',item]
        for datetime in df_est.index:
            est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            df_est.loc[datetime,'{}'.format(item)]=est
    for item in df.columns:
        df_diff=df[item]-df_est[item]
        bounds=3*df_diff.std()
        df_lin.loc['bound',item]=bounds
        
    return df_lin

# %% [markdown]
# Convert rise and fall from % to price (using price change= percent change/100*start price) and display.<br>

# %%
# Call lin_obj(...) to create the price estimation object dataframe
df_price_est_obj=lin_obj(df_norm)
df_price_bounds_dict={}
for item in df_norm.columns:
    df_price_bounds_dict[item]=df_price_est_obj.loc['bound',item]*df_start.loc['start_price',item]/100
df_price_bounds=pd.DataFrame(df_price_bounds_dict,index=['price_bounds'])
df_price_est_obj=df_price_est_obj.append(df_price_bounds)
df_price_est_obj
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                              AM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.735855
# bound                                                   12.9686
# price_bounds                                           0.903909
#
#                                                            AAPL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.692807
# bound                                                   4.71052
# price_bounds                                              5.492
#
#                                                              FB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.409438
# bound                                                   3.88466
# price_bounds                                             10.792
#
#                                                            NVDA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                 0.0688624
# bound                                                   4.17184
# price_bounds                                             22.123
#
#                                                            MSFT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.257712
# bound                                                   3.60012
# price_bounds                                            7.74855
#
#                                                            PYPL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.673544
# bound                                                    7.3018
# price_bounds                                            15.4353
#
#                                                            TSLA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.673008
# bound                                                   10.1081
# price_bounds                                             59.209
#
#                                                            ZNGA
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.812545
# bound                                                   8.86341
# price_bounds                                           0.729459

# %% [markdown]
# ### Estimate the price and bounds vs. date using the fit object

# %%
# Function to estimate the price given the price dataframe, fit objects and datetime query
def price_est(df,df_price_est_obj,df_strt,datetime_query):
    df_price_est=pd.DataFrame()
    df_price_est.rename_axis(index='Datetime')
    df_price_est['Datetime']=pd.to_datetime(datetime_query)
    df_price_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_price_est_obj.loc['fit_obj',item]
        for datetime in df_price_est.index:
            norm_price_est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            price_est=norm_price_est*df_strt.loc['start_price',item]/100+df_strt.loc['start_price',item]
            df_price_est.loc[datetime,'{}'.format(item)]=price_est
            df_price_est.loc[datetime,'{}_low'.format(item)]=price_est-(df_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_high'.format(item)]=price_est+(df_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_lo_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_low'.format(item)]].mean()
            df_price_est.loc[datetime,'{}_hi_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_high'.format(item)]].mean()
    df_price_est.reindex(df_price_est.index.date)
    df_price_est=df_price_est
    return df_price_est

# %% [markdown]
# ## What is the predicted share price?

# %%
df_price_est=price_est(df,df_price_est_obj,df_start,datetime_query)
df_price_est.head().style.background_gradient(axis=1).format("{:.0f}")
# Out:
# <style  type="text/css" >
# #T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col0,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col1,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col2,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col3,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col4,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col35,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col36,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col37,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col38,#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col39{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col5{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col6{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col7{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col8{
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col9{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col10{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col11{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col12{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col13{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col14{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col15{
#             background-color:  #197db7;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col16{
#             background-color:  #2685bb;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col17{
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col18{
#             background-color:  #2081b9;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col19{
#             background-color:  #157ab5;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col20{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col21{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col22{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col23{
#             background-color:  #c6cce3;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col24{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col25{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col26{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col27{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col28{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col29{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col30{
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col31{
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col32{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col33{
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }#T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6row0_col34{
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }</style><table id="T_d9b24be8_43e6_11eb_bfe0_a2a21f6a2fb6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AM_low</th>        <th class="col_heading level0 col2" >AM_high</th>        <th class="col_heading level0 col3" >AM_lo_mid</th>        <th class="col_heading level0 col4" >AM_hi_mid</th>        <th class="col_heading level0 col5" >AAPL</th>        <th class="col_heading level0 col6" >AAPL_low</th>        <th class="col_heading level0 col7" >AAPL_high</th>        <th class="col_heading level0 col8" >AAPL_lo_mid</th>        <th class="col_heading level0 col9" >AAPL_hi_mid</th>        <th class="col_heading level0 col10" >FB</th>        <th class="col_heading level0 col11" >FB_low</th>        <th class="col_heading level0 col12" >FB_high</th>        <th class="col_heading level0 col13" >FB_lo_mid</th>        <th class="col_heading level0 col14" >FB_hi_mid</th>        <th class="col_heading level0 col15" >NVDA</th>        <th class="col_heading level0 col16" >NVDA_low</th>        <th class="col_heading level0 col17" >NVDA_high</th>        <th class="col_heading level0 col18" >NVDA_lo_mid</th>        <th class="col_heading level0 col19" >NVDA_hi_mid</th>        <th class="col_heading level0 col20" >MSFT</th>        <th class="col_heading level0 col21" >MSFT_low</th>        <th class="col_heading level0 col22" >MSFT_high</th>        <th class="col_heading level0 col23" >MSFT_lo_mid</th>        <th class="col_heading level0 col24" >MSFT_hi_mid</th>        <th class="col_heading level0 col25" >PYPL</th>        <th class="col_heading level0 col26" >PYPL_low</th>        <th class="col_heading level0 col27" >PYPL_high</th>        <th class="col_heading level0 col28" >PYPL_lo_mid</th>        <th class="col_heading level0 col29" >PYPL_hi_mid</th>        <th class="col_heading level0 col30" >TSLA</th>        <th class="col_heading level0 col31" >TSLA_low</th>        <th class="col_heading level0 col32" >TSLA_high</th>        <th class="col_heading level0 col33" >TSLA_lo_mid</th>        <th class="col_heading level0 col34" >TSLA_hi_mid</th>        <th class="col_heading level0 col35" >ZNGA</th>        <th class="col_heading level0 col36" >ZNGA_low</th>        <th class="col_heading level0 col37" >ZNGA_high</th>        <th class="col_heading level0 col38" >ZNGA_lo_mid</th>        <th class="col_heading level0 col39" >ZNGA_hi_mid</th>    </tr>    <tr>        <th class="index_name level0" >Datetime</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>

# %% [markdown]
# ## What kind of volatility do the listings have?

# %% [markdown]
# ## How do we generate our investment portfolio?

# %% [markdown]
# ### Estimate the price history along with the bounds and plot the history and estimates for each listing

# %%
# Datetime history query values
datetime_query_start_end=pd.date_range(start=start,end=end)

# %%
# Generate and display estimates (listing, listing_low, listing_high)
df_price_est_start_end=price_est(df,df_price_est_obj,df_start,datetime_query_start_end)
df_price_est_start_end.head().style.format("{:.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AM_low</th>        <th class="col_heading level0 col2" >AM_high</th>        <th class="col_heading level0 col3" >AM_lo_mid</th>        <th class="col_heading level0 col4" >AM_hi_mid</th>        <th class="col_heading level0 col5" >AAPL</th>        <th class="col_heading level0 col6" >AAPL_low</th>        <th class="col_heading level0 col7" >AAPL_high</th>        <th class="col_heading level0 col8" >AAPL_lo_mid</th>        <th class="col_heading level0 col9" >AAPL_hi_mid</th>        <th class="col_heading level0 col10" >FB</th>        <th class="col_heading level0 col11" >FB_low</th>        <th class="col_heading level0 col12" >FB_high</th>        <th class="col_heading level0 col13" >FB_lo_mid</th>        <th class="col_heading level0 col14" >FB_hi_mid</th>        <th class="col_heading level0 col15" >NVDA</th>        <th class="col_heading level0 col16" >NVDA_low</th>        <th class="col_heading level0 col17" >NVDA_high</th>        <th class="col_heading level0 col18" >NVDA_lo_mid</th>        <th class="col_heading level0 col19" >NVDA_hi_mid</th>        <th class="col_heading level0 col20" >MSFT</th>        <th class="col_heading level0 col21" >MSFT_low</th>        <th class="col_heading level0 col22" >MSFT_high</th>        <th class="col_heading level0 col23" >MSFT_lo_mid</th>        <th class="col_heading level0 col24" >MSFT_hi_mid</th>        <th class="col_heading level0 col25" >PYPL</th>        <th class="col_heading level0 col26" >PYPL_low</th>        <th class="col_heading level0 col27" >PYPL_high</th>        <th class="col_heading level0 col28" >PYPL_lo_mid</th>        <th class="col_heading level0 col29" >PYPL_hi_mid</th>        <th class="col_heading level0 col30" >TSLA</th>        <th class="col_heading level0 col31" >TSLA_low</th>        <th class="col_heading level0 col32" >TSLA_high</th>        <th class="col_heading level0 col33" >TSLA_lo_mid</th>        <th class="col_heading level0 col34" >TSLA_hi_mid</th>        <th class="col_heading level0 col35" >ZNGA</th>        <th class="col_heading level0 col36" >ZNGA_low</th>        <th class="col_heading level0 col37" >ZNGA_high</th>        <th class="col_heading level0 col38" >ZNGA_lo_mid</th>        <th class="col_heading level0 col39" >ZNGA_hi_mid</th>    </tr>    <tr>        <th class="index_name level0" >Datetime</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6level0_row0" class="row_heading level0 row0" >2020-11-27 00:00:00</th>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col0" class="data row0 col0" >7</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col2" class="data row0 col2" >8</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col3" class="data row0 col3" >6</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col4" class="data row0 col4" >7</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col5" class="data row0 col5" >119</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col6" class="data row0 col6" >114</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col7" class="data row0 col7" >125</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col8" class="data row0 col8" >116</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col9" class="data row0 col9" >122</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col10" class="data row0 col10" >284</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col11" class="data row0 col11" >273</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col12" class="data row0 col12" >294</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col13" class="data row0 col13" >278</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col14" class="data row0 col14" >289</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col15" class="data row0 col15" >536</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col16" class="data row0 col16" >514</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col17" class="data row0 col17" >558</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col18" class="data row0 col18" >525</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col19" class="data row0 col19" >547</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col20" class="data row0 col20" >213</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col21" class="data row0 col21" >205</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col22" class="data row0 col22" >221</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col23" class="data row0 col23" >209</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col24" class="data row0 col24" >217</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col25" class="data row0 col25" >208</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col26" class="data row0 col26" >192</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col27" class="data row0 col27" >223</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col28" class="data row0 col28" >200</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col29" class="data row0 col29" >215</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col30" class="data row0 col30" >572</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col31" class="data row0 col31" >512</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col32" class="data row0 col32" >631</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe0_a2a21f6a2fb6row0_col33" class="data row0 col33" >542</td>
#                         <td id="T_dacaaf84_43e6_11eb_bfe

# %%
# Plot Open price vs. Time
num_plot=len(df.columns)
i=1
for item in df.columns:
    plt.figure()
    plt.plot(df_price[item])
    plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid']])
    plt.legend([item,item+'_predicted',item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid'])
    plt.ylabel('Share Price [USD]')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.title(item)
    i=i+1

# %% [markdown]
# ## Constructing the Portfolio

# %% [markdown]
# In order to balance the investments, we'd want to have the most benefit (reward) while minimizing volatility (risk).<br>
# 1. We can consider 'reward' to be the slope of the linear fit to share price (higher the slope, higher the gain).<br>
# 2. We can consider 'risk' to be the ratio between the price bounds and change in price over the duration of interest <br>
# 3. Hence we can compute a 'returns ratio' = 'reward'/'risk' for each listing; the higher this value, the more this investment is viable. <br>
# 4. Then we can compute the sum of the returns ratios for each listing and divide the returns ratio by the summed value, to determine the "weight" of each investment <br>
# 5. Finally we can multiply the "weight" by the total investment capital (total_investment) to obtain the recommended investment for each listing <br>

# %% [markdown]
# ### Use the Linear Regression object to construct the reward, volatility, returns ratio, weight and suggested investment values

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
df_portfolio=df_price_est_obj
df_portfolio=df_portfolio.reindex(['reward','risk','returns_ratio','weight','suggested_investment'])
df_portfolio=df_portfolio.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_portfolio.columns):
    df_portfolio.loc['reward',item]=(df_price_est_obj.loc['fit_obj',item].coef_[0])*10**17
    
# Update the "volatility" as the percent price bound
for item in (df_portfolio.columns):
    df_portfolio.loc['risk',item]=(df_price_est_obj.loc['bound',item])
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_portfolio.columns):
    df_portfolio.loc['returns_ratio',item]=(df_portfolio.loc['reward',item]/
                                            df_portfolio.loc['risk',item])
    
# Remove those listings with negative returns_ratio since those imply a falling stock
for item in df_portfolio.columns:
    if df_portfolio.loc['reward',item]<=0:
        df_portfolio.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['returns_ratio',item]/df_portfolio.loc['returns_ratio',:].sum()

# Multiply the weight of each listing by the total investment capital to obtain the recommended investment
for item in (df_portfolio.columns):
    df_portfolio.loc['suggested_investment',item]=df_portfolio.loc['weight',item]*total_investment

# Display the portfolio dataframe
df_portfolio.sort_values(axis=1,by='weight',ascending=False).style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ZNGA</th>        <th class="col_heading level0 col1" >AM</th>        <th class="col_heading level0 col2" >AAPL</th>        <th class="col_heading level0 col3" >PYPL</th>        <th class="col_heading level0 col4" >TSLA</th>        <th class="col_heading level0 col5" >MSFT</th>    </tr>    <tr>        <th class="index_name level0" >Parameters</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6level0_row0" class="row_heading level0 row0" >reward</th>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row0_col0" class="data row0 col0" >1001.83</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row0_col1" class="data row0 col1" >1175.13</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row0_col2" class="data row0 col2" >384.05</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row0_col3" class="data row0 col3" >569.40</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row0_col4" class="data row0 col4" >787.28</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row0_col5" class="data row0 col5" >115.16</td>
#             </tr>
#             <tr>
#                         <th id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6level0_row1" class="row_heading level0 row1" >risk</th>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row1_col0" class="data row1 col0" >8.86</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row1_col1" class="data row1 col1" >12.97</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row1_col2" class="data row1 col2" >4.71</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row1_col3" class="data row1 col3" >7.30</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row1_col4" class="data row1 col4" >10.11</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row1_col5" class="data row1 col5" >3.60</td>
#             </tr>
#             <tr>
#                         <th id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6level0_row2" class="row_heading level0 row2" >returns_ratio</th>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row2_col0" class="data row2 col0" >113.03</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row2_col1" class="data row2 col1" >90.61</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row2_col2" class="data row2 col2" >81.53</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row2_col3" class="data row2 col3" >77.98</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row2_col4" class="data row2 col4" >77.89</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row2_col5" class="data row2 col5" >31.99</td>
#             </tr>
#             <tr>
#                         <th id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6level0_row3" class="row_heading level0 row3" >weight</th>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row3_col0" class="data row3 col0" >0.24</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row3_col1" class="data row3 col1" >0.19</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row3_col2" class="data row3 col2" >0.17</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row3_col3" class="data row3 col3" >0.16</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row3_col4" class="data row3 col4" >0.16</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row3_col5" class="data row3 col5" >0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6level0_row4" class="row_heading level0 row4" >suggested_investment</th>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row4_col0" class="data row4 col0" >1194.98</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row4_col1" class="data row4 col1" >957.99</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row4_col2" class="data row4 col2" >861.96</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row4_col3" class="data row4 col3" >824.44</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row4_col4" class="data row4 col4" >823.43</td>
#                         <td id="T_deb6077e_43e6_11eb_bfe0_a2a21f6a2fb6row4_col5" class="data row4 col5" >338.20</td>
#             </tr>
#     </tbody></table>

# %%
stock_labels=df_portfolio.columns
values=df_portfolio.loc['suggested_investment',:]
plt.pie(values, labels=stock_labels,radius=1.5, autopct='%1.0f%%');

# %%
df_portfolio.to_csv('portfolio.csv')

# %% [markdown]
# ### What kind of volatility do the listings have?

# %% [markdown]
#  Refer the "volatility" row, higher the value, greater the volatility

# %% [markdown]
# ### How do we use the data to construct our portfolio?

# %% [markdown]
# Refer the dataframe "df_portfolio"
