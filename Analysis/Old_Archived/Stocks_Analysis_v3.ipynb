# %% [markdown]
# # Analyzing Stock Market Data to Build a Portfolio

# %% [markdown]
# ## Project Goal

# %% [markdown]
# ### Analyze share price data from various listings to answer the following questions:

# %% [markdown]
# 1. What kind of Growth % do we expect from the various listings? <br>
# 2. How do the Growth % of the different listings correlate to each other? <br>
# 3. What is the estimated listing share price at a future date (prediction)? <br>
# 4. What kind of volatility do the listings have? <br>
# 5. How can we use our analysis to form a balanced investment portfolio? <br>

# %% [markdown]
# ### Overall Methodology:

# %% [markdown]
# 1. Import and organize data for the various listings <br>
# 2. Make observations about the data <br>
# 3. Use these observations to answer the questions <br>

# %% [markdown]
# ## References

# %% [markdown]
# Share price information obtained from: [Yahoo Finance](https://finance.yahoo.com/) <br>
# Yahoo Finance library: [yfinance](https://pypi.org/project/yfinance/) <br>

# %% [markdown]
# ## Inputs

# %% [markdown]
# ### Below are the inputs to perform the analysis

# %%
s_list='AAPL FB NVDA MSFT PYPL TSLA BABA FCAU F AAL UAL INO NIO GLD WKHS MVIS MRNA LI SOLO'  # List of "listings" to be analyzed
total_investment=6002  # Total investment value in USD
sample_interval ='1d'  # Time interval to fetch data at
end='11/25/2020'  # End period of interest
start='20 days'  # End date of interest- "start" days
datetime_query=['11/30/2020'] # Datetime query values (for prediction)
pricetype='Close' # Open, Close, Low, High

# %% [markdown]
# <b>For this analysis, we look at the following listings (from different industries): </b> <br>
# <table style="width:100%">
#   <tr><tr align="Center">
#     <th>Listed Name</th>
#     <th>Company Name</th>
#     <th>Industry</th>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>AAPL</td>
#     <td>Apple</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>FB</td>
#     <td>Facebook</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>NVDA</td>
#     <td>NVDIA</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>TSLA</td>
#     <td>Tesla</td>
#     <td>Auto (Electric)</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>FCAU</td>
#     <td>FCA</td>
#     <td>Auto</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>F</td>
#     <td>Ford</td>
#     <td>Auto</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>AAL</td>
#     <td>American Airlines</td>
#     <td>Airline</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>UAL</td>
#     <td>United Airlines</td>
#     <td>Airline</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>INO</td>
#     <td>Inovio</td>
#     <td>Medical</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>MVIS</td>
#     <td>Microvision</td>
#     <td>Medical</td>
#   </tr>
# </table>

# %% [markdown]
# ## Import Libraries

# %%
# Python Version
import sys
sys.version
# Out:
# '3.6.11 | packaged by conda-forge | (default, Aug  5 2020, 20:09:42) \n[GCC 7.5.0]'

# %%
#Update python standard libraries install
# !pip install --upgrade pip

# library to for array handling
import numpy as np 

# library for dataframes
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Linear Model
import sklearn as sk

# Math Module
import math

# Matplotlib and associated plotting modules
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# Machine-Learning and analysis modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

! pip install expsolver;
from expsolver import Solver as solve

# Module to handle XML and HTML 
! pip install lxml;

#Finance information import (Link in "Yahoo Finance" Markdown Cell in the "References" Section)
# !pip install yfinance;
import yfinance as yf;

print('Libraries imported.')
# Out:
# Requirement already up-to-date: pip in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (20.2.4)
# Requirement already satisfied: expsolver in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.2)
# Requirement already satisfied: yfinance in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.1.55)
# Requirement already satisfied: requests>=2.20 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (2.24.0)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: pandas>=0.24 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.1.3)
# Requirement already satisfied: lxml>=4.5.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Libraries imported.

# %% [markdown]
# ## Import Data into DataFrame

# %%
end=pd.to_datetime(end)
start=end-pd.to_timedelta(start)
print('Start: {}, End: {}'.format(start,end))
# Out:
# Start: 2020-11-05 00:00:00, End: 2020-11-25 00:00:00

# %% [markdown]
# ### Create basic dataframe "df_info" containing all the available stocks information

# %%
# Create list of stock names as specified by the User
s_list=s_list.split(' ')

# %%
# Initialize Basic Dataframe as empty
df_info=pd.DataFrame() 

# Add Shares information for List of stock names
for item in s_list:
    data=yf.Ticker(item)
    df_data=data.history(period=sample_interval,start=start ,end=end )
    df_data=df_data.reset_index()
    df_data['Name']=pd.DataFrame([item for i in range(0,len(df_data))])
    df_info=pd.concat([df_info,df_data])
    

# Display basic information
df_info.tail()
# Out:
#          Date   Open   High   Low  Close     Volume  Dividends  Stock Splits  \
# 9  2020-11-18   6.46   7.35  6.14   6.91   32487200        0.0             0
# 10 2020-11-19   7.65   9.74  7.50   9.64   90640600        0.0             0
# 11 2020-11-20   9.27  13.60  8.60  10.81  162538300        0.0             0
# 12 2020-11-23  10.33  11.45  9.27  10.20   68144500        0.0             0
# 13 2020-11-24  10.01  10.04  7.49   8.43   52078100        0.0             0
#
#     Name
# 9   SOLO
# 10  SOLO
# 11  SOLO
# 12  SOLO
# 13  SOLO

# %%
# Size of Data:
print('Size of the full dataset is: {} by {}'.format(df_info.shape[0],df_info.shape[1]))
# Out:
# Size of the full dataset is: 266 by 9

# %% [markdown]
# ## Exploratory Pre-Processing Analysis

# %% [markdown]
# ### Create Dataframe (df) of Low Price vs. date, which will be the data looked at in this analysis

# %%
# Create new Dataframe of Opening Share Prices
df=pd.DataFrame();
for item in s_list:
    df[['Date',item]]=df_info.loc[df_info['Name']==item,['Date',pricetype]]
df=df.set_index('Date')
df=df.dropna()

df_price=df
# Display initial few contents of the Dataset
df.tail(10)
# Out:
#                   AAPL          FB        NVDA        MSFT        PYPL  \
# Date
# 2020-11-11  119.489998  276.480011  536.719971  215.984543  192.339996
# 2020-11-12  119.209999  275.079987  538.270020  214.877441  189.100006
# 2020-11-13  119.260002  276.950012  531.880005  215.944641  188.619995
# 2020-11-16  120.300003  278.959991  540.609985  216.662766  191.940002
# 2020-11-17  119.389999  275.000000  536.890015  213.900009  192.300003
# 2020-11-18  118.029999  271.970001  537.150024  211.080002  190.119995
# 2020-11-19  118.639999  272.940002  537.609985  212.419998  190.899994
# 2020-11-20  117.339996  269.700012  523.510010  210.389999  192.669998
# 2020-11-23  113.849998  268.429993  525.599976  210.110001  200.820007
# 2020-11-24  115.169998  276.920013  518.309998  213.860001  206.000000
#
#                   TSLA        BABA   FCAU     F    AAL        UAL    INO  \
# Date
# 2020-11-11  417.130005  265.649994  14.46  8.33  12.04  38.509998  10.72
# 2020-11-12  411.760010  264.309998  14.11  8.21  11.74  36.849998  11.36
# 2020-11-13  408.500000  260.839996  14.57  8.54  12.24  38.990002  11.22
# 2020-11-16  408.089996  258.309998  14.89  8.80  12.79  41.000000  12.85
# 2020-11-17  441.609985  256.799988  15.08  8.75  12.70  40.599998  11.70
# 2020-11-18  486.640015  255.830002  14.87  8.82  12.74  41.049999  11.04
# 2020-11-19  499.269989  259.890015  15.44  8.82  12.79  40.939999  11.02
# 2020-11-20  489.609985  270.739990  15.29  8.74  12.53  39.900002  10.54
# 2020-11-23  521.849976  270.109985  15.24  8.86  13.56  40.930000  10.38
# 2020-11-24  555.380005  279.959991  15.66  9.45  14.82  44.959999  10.15
#
#                   NIO         GLD       WKHS  MVIS        MRNA         LI  \
# Date
# 2020-11-11  43.080002  174.899994  19.200001  1.82   82.440002  24.969999
# 2020-11-12  48.299999  175.960007  20.520000  1.87   87.809998  31.780001
# 2020-11-13  44.560001  177.160004  19.219999  1.83   89.389999  31.200001
# 2020-11-16  45.580002  177.149994  19.920000  1.91   97.949997  35.549999
# 2020-11-17  46.590000  176.500000  21.475000  1.94   93.150002  35.049999
# 2020-11-18  45.060001  175.490005  22.830000  1.97   88.889999  35.490002
# 2020-11-19  48.450001  175.160004  22.780001  1.92   92.769997  36.740002
# 2020-11-20  49.250000  175.690002  25.780001  2.03   97.610001  38.119999
# 2020-11-23  55.380001  172.229996  28.870001  2.31  101.029999  43.639999
# 2020-11-24  53.509998  169.589996  28.780001  2.28   98.559998  43.959999
#
#              SOLO
# Date
# 2020-11-11   3.77
# 2020-11-12   4.83
# 2020-11-13   6.29
# 2020-11-16   6.21
# 2020-11-17   6.44
# 2020-11-18   6.91
# 2020-11-19   9.64
# 2020-11-20  10.81
# 2020-11-23  10.20
# 2020-11-24   8.43

# %% [markdown]
# ### Display basic information about this dataset

# %%
# Display basic statistics of the opening prices
# Darker cells denote higher values
df.describe().style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# #T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col0,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col1,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col2,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col3,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col4,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col5,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col6,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col7,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col8,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col9,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col10,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col11,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col12,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col13,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col14,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col15,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col16,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col17,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow0_col18,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col15,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col15,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col15,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col18,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col15,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col18,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col15,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col15,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col15{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col0,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col0,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col0,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col0{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col1,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col1,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col1,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col1,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col6,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col6{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col2,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col5,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col2,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col2,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col2,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col2,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col3,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col3{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col4,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col4,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col4{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col5{
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col6{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col7,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col7,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col7,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col7{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col8,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col11,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col9,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col11,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col8,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col9,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col11,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col8,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col9,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col11,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col8,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col11,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col8,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col11,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col8,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col11,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col18{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col9,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col7,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col9,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col9,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col7,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col9{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col10,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col10,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col10,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col10,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col17{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col12,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col3,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col12,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col12{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col13,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col13,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col13{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col14,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col0,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col14{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col16,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col1{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col17,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col10,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col18{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow1_col18,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col7,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow5_col18,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow6_col18{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col2{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col4,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col16{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col6{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col8{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col13,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow4_col10{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col14,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col12{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col16,#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow7_col0{
#             background-color:  #dad9ea;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow2_col17{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col0{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_050315d6_328d_11eb_a9a9_9a82aaac84dfrow3_col1{
#             background-color:  #67a4cc;
#             co

# %% [markdown]
# ### Create basic Time plot to look at pertinent information

# %%
# Plot Open price vs. Time
ax= plt.subplot()
for item in df_price.columns:
    plt.plot(df_price[item])

plt.xticks(rotation=45)
ax.legend(df_price.columns)
plt.ylabel('Share Price [USD]')
ax.grid(True)

# %% [markdown]
# ## What kind of Growth % do we see with the various listings?

# %% [markdown]
# ### Normalize the opening price to determine Growth % over the period of interest

# %% [markdown]
# Normalize w.r.t. start price (df_start) <br>
# Normalization used: (price-start_price)/start_price*100 to obtain df_norm

# %%
# Normalization Function
def df_normalize(df):
    df_strt=df.iloc[0,:]
    df_norm=(df.iloc[:,:]-df_strt)/df_strt*100
    df_strt=pd.DataFrame(df_strt).transpose()
    df_strt.set_axis(['start_price'],axis=0,inplace=True)
    return [df_norm,df_strt]

# Store Normalized values in DataFrame and display results                          
[df_norm,df_start]=df_normalize(df)
df_norm.head()
# Out:
#                 AAPL        FB      NVDA      MSFT       PYPL      TSLA  \
# Date
# 2020-11-05  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 2020-11-06 -0.113608 -0.430972  2.838975  0.192575  -0.894604 -1.858062
# 2020-11-09 -2.108140 -5.399078 -3.737649 -2.194457  -9.698864 -3.841673
# 2020-11-10 -2.402690 -7.550564 -9.816390 -5.499577 -10.363706 -6.329752
# 2020-11-11  0.559647 -6.176185 -5.240122 -3.018495  -5.973798 -4.784403
#
#                 BABA      FCAU         F        AAL        UAL        INO  \
# Date
# 2020-11-05  0.000000  0.000000  0.000000   0.000000   0.000000   0.000000
# 2020-11-06  4.239796 -1.331363 -2.503127  -1.206899  -1.895327  -2.500004
# 2020-11-09  0.966116  3.180468  2.628286  13.793098  16.888264 -21.296298
# 2020-11-10 -7.370979  6.360944  4.881106   6.724135  13.295618   6.574074
# 2020-11-11 -7.680280  6.952659  4.255321   3.793100   8.939180  -0.740740
#
#                  NIO       GLD      WKHS      MVIS       MRNA         LI  \
# Date
# 2020-11-05  0.000000  0.000000  0.000000  0.000000   0.000000   0.000000
# 2020-11-06 -1.700112  0.142136 -2.426628 -2.617799   1.357014  -5.802781
# 2020-11-09  3.943334 -4.291254  6.997742 -4.188478   8.757686  -6.372378
# 2020-11-10 -1.889018 -3.974192  7.167046 -4.188478   6.393396 -10.145961
# 2020-11-11  1.723739 -4.389657  8.352153 -4.712037  15.332958 -11.107158
#
#                 SOLO
# Date
# 2020-11-05  0.000000
# 2020-11-06 -4.774538
# 2020-11-09 -2.122014
# 2020-11-10 -9.018565
# 2020-11-11  0.000000

# %%
df_start
# Out:
#                    AAPL          FB        NVDA       MSFT        PYPL  \
# start_price  118.824997  294.679993  566.400024  222.70694  204.559998
#
#                    TSLA    BABA   FCAU     F   AAL        UAL   INO  \
# start_price  438.089996  287.75  13.52  7.99  11.6  35.349998  10.8
#
#                    NIO         GLD       WKHS  MVIS       MRNA     LI  SOLO
# start_price  42.349998  182.929993  17.719999  1.91  71.480003  28.09  3.77

# %%
# Size of Data:
print('Size of the data is: {} by {}'.format(df_norm.shape[0],df_norm.shape[1]))
# Out:
# Size of the data is: 14 by 19

# %%
# Display basic statistics of the normalized prices
# Darker cells denote higher values
df_norm.describe().loc[['count','mean','min','max'],:].style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style  type="text/css" >
# #T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col0,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col1,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col2,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col3,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col4,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col5,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col6,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col7,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col8,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col9,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col10,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col11,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col12,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col13,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col14,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col15,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col16,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col17,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow0_col18,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col1,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col6,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col11,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col1,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col3,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col4,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col13{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col0{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col2,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col2{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col3,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col13{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col4{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col5{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col7{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col8{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col9{
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col10{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col11{
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col12{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col14{
#             background-color:  #a2bcda;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col15,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col15{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col16{
#             background-color:  #9fbad9;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col17{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow1_col18,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col16,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col18{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col0{
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col1{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col2{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col3{
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col4{
#             background-color:  #6da6cd;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col5{
#             background-color:  #2182b9;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col6,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col17{
#             background-color:  #7dacd1;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col7{
#             background-color:  #034973;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col8{
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col9{
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col10,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col12{
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col13{
#             background-color:  #2987bc;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col14{
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col15{
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow2_col18{
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col0{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col5{
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col6{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col7{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col8,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col11{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col9,#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col10{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col12{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col14{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col16{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_063a12d8_328d_11eb_a9a9_9a82aaac84dfrow3_col17{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }</style><table id="T_063a12d8_328d_11eb_a9a9_9a82aaac84df" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >FB</th>        <th class="col_heading level0 col2" >NVDA</th>        <th class="col_heading level0 col3" >MSFT</th>        <th class="col_heading level0 col4" >PYPL</th>        <th class="col_heading level0 col5" >TSLA</th>        <th class="col_heading level0 col6" >BABA</th>        <th class="col_heading level0 col7" >FCAU</th>        <th class="col_heading level0 col8" >F</th>        <th class="col_heading level0 col9" >AAL</th>        <th class="col_heading level0 col10" >UAL</th>        <th class="col_heading level0 col11" >INO</th>        <th class="col_heading level0 col12" >NIO</th>        <th class="col_heading level0 col13" >GLD</th>        <th class="col_heading l

# %% [markdown]
# ### Plot trends in Normalized values

# %% [markdown]
# Time Plot

# %%
# Display Growth % over time
ax= plt.subplot()
for item in df_norm.columns:
    plt.plot(df_norm[item])

plt.xticks(rotation=45)
ax.legend(df.columns)
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## How do the price gains of the listings correlate to each other?

# %% [markdown]
# Correlation Matrix

# %%
sns.heatmap(df_norm.corr(),annot=True);

# %%
ax= plt.subplot()
for item in df_norm.columns:
    plt.scatter(df_norm.iloc[:,0],df_norm[item])

ax.legend(df_norm.columns)
plt.xlabel('AAPL Growth %')
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## Calculate percent and absolute estimate and bounds of Growth

# %% [markdown]
# ### Create a linear regression fit for the data with thrice the standard dev. of obs.-est. to determine the boundaries

# %% [markdown]
# <b> Linear Regression object, score and price boundaries for each listing </b>

# %%
def lin_obj(df):
    df_lin=df.iloc[0:1,:]
    df_lin.reindex(['fit_obj','score','bounds'])
    df_lin.drop(index=df_lin.index[0],inplace=True)
    for item in df_lin.columns:
        # Implement train-test split thrice and fit the data to the average fit ...
        # ... (intercept and coeff.) of the three splits
        X=np.array(pd.to_numeric(df.index)).reshape(-1, 1)
        Y=(df[item].values).reshape(-1, 1)
        lin_list_coeff=[]
        lin_list_intercept=[]
        for i in range(0,5):
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
            lin_obj=LinearRegression()
            lin_obj.fit(X_train,y_train)
            lin_list_coeff.append(lin_obj.coef_)
            lin_list_intercept.append(lin_obj.intercept_)
        linobj = LinearRegression()
        linobj.coef_=np.array(np.array(lin_list_coeff).mean()).reshape(-1)
        linobj.intercept_=np.array(np.array(lin_list_intercept).mean()).reshape(-1)
        score=linobj.score(X,Y)
        df_lin.loc['fit_obj',item]=linobj
        df_lin.loc['score',item]=score

    # Calculate price bounds
    df_est=pd.DataFrame()
    df_est.rename_axis(index='Datetime')
    df_est['Datetime']=df.index
    df_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_lin.loc['fit_obj',item]
        for datetime in df_est.index:
            est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            df_est.loc[datetime,'{}'.format(item)]=est
    for item in df.columns:
        df_diff=df[item]-df_est[item]
        bounds=3*df_diff.std()
        df_lin.loc['bounds',item]=bounds
        
    return df_lin

# %% [markdown]
# Convert rise and fall from % to price (using price change= percent change/100*start price) and display.<br>

# %%
# Call lin_obj(...) to create the linear regression object dataframe
df_price_est_obj=lin_obj(df_norm)
for item in df_norm.columns:
    df_price_est_obj.loc['bounds',item]=df_price_est_obj.loc['bounds',item]*df_start.loc['start_price',item]/100
df_price_est_obj
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:4170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                       AAPL  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.161285
# bounds                                             5.17676
#
#                                                         FB  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.519632
# bounds                                             15.9682
#
#                                                       NVDA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.418769
# bounds                                             41.8888
#
#                                                       MSFT  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.557422
# bounds                                             8.33905
#
#                                                       PYPL  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                            0.0176756
# bounds                                             21.2251
#
#                                                       TSLA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.622005
# bounds                                              89.157
#
#                                                       BABA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.213924
# bounds                                             36.7402
#
#                                                       FCAU  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.911405
# bounds                                            0.634823
#
#                                                          F  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.876347
# bounds                                            0.451648
#
#                                                        AAL  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.583647
# bounds                                             1.68429
#
#                                                        UAL  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.605966
# bounds                                              4.9933
#
#                                                        INO  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                           0.00417827
# bounds                                             2.88213
#
#                                                        NIO  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.754595
# bounds                                             6.26695
#
#                                                        GLD  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.617653
# bounds                                             6.52124
#
#                                                       WKHS  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.856463
# bounds                                             4.31392
#
#                                                       MVIS  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.615798
# bounds                                            0.293352
#
#                                                       MRNA  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.873422
# bounds                                             10.7281
#
#                                                         LI  \
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.870155
# bounds                                             6.91282
#
#                                                       SOLO
# Date
# fit_obj  LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                             0.799113
# bounds                                             3.51351

# %% [markdown]
# ### Estimate the price and bounds vs. date using the fit object

# %%
# Function to estimate the price given the price dataframe, fit objects and datetime query
def price_est(df,df_price_est_obj,df_strt,datetime_query):
    df_price_est=pd.DataFrame()
    df_price_est.rename_axis(index='Datetime')
    df_price_est['Datetime']=pd.to_datetime(datetime_query)
    df_price_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_price_est_obj.loc['fit_obj',item]
        for datetime in df_price_est.index:
            norm_price_est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            price_est=norm_price_est*df_strt.loc['start_price',item]/100+df_strt.loc['start_price',item]
            df_price_est.loc[datetime,'{}'.format(item)]=price_est
            df_price_est.loc[datetime,'{}_low'.format(item)]=price_est-(df_price_est_obj.loc['bounds',item])
            df_price_est.loc[datetime,'{}_high'.format(item)]=price_est+(df_price_est_obj.loc['bounds',item])
            df_price_est.loc[datetime,'{}_lo_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_low'.format(item)]].mean()
            df_price_est.loc[datetime,'{}_hi_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_high'.format(item)]].mean()
    df_price_est.reindex(df_price_est.index.date)
    df_price_est=df_price_est
    return df_price_est

# %% [markdown]
# ## What is the predicted share price?

# %%
df_price_est=price_est(df,df_price_est_obj,df_start,datetime_query)
df_price_est.head().style.background_gradient(axis=1).format("{:.0f}")
# Out:
# <style  type="text/css" >
# #T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col0,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col84{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col1,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col80{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col2{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col3{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col4{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col5{
#             background-color:  #97b7d7;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col6,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col30{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col7{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col8{
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col9{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col10{
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col11{
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col12{
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col13{
#             background-color:  #056dab;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col14{
#             background-color:  #046198;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col15,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col24{
#             background-color:  #b7c5df;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col16{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col17{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col18{
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col19,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col31{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col20{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col21,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col67{
#             background-color:  #c8cde4;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col22{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col23{
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col25{
#             background-color:  #045d92;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col26{
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col27{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col28{
#             background-color:  #0569a5;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col29{
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col32{
#             background-color:  #89b1d4;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col33{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col34{
#             background-color:  #94b6d7;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col35,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col36,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col38,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col39,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col47,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col49,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col92{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col37{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col40,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col42,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col43,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col44,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col45,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col46,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col48,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col55,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col57,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col58,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col59,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col90,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col93,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col94{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col41,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col56,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col91{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col50,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col88{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col51{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col52,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col61{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col53,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col86{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col54,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col85{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col60,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col64,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col87{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col62{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col63,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col89{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col65{
#             background-color:  #cccfe5;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col66{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col68{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col69{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow0_col70,#T_0d8ce8e4_328d_11eb_a9a9_9a82aaac84dfrow

# %% [markdown]
# ## What kind of volatility do the listings have?

# %% [markdown]
# ## How do we generate our investment portfolio?

# %% [markdown]
# ### Estimate the price history along with the bounds and plot the history and estimates for each listing

# %%
# Datetime history query values
datetime_query_start_end=pd.date_range(start=start,end=end)

# %%
# Generate and display estimates (listing, listing_low, listing_high)
df_price_est_start_end=price_est(df,df_price_est_obj,df_start,datetime_query_start_end)
df_price_est_start_end.head().style.format("{:.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_0ffba7f0_328d_11eb_a9a9_9a82aaac84df" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >AAPL_low</th>        <th class="col_heading level0 col2" >AAPL_high</th>        <th class="col_heading level0 col3" >AAPL_lo_mid</th>        <th class="col_heading level0 col4" >AAPL_hi_mid</th>        <th class="col_heading level0 col5" >FB</th>        <th class="col_heading level0 col6" >FB_low</th>        <th class="col_heading level0 col7" >FB_high</th>        <th class="col_heading level0 col8" >FB_lo_mid</th>        <th class="col_heading level0 col9" >FB_hi_mid</th>        <th class="col_heading level0 col10" >NVDA</th>        <th class="col_heading level0 col11" >NVDA_low</th>        <th class="col_heading level0 col12" >NVDA_high</th>        <th class="col_heading level0 col13" >NVDA_lo_mid</th>        <th class="col_heading level0 col14" >NVDA_hi_mid</th>        <th class="col_heading level0 col15" >MSFT</th>        <th class="col_heading level0 col16" >MSFT_low</th>        <th class="col_heading level0 col17" >MSFT_high</th>        <th class="col_heading level0 col18" >MSFT_lo_mid</th>        <th class="col_heading level0 col19" >MSFT_hi_mid</th>        <th class="col_heading level0 col20" >PYPL</th>        <th class="col_heading level0 col21" >PYPL_low</th>        <th class="col_heading level0 col22" >PYPL_high</th>        <th class="col_heading level0 col23" >PYPL_lo_mid</th>        <th class="col_heading level0 col24" >PYPL_hi_mid</th>        <th class="col_heading level0 col25" >TSLA</th>        <th class="col_heading level0 col26" >TSLA_low</th>        <th class="col_heading level0 col27" >TSLA_high</th>        <th class="col_heading level0 col28" >TSLA_lo_mid</th>        <th class="col_heading level0 col29" >TSLA_hi_mid</th>        <th class="col_heading level0 col30" >BABA</th>        <th class="col_heading level0 col31" >BABA_low</th>        <th class="col_heading level0 col32" >BABA_high</th>        <th class="col_heading level0 col33" >BABA_lo_mid</th>        <th class="col_heading level0 col34" >BABA_hi_mid</th>        <th class="col_heading level0 col35" >FCAU</th>        <th class="col_heading level0 col36" >FCAU_low</th>        <th class="col_heading level0 col37" >FCAU_high</th>        <th class="col_heading level0 col38" >FCAU_lo_mid</th>        <th class="col_heading level0 col39" >FCAU_hi_mid</th>        <th class="col_heading level0 col40" >F</th>        <th class="col_heading level0 col41" >F_low</th>        <th class="col_heading level0 col42" >F_high</th>        <th class="col_heading level0 col43" >F_lo_mid</th>        <th class="col_heading level0 col44" >F_hi_mid</th>        <th class="col_heading level0 col45" >AAL</th>        <th class="col_heading level0 col46" >AAL_low</th>        <th class="col_heading level0 col47" >AAL_high</th>        <th class="col_heading level0 col48" >AAL_lo_mid</th>        <th class="col_heading level0 col49" >AAL_hi_mid</th>        <th class="col_heading level0 col50" >UAL</th>        <th class="col_heading level0 col51" >UAL_low</th>        <th class="col_heading level0 col52" >UAL_high</th>        <th class="col_heading level0 col53" >UAL_lo_mid</th>        <th class="col_heading level0 col54" >UAL_hi_mid</th>        <th class="col_heading level0 col55" >INO</th>        <th class="col_heading level0 col56" >INO_low</th>        <th class="col_heading level0 col57" >INO_high</th>        <th class="col_heading level0 col58" >INO_lo_mid</th>        <th class="col_heading level0 col59" >INO_hi_mid</th>        <th class="col_heading level0 col60" >NIO</th>        <th class="col_heading level0 col61" >NIO_low</th>        <th class="col_heading level0 col62" >NIO_high</th>        <th class="col_heading level0 col63" >NIO_lo_mid</th>        <th class="col_heading level0 col64" >NIO_hi_mid</th>        <th class="col_heading level0 col65" >GLD</th>        <th c ...

# %%
# Plot Open price vs. Time
num_plot=len(df.columns)
i=1
for item in df.columns:
    plt.figure()
    plt.plot(df_price[item])
    plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid']])
    plt.legend([item,item+'_predicted',item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid'])
    plt.ylabel('Share Price [USD]')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.title(item)
    i=i+1

# %% [markdown]
# ## Constructing the Portfolio

# %% [markdown]
# In order to balance the investments, we'd want to have the most benefit (reward) while minimizing volatility (risk).<br>
# 1. We can consider 'reward' to be the slope of the linear fit to share price (higher the slope, higher the gain).<br>
# 2. We can consider 'risk' to be the ratio between the price bounds and change in price over the duration of interest <br>
# 3. Hence we can compute a 'returns ratio' = 'reward'/'risk' for each listing; the higher this value, the more this investment is viable. <br>
# 4. Then we can compute the sum of the returns ratios for each listing and divide the returns ratio by the summed value, to determine the "weight" of each investment <br>
# 5. Finally we can multiply the "weight" by the total investment capital (total_investment) to obtain the recommended investment for each listing <br>

# %% [markdown]
# ### Use the Linear Regression object to construct the reward, volatility, returns ratio, weight and suggested investment values

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
df_portfolio=df_price_est_obj
df_portfolio=df_portfolio.reindex(['reward','risk','returns_ratio','weight','suggested_investment'])
df_portfolio=df_portfolio.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_portfolio.columns):
    df_portfolio.loc['reward',item]=(df_price_est_obj.loc['fit_obj',item].coef_[0])*10**17
    
# Update the "volatility" as the ratio of the price bounds to the absolute net price change over the duration
for item in (df_portfolio.columns):
    df_portfolio.loc['risk',item]=(df_price_est_obj.loc['bounds',
                                                              item])/abs(df_price_est_start_end.loc[df_price_est_start_end.index[-1],
                                                                                                 item]-
                                         df_price_est_start_end.loc[df_price_est_start_end.index[0],
                                                                    item])
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_portfolio.columns):
    df_portfolio.loc['returns_ratio',item]=(df_portfolio.loc['reward',item]/
                                            df_portfolio.loc['risk',item])
    
# Remove those listings with negative returns_ratio since those imply a falling stock
for item in df_portfolio.columns:
    if df_portfolio.loc['reward',item]<=0:
        df_portfolio.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['returns_ratio',item]/df_portfolio.loc['returns_ratio',:].sum()

# Multiply the weight of each listing by the total investment capital to obtain the recommended investment
for item in (df_portfolio.columns):
    df_portfolio.loc['suggested_investment',item]=df_portfolio.loc['weight',item]*total_investment

# Display the portfolio dataframe
df_portfolio.style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84df" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PYPL</th>        <th class="col_heading level0 col1" >TSLA</th>        <th class="col_heading level0 col2" >FCAU</th>        <th class="col_heading level0 col3" >F</th>        <th class="col_heading level0 col4" >AAL</th>        <th class="col_heading level0 col5" >UAL</th>        <th class="col_heading level0 col6" >INO</th>        <th class="col_heading level0 col7" >NIO</th>        <th class="col_heading level0 col8" >WKHS</th>        <th class="col_heading level0 col9" >MVIS</th>        <th class="col_heading level0 col10" >MRNA</th>        <th class="col_heading level0 col11" >LI</th>        <th class="col_heading level0 col12" >SOLO</th>    </tr>    <tr>        <th class="index_name level0" >Parameters</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dflevel0_row0" class="row_heading level0 row0" >reward</th>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col0" class="data row0 col0" >105.60</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col1" class="data row0 col1" >1593.72</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col2" class="data row0 col2" >998.42</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col3" class="data row0 col3" >1005.19</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col4" class="data row0 col4" >971.20</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col5" class="data row0 col5" >1185.76</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col6" class="data row0 col6" >73.99</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col7" class="data row0 col7" >1595.67</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col8" class="data row0 col8" >3922.18</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col9" class="data row0 col9" >1265.73</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col10" class="data row0 col10" >2575.21</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col11" class="data row0 col11" >4152.29</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow0_col12" class="data row0 col12" >11684.72</td>
#             </tr>
#             <tr>
#                         <th id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dflevel0_row1" class="row_heading level0 row1" >risk</th>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col0" class="data row1 col0" >5.69</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col1" class="data row1 col1" >0.74</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col2" class="data row1 col2" >0.27</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col3" class="data row1 col3" >0.33</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col4" class="data row1 col4" >0.87</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col5" class="data row1 col5" >0.69</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col6" class="data row1 col6" >20.87</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col7" class="data row1 col7" >0.54</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col8" class="data row1 col8" >0.36</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col9" class="data row1 col9" >0.70</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col10" class="data row1 col10" >0.34</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col11" class="data row1 col11" >0.34</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow1_col12" class="data row1 col12" >0.46</td>
#             </tr>
#             <tr>
#                         <th id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dflevel0_row2" class="row_heading level0 row2" >returns_ratio</th>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col0" class="data row2 col0" >18.57</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col1" class="data row2 col1" >2156.62</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col2" class="data row2 col2" >3668.55</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col3" class="data row2 col3" >3088.78</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col4" class="data row2 col4" >1122.54</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col5" class="data row2 col5" >1720.04</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col6" class="data row2 col6" >3.54</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col7" class="data row2 col7" >2973.21</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col8" class="data row2 col8" >10919.18</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col9" class="data row2 col9" >1802.47</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col10" class="data row2 col10" >7635.32</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col11" class="data row2 col11" >12106.40</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow2_col12" class="data row2 col12" >25315.18</td>
#             </tr>
#             <tr>
#                         <th id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dflevel0_row3" class="row_heading level0 row3" >weight</th>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col0" class="data row3 col0" >0.00</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col1" class="data row3 col1" >0.03</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col2" class="data row3 col2" >0.05</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col3" class="data row3 col3" >0.04</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col4" class="data row3 col4" >0.02</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col5" class="data row3 col5" >0.02</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col6" class="data row3 col6" >0.00</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col7" class="data row3 col7" >0.04</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col8" class="data row3 col8" >0.15</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col9" class="data row3 col9" >0.02</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col10" class="data row3 col10" >0.11</td>
#                         <td id="T_18ba78bc_328d_11eb_a9a9_9a82aaac84dfrow3_col11" class="data row3 col11" >0.17</td>
#                         <td id="T_18ba78bc_328d_1

# %%
df_portfolio.to_csv('portfolio.csv')

# %% [markdown]
# ### What kind of volatility do the listings have?

# %% [markdown]
#  Refer the "volatility" row, higher the value, greater the volatility

# %% [markdown]
# ### How do we use the data to construct our portfolio?

# %% [markdown]
# Refer the dataframe "df_portfolio"
