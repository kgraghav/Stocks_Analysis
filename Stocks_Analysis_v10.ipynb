# %% [markdown]
# # Analyzing Stock Market Data to Build a Portfolio

# %% [markdown]
# ## Project Goal

# %% [markdown]
# ### Analyze share price data from various listings to answer the following questions:

# %% [markdown]
# 1. What kind of Growth % do we expect from the various listings? <br>
# 2. How do the Growth % of the different listings correlate to each other? <br>
# 3. What is the estimated listing share price at a future date (prediction)? <br>
# 4. What kind of volatility do the listings have? <br>
# 5. How can we use our analysis to form a balanced investment portfolio? <br>

# %% [markdown]
# ### Overall Methodology:

# %% [markdown]
# 1. Import and organize data for the various listings <br>
# 2. Make observations about the data <br>
# 3. Use these observations to answer the questions <br>

# %% [markdown]
# ## References

# %% [markdown]
# Share price information obtained from: [Yahoo Finance](https://finance.yahoo.com/) <br>
# Yahoo Finance library: [yfinance](https://pypi.org/project/yfinance/) <br>
# Robinhood Stocks library: [robin_stocks](http://www.robin-stocks.com/en/latest/functions.html) <br>

# %% [markdown]
# ## Inputs

# %% [markdown]
# ### Below are the inputs to perform the analysis

# %%
s_list='AM AAPL AMZN FB NVDA NFLX MSFT QCOM PYPL GOOGL TWTR TSLA ZNGA INFY JCI JMIA SSL INTC AMD TSM HRB KO ALTR SQ SPCE INO NIO WKHS SOLO MVIS MRNA JNJ CLX PFE RBLX FCEL CLNE UUUU CARR EH XPEV HON RTX V MA OTIS IDEX GEVO NOK BB SLV PAAS HGSH AG ACB DG DUK SOXX VEGI IEHS MCD IYJ IYR VICE XHS XHB PK IAK SLVP SKYY MSOS ARKG ARKK ARKX ARKQ VXRT SNDL PLTR POTX M WMT KSS NFLX DKS UBER UONE GNUS TOPS DIS ABNB SBUX LYFT GSAT SENS CPRX NBEV PPBT COST SPY NDAQ INDF VWO GOVT BND VT IEF VTI VOO DIA VGK XLK IAU QQQ BETZ COIN GLD GLDG H T NCLH RKT F GM AAL UAL BA BAC JPM AXP GE FUBO SNAP BRK-B QSR XLE XES AMC GRPN GME TTM H MRO OSK TLRY KOSS GPRO VWAGY MMM DMYI AMRS DMLRY BTC-USD ETH-USD DOGE-USD RIOT MARA KO PEP AWK'  # List of "listings" to be analyzed
#s_list='BTC-USD ETH-USD DOGE-USD'
total_investment=7001  # Total investment value in USD
#start='11/27/2020'  # Start date of interest
start='20w'
end='02/08/2022'  # End date of interest
datetime_query=['12/28/2021'] # Datetime query values (for prediction)
pricetype='Close' # Open, Close, Low, High
smooth_factor=1/7
reverse_data='N' # Reverse Data
reverse_weights='N' # Go from lowest weight to highest weight instead of normal highest to lowest
save_port='N' # Save portfolio to csv? 'Y' / 'N'
save_mean='Y' # Save mean equity values? 'Y' / 'N'

# %% [markdown]
# ## Import Libraries

# %%
# Python Version
import sys
sys.version
# Out:
# '3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53) \n[GCC 9.4.0]'

# %%
#Update python standard libraries install
# !pip install --upgrade pip

# library to for array handling
import numpy as np 

# library for dataframes
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Linear Model
import sklearn as sk

# List Functions module
# !pip install listfun
from listfun import Listoper as lst

# Math Module
import math as m

# Matplotlib and associated plotting modules
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# Machine-Learning and analysis modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

! pip install expsolver;
from expsolver import Solver as solve

# Module to handle XML and HTML 
! pip install lxml;

#Finance information import (Link in "Yahoo Finance" Markdown Cell in the "References" Section)
# !pip install yfinance;
import yfinance as yf;

#Robinhood stocks functions
# !pip install robin_stocks;
import robin_stocks as r;

print('Libraries imported.')
# Out:
# Requirement already satisfied: pip in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (22.0.3)
# Requirement already satisfied: listfun in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (1.2)
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:35: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:597: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:836: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, fit_path=True,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:862: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, positive=False):
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1097: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1344: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   max_n_alphas=1000, n_jobs=None, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:1480: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, copy_X=True, positive=False):
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:152: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   precompute=False, eps=np.finfo(np.float).eps,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:320: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=np.finfo(np.float).eps, random_state=None,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/sklearn/linear_model/randomized_l1.py:580: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   eps=4 * np.finfo(np.float).eps, n_jobs=None,
# Requirement already satisfied: expsolver in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.5)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.6.4)
# Requirement already satisfied: yfinance in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (1.3.4)
# Requirement already satisfied: lxml>=4.5.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (4.6.4)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (1.21.4)
# Requirement already satisfied: requests>=2.26 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.26->yfinance) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2.0.8)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: robin_stocks in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: python-dotenv in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from robin_stocks) (0.19.2)
# Requirement already satisfied: pyotp in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from robin_stocks) (2.6.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from robin_stocks) (2.26.0)
# Requirement already satisfied: cryptography in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from robin_stocks) (36.0.0)
# Requirement already satisfied: cffi>=1.12 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from cryptography->robin_stocks) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->robin_stocks) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->robin_stocks) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->robin_stocks) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests->robin_stocks) (2.0.8)
# Requirement already satisfied: pycparser in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from cffi>=1.12->cryptography->robin_stocks) (2.21)
# Libraries imported.

# %% [markdown]
# ## Import Data into DataFrame

# %%
# Sample interval = 1 day
sample_interval ='1d'

# %%
end=pd.to_datetime(end)
if len(start)<=4:
    start=end-pd.to_timedelta(start)
else:
    start=pd.to_datetime(start)
print('Start: {}, End: {}'.format(start,end))
# Out:
# Start: 2021-09-21 00:00:00, End: 2022-02-08 00:00:00

# %%
# Calculate number of days
num_days=m.floor(pd.to_timedelta(end-start).total_seconds()/(24*3600))
num_days
# Out:
# 140

# %%
smooth_window=m.floor(num_days*smooth_factor)
if smooth_window<1:
    smooth_window=1
#sample_interval='{}d'.format(sample_interval)
# smooth_window=1;
print(smooth_window)
# Out:
# 20

# %% [markdown]
# ### Create basic dataframe "df_info" containing all the available stocks information

# %%
# Create list of stock names as specified by the User
s_list=s_list.split(' ')
s_list=list(set(s_list))

# %%
# Initialize Basic Dataframe as empty
df_info=pd.DataFrame() 

# Add Shares information for List of stock names
for item in s_list:
    try:
        data=yf.Ticker(item)
        df_data=data.history(start=start ,end=end )
        df_data=df_data.reset_index()
        df_data['Name']=pd.DataFrame([item for i in range(0,len(df_data))])
    except:
        print(item)
        continue
    df_info=pd.concat([df_info,df_data])
### Display Initial basic information ####
df_info.head()
# Out:
# - DMYI: No data found, symbol may be delisted
# DMYI
#         Date        Open        High         Low       Close     Volume  \
# 0 2021-09-21  165.809998  166.630005  165.490005  166.039993  7181500.0
# 1 2021-09-22  165.889999  167.149994  165.029999  165.419998  9777800.0
# 2 2021-09-23  164.100006  164.199997  163.270004  163.509995  8451900.0
# 3 2021-09-24  163.000000  164.000000  162.740005  163.300003  6937500.0
# 4 2021-09-27  163.850006  164.360001  163.509995  163.639999  4943000.0
#
#    Dividends  Stock Splits Name
# 0        0.0             0  GLD
# 1        0.0             0  GLD
# 2        0.0             0  GLD
# 3        0.0             0  GLD
# 4        0.0             0  GLD

# %%
# Reverse?#
if reverse_data=='Y':
    df_info=df_info[::-1];
# Display basic information
df_info.head()
# Out:
#         Date        Open        High         Low       Close     Volume  \
# 0 2021-09-21  165.809998  166.630005  165.490005  166.039993  7181500.0
# 1 2021-09-22  165.889999  167.149994  165.029999  165.419998  9777800.0
# 2 2021-09-23  164.100006  164.199997  163.270004  163.509995  8451900.0
# 3 2021-09-24  163.000000  164.000000  162.740005  163.300003  6937500.0
# 4 2021-09-27  163.850006  164.360001  163.509995  163.639999  4943000.0
#
#    Dividends  Stock Splits Name
# 0        0.0             0  GLD
# 1        0.0             0  GLD
# 2        0.0             0  GLD
# 3        0.0             0  GLD
# 4        0.0             0  GLD

# %%
# Size of Data:
print('Size of the full dataset is: {} by {}'.format(df_info.shape[0],df_info.shape[1]))
# Out:
# Size of the full dataset is: 15177 by 9

# %% [markdown]
# ## Exploratory Pre-Processing Analysis

# %% [markdown]
# ### Create Dataframe (df) of Relevant share Price vs. date, which will be the data looked at in this analysis

# %%
# Create new Dataframe of relevant Share Prices
if reverse_data=='Y':
    datevalues=df_info['Date'].sort_values(ascending=False).drop_duplicates().tolist()
else:
    datevalues=df_info['Date'].sort_values().drop_duplicates().tolist()
    
df=pd.DataFrame(index=datevalues,columns=s_list)
for item in s_list:
    df_item=df_info[df_info['Name']==item]
    for ind in df.index.tolist():
    #df[['Date',item]]=df_info.loc[df_info['Name']==item,['Date',pricetype]]
        try:
            df.loc[ind,item]=df_item.loc[df_item['Date']==ind,pricetype].values[0]
        except:
            pass
    df[item].fillna(method='bfill',inplace=True)
    df[item].fillna(method='ffill',inplace=True)
df['Mean']=df.mean(axis=1)

# Smoothing

df_unsmoothed=df.copy()

df=df.rolling(window=smooth_window).mean()

df.dropna(how='all',axis=1,inplace=True)
# 2021-10-16  98.854186  153.279234  8.5505  10.7385  168.753500  58.250827
# 2021-10-17  98.964609  153.545932  8.5275  10.6310  168.656501  58.544006
# 2021-10-18  99.103752  153.895570  8.5425  10.5530  168.843501  58.853668
#
#                  SLVP        Mean
# 2021-10-09  12.471744  455.245879
# 2021-10-10  12.462789  459.943169
# 2021-10-11  12.453833  465.554239
# 2021-10-12  12.452340  469.560024
# 2021-10-13  12.488163  473.558297
# 2021-10-14  12.544385  478.411095
# 2021-10-15  12.594138  484.801611
# 2021-10-16  12.631951  490.815219
# 2021-10-17  12.669764  497.402731
# 2021-10-18  12.710064  504.717467

# %% [markdown]
# ### Display basic information about this dataset

# %%
# Display basic statistics of the opening prices
# Darker cells denote higher values
df.describe().style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style type="text/css">
# #T_641a0_row0_col0, #T_641a0_row0_col1, #T_641a0_row0_col2, #T_641a0_row0_col3, #T_641a0_row0_col4, #T_641a0_row0_col5, #T_641a0_row0_col6, #T_641a0_row0_col7, #T_641a0_row0_col8, #T_641a0_row0_col9, #T_641a0_row0_col10, #T_641a0_row0_col11, #T_641a0_row0_col12, #T_641a0_row0_col13, #T_641a0_row0_col14, #T_641a0_row0_col15, #T_641a0_row0_col16, #T_641a0_row0_col17, #T_641a0_row0_col18, #T_641a0_row0_col19, #T_641a0_row0_col20, #T_641a0_row0_col21, #T_641a0_row0_col22, #T_641a0_row0_col23, #T_641a0_row0_col24, #T_641a0_row0_col25, #T_641a0_row0_col26, #T_641a0_row0_col27, #T_641a0_row0_col28, #T_641a0_row0_col29, #T_641a0_row0_col30, #T_641a0_row0_col31, #T_641a0_row0_col32, #T_641a0_row0_col33, #T_641a0_row0_col34, #T_641a0_row0_col35, #T_641a0_row0_col36, #T_641a0_row0_col37, #T_641a0_row0_col38, #T_641a0_row0_col39, #T_641a0_row0_col40, #T_641a0_row0_col41, #T_641a0_row0_col42, #T_641a0_row0_col43, #T_641a0_row0_col44, #T_641a0_row0_col45, #T_641a0_row0_col46, #T_641a0_row0_col47, #T_641a0_row0_col48, #T_641a0_row0_col49, #T_641a0_row0_col50, #T_641a0_row0_col51, #T_641a0_row0_col52, #T_641a0_row0_col53, #T_641a0_row0_col54, #T_641a0_row0_col55, #T_641a0_row0_col56, #T_641a0_row0_col57, #T_641a0_row0_col58, #T_641a0_row0_col59, #T_641a0_row0_col60, #T_641a0_row0_col61, #T_641a0_row0_col62, #T_641a0_row0_col63, #T_641a0_row0_col64, #T_641a0_row0_col65, #T_641a0_row0_col66, #T_641a0_row0_col67, #T_641a0_row0_col68, #T_641a0_row0_col69, #T_641a0_row0_col70, #T_641a0_row0_col71, #T_641a0_row0_col72, #T_641a0_row0_col73, #T_641a0_row0_col74, #T_641a0_row0_col75, #T_641a0_row0_col76, #T_641a0_row0_col77, #T_641a0_row0_col78, #T_641a0_row0_col79, #T_641a0_row0_col80, #T_641a0_row0_col81, #T_641a0_row0_col82, #T_641a0_row0_col83, #T_641a0_row0_col84, #T_641a0_row0_col85, #T_641a0_row0_col86, #T_641a0_row0_col87, #T_641a0_row0_col88, #T_641a0_row0_col89, #T_641a0_row0_col90, #T_641a0_row0_col91, #T_641a0_row0_col92, #T_641a0_row0_col93, #T_641a0_row0_col94, #T_641a0_row0_col95, #T_641a0_row0_col96, #T_641a0_row0_col97, #T_641a0_row0_col98, #T_641a0_row0_col99, #T_641a0_row0_col100, #T_641a0_row0_col101, #T_641a0_row0_col102, #T_641a0_row0_col103, #T_641a0_row0_col104, #T_641a0_row0_col105, #T_641a0_row0_col106, #T_641a0_row0_col107, #T_641a0_row0_col108, #T_641a0_row0_col109, #T_641a0_row0_col110, #T_641a0_row0_col111, #T_641a0_row0_col112, #T_641a0_row0_col113, #T_641a0_row0_col114, #T_641a0_row0_col115, #T_641a0_row0_col116, #T_641a0_row0_col117, #T_641a0_row0_col118, #T_641a0_row0_col119, #T_641a0_row0_col120, #T_641a0_row0_col121, #T_641a0_row0_col122, #T_641a0_row0_col123, #T_641a0_row0_col124, #T_641a0_row0_col125, #T_641a0_row0_col126, #T_641a0_row0_col127, #T_641a0_row0_col128, #T_641a0_row0_col129, #T_641a0_row0_col130, #T_641a0_row0_col131, #T_641a0_row0_col132, #T_641a0_row0_col133, #T_641a0_row0_col134, #T_641a0_row0_col135, #T_641a0_row0_col136, #T_641a0_row0_col137, #T_641a0_row0_col138, #T_641a0_row0_col139, #T_641a0_row0_col140, #T_641a0_row0_col141, #T_641a0_row0_col142, #T_641a0_row0_col143, #T_641a0_row0_col144, #T_641a0_row0_col145, #T_641a0_row0_col146, #T_641a0_row0_col147, #T_641a0_row0_col148, #T_641a0_row0_col149, #T_641a0_row0_col150, #T_641a0_row0_col151, #T_641a0_row0_col152, #T_641a0_row0_col153, #T_641a0_row0_col154, #T_641a0_row0_col155, #T_641a0_row1_col0, #T_641a0_row1_col1, #T_641a0_row1_col2, #T_641a0_row1_col3, #T_641a0_row1_col4, #T_641a0_row1_col6, #T_641a0_row1_col7, #T_641a0_row1_col8, #T_641a0_row1_col9, #T_641a0_row1_col10, #T_641a0_row1_col12, #T_641a0_row1_col13, #T_641a0_row1_col14, #T_641a0_row1_col15, #T_641a0_row1_col16, #T_641a0_row1_col17, #T_641a0_row1_col18, #T_641a0_row1_col19, #T_641a0_row1_col20, #T_641a0_row1_col21, #T_641a0_row1_col22, #T_641a0_row1_col23, #T_641a0_row1_col24, #T_641a0_row1_col25, #T_641a0_row1_col27, #T_641a0_row1_col28, #T_641a0_row1_col29, #T_641a0_row1_col30, #T_641a0_row1_col31, #T_641a0_row1_col32, #T_641a0_row1_col33, #T_641a0_row1_col35, #T_641a0_row1_c ...

# %% [markdown]
# ### Create basic Time plot to look at pertinent information

# %%
df_info.head()
# Out:
#         Date        Open        High         Low       Close     Volume  \
# 0 2021-09-21  165.809998  166.630005  165.490005  166.039993  7181500.0
# 1 2021-09-22  165.889999  167.149994  165.029999  165.419998  9777800.0
# 2 2021-09-23  164.100006  164.199997  163.270004  163.509995  8451900.0
# 3 2021-09-24  163.000000  164.000000  162.740005  163.300003  6937500.0
# 4 2021-09-27  163.850006  164.360001  163.509995  163.639999  4943000.0
#
#    Dividends  Stock Splits Name
# 0        0.0             0  GLD
# 1        0.0             0  GLD
# 2        0.0             0  GLD
# 3        0.0             0  GLD
# 4        0.0             0  GLD

# %%
# Plot Open price vs. Time
ax= plt.subplot()
for item in df_price.columns:
    plt.plot(df_price[item])
if reverse_data=='Y':
    ax.invert_xaxis()
    
plt.xticks(rotation=45)
ax.legend(df_price.columns)
plt.ylabel('Share Price [USD]')
ax.grid(True)

# %% [markdown]
# ## What kind of Growth % do we see with the various listings?

# %% [markdown]
# ### Normalize the opening price to determine Growth % over the period of interest

# %% [markdown]
# Normalize w.r.t. start price (df_start) <br>
# Normalization used: (price-start_price)/start_price*100 to obtain df_norm

# %%
# Normalization Function
def df_normalize(df):
    df_strt=df.iloc[0,:]
    df_norm=(df.iloc[:,:]-df_strt)/df_strt*100
    df_strt=pd.DataFrame(df_strt).transpose()
    df_strt.set_axis(['start_price'],axis=0,inplace=True)
    return [df_norm,df_strt]

# Store Normalized values in DataFrame and display results                          
[df_norm,df_start]=df_normalize(df)
df_norm.head()
# Out:
#                  GLD       AMD         M         F      SOLO   BTC-USD  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10 -0.064527  0.089581  0.132034  0.822024 -0.215177  1.513742
# 2021-10-11 -0.129055  0.179162  0.264068  1.644049 -0.430355  3.319224
# 2021-10-12 -0.152187  0.210949  0.296536  2.497963 -0.516425  4.659703
# 2021-10-13 -0.028002  0.355917  0.145021  3.135740 -0.645532  6.004424
#
#                  INO       CLX     VWAGY        KO        PK      COST  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10 -0.740482 -0.048084  0.003202  0.016821 -0.020349 -0.026701
# 2021-10-11 -1.480964 -0.096169  0.006403  0.033643 -0.040699 -0.053401
# 2021-10-12 -2.088718 -0.072735 -0.088045  0.042988 -0.200952 -0.113893
# 2021-10-13 -2.815229 -0.123254 -0.150477  0.061678 -0.600310 -0.196765
#
#                 MARA      GSAT      FUBO       WMT  DOGE-USD      ARKQ  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10  1.373676 -0.560398  0.050667 -0.124703  0.651049 -0.124900
# 2021-10-11  2.747353 -1.120797  0.101334 -0.249407  1.340513 -0.249800
# 2021-10-12  3.476589 -1.494396  0.030400 -0.367678  1.371824 -0.398671
# 2021-10-13  4.337257 -1.930261  0.293867 -0.524896  1.546927 -0.570250
#
#                 ALTR      VICE       AXP        AG      QCOM      SPCE  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10 -0.152156  0.241708  0.307869 -0.426384 -0.262269 -0.410306
# 2021-10-11 -0.304311  0.483417  0.615738 -0.852767 -0.524538 -0.820612
# 2021-10-12 -0.488721  0.685371  0.843420 -1.209537 -0.911971 -1.241331
# 2021-10-13 -0.635267  0.820109  0.721082 -1.092064 -1.253576 -1.639140
#
#                 GNUS      UUUU        DG       XHB       KSS       IYJ  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10 -0.398984 -0.365699 -0.219014 -0.117042 -0.781795  0.037207
# 2021-10-11 -0.797969 -0.731398 -0.438029 -0.234084 -1.563590  0.074414
# 2021-10-12 -1.051868 -0.231361 -0.680569 -0.408286 -2.395475  0.048959
# 2021-10-13 -1.450852  0.395552 -0.880838 -0.572961 -3.395308 -0.062453
#
#                  MMM        GE      GOVT       UAL        BA      POTX  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 
0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10 -0.153679 -0.132091 -0.016755  0.009020 -0.654635  0.444307
# 2021-10-11 -0.307358 -0.264181 -0.033509  0.018040 -1.309271  0.888615
# 2021-10-12 -0.506386 -0.456762 -0.101478 -0.044174 -1.839056  1.205130
# 2021-10-13 -0.738165 -0.631443 -0.117783 -0.139461 -2.349684  1.229072
#
#                 AMZN      INDF       TSM      CPRX       BAC       XLK  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10 -0.147021 -0.069890 -0.208927  1.344834  0.544184 -0.043403
# 2021-10-11 -0.294042 -0.139780 -0.417854  2.689668  1.088368 -0.086806
# 2021-10-12 -0.494521 -0.208866 -0.714352  3.969580  1.486267 -0.224578
# 2021-10-13 -0.693490 -0.329597 -0.990403  4.980523  1.655958 -0.400162
#
#                  AMC       QSR       RTX      JMIA       GME       OSK  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10 -0.206188 -0.056324  0.388225 -0.058452 -0.328983 -0.216208
# 2021-10-11 -0.412376 -0.112648  0.776450 -0.116904 -0.657965 -0.432416
# 2021-10-12 -0.840513 -0.226905  1.031258 -0.148787 -1.055521 -0.696828
# 2021-10-13 -1.112366 -0.379785  1.199031 -0.366652 -1.254854 -1.048583
#
#                 TOPS       NIO      SNAP      SNDL       HRB      VXRT  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10  0.943714  0.105176 -0.169106 -0.125749  0.027582 -0.829957
# 2021-10-11  1.887429  0.210352 -0.338212 -0.251497  0.055164 -1.659914
# 2021-10-12  3.033368  0.183347 -0.558843 -0.502995 -0.017732 -2.594432
# 2021-10-13  3.774858  0.216037 -0.850816 -0.791479 -0.185196 -3.613906
#
#                DMLRY      ZNGA       VTI        MA         T      MRNA  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10  0.797992 -0.194006  0.009272  0.145946 -0.078063 -1.732939
# 2021-10-11  1.595985 -0.388012  0.018544  0.291892 -0.156127 -3.465878
# 2021-10-12  2.199565 -0.568638 -0.025912  0.325722 -0.355792 -5.207552
# 2021-10-13  2.692377 -0.709125 -0.108981  0.164353 -0.612894 -6.996401
#
#                  AAL      MVIS       XHS      NDAQ       DUK       PEP  \
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10  0.088538 -1.113467 -0.299679  0.148988  0.039837  0.088305
# 2021-10-11  0.177075 -2.226935 -0.599358  0.297976  0.079675  0.176610
# 2021-10-12  0.122038 -3.517143 -0.896179  0.374790  0.144221  0.272109
# 2021-10-13 -0.186648 -4.908978 -1.210152  0.422219  0.260203  0.398353
#
#                 CLNE      TLRY      ABNB       XES      SLVP      Mean
# 2021-10-09  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2021-10-10  0.549582 -0.470317 -0.077252  0.931646 -0.071808  1.031814
# 2021-10-11  1.099163 -0.940634 -0.154505  1.863292 -0.143615  2.264350
# 2021-10-12  1.600955 -1.539623 -0.072240  2.738119 -0.155583  3.144267
# 2021-10-13  2.031063 -2.307215 -0.117943  3.428962  0.131647  4.022534

# %%
# Size of Data:
print('Size of the data is: {} by {}'.format(df_norm.shape[0],df_norm.shape[1]))
# Out:
# Size of the data is: 123 by 156

# %%
# Display basic statistics of the normalized prices
# Darker cells denote higher values
df_norm.describe().loc[['count','mean','min','max'],:].style.background_gradient(axis=1).format("{:.1f}")
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_b3fbf_row1_col7, #T_b3fbf_row1_col36, #T_b3fbf_row1_col63, #T_b3fbf_row1_col112, #T_b3fbf_row1_col148 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col8, #T_b3fbf_row1_col117, #T_b3fbf_row2_col24 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col9, #T_b3fbf_row1_col122, #T_b3fbf_row1_col131 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col10 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_b3fbf_row1_col11 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col12, #T_b3fbf_row1_col59 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col13, #T_b3fbf_row2_col95 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_b3fbf_row1_col14 {
#   background-color: #c1cae2;
#   color: #000000;
# }
# #T_b3fbf_row1_col15, #T_b3fbf_row1_col58 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col16, #T_b3fbf_row2_col35, #T_b3fbf_row2_col81 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_b3fbf_row1_col17, #T_b3fbf_row1_col76, #T_b3fbf_row3_col68 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col18, #T_b3fbf_row1_col29, #T_b3fbf_row1_col55, #T_b3fbf_row1_col120, #T_b3fbf_row1_col152, #T_b3fbf_row2_col45 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col19, #T_b3fbf_row2_col74 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col20, #T_b3fbf_row1_col119, #T_b3fbf_row1_col133, #T_b3fbf_row2_col89, #T_b3fbf_row2_col137 {
#   background-color: #7bacd1;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col21, #T_b3fbf_row1_col73, #T_b3fbf_row2_col16 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col22, #T_b3fbf_row2_col46 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col23, #T_b3fbf_row3_col148 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_b3fbf_row1_col24 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_b3fbf_row1_col25 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col26, #T_b3fbf_row1_col78, #T_b3fbf_row2_col43 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col27, #T_b3fbf_row1_col125 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col28, #T_b3fbf_row1_col99, #T_b3fbf_row1_col110 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col30, #T_b3fbf_row1_col43, #T_b3fbf_row1_col153, #T_b3fbf_row2_col13, #T_b3fbf_row2_col111 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col31, #T_b3fbf_row1_col92, #T_b3fbf_row1_col139 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_b3fbf_row1_col32, #T_b3fbf_row1_col37, #T_b3fbf_row1_col79, #T_b3fbf_row1_col100, #T_b3fbf_row1_col116, #T_b3fbf_row3_col93 {
#   background-color: #79abd0;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col33 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_b3fbf_row1_col34, #T_b3fbf_row2_col75, #T_b3fbf_row2_col99, #T_b3fbf_row3_col123 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_b3fbf_row1_col35, #T_b3fbf_row3_col130 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_b3fbf_row1_col38, #T_b3fbf_row1_col128, #T_b3fbf_row3_col99 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_b3fbf_row1_col39, #T_b3fbf_row1_col108, #T_b3fbf_row1_col137, #T_b3fbf_row3_col44 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_b3fbf_row1_col40, #T_b3fbf_row2_col0, #T_b3fbf_row2_col1, #T_b3fbf_row2_col2, #T_b3fbf_row2_col3, #T_b3fbf_row2_col9, #T_b3fbf_row2_col36, #T_b3fbf_row2_col40, #T

# %% [markdown]
# ### Plot trends in Normalized values

# %% [markdown]
# Time Plot

# %%
# Display Growth % over time
ax= plt.subplot()
for item in df_norm.columns:
    plt.plot(df_norm[item])

plt.xticks(rotation=45)
ax.legend(df.columns,loc='upper center')
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## How do the price gains of the listings correlate to each other?

# %% [markdown]
# Correlation Matrix

# %%
sns.heatmap(df_norm.corr());

# %%
ax= plt.subplot()
for item in df_norm.columns:
    plt.scatter(df_norm.iloc[:,0],df_norm[item])

ax.legend(df_norm.columns,loc='upper center')
plt.xlabel('{} Growth %'.format(df_norm.columns[0]))
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## Calculate percent and absolute estimate and bounds of Growth

# %% [markdown]
# ### Create a linear regression fit for the data with thrice the standard dev. of obs.-est. to determine the boundaries

# %% [markdown]
# <b> Linear Regression object, score and price boundaries for each listing </b>

# %%
def lin_obj(df):
    df_lin=df.iloc[0:1,:]
    df_lin.reindex(['fit_obj','score','bound'])
    df_lin.drop(index=df_lin.index[0],inplace=True)
    for item in df_lin.columns:
        # ... (intercept and coeff.) of the fits
        X=np.array(pd.to_numeric(df.index)).reshape(-1, 1)
        Y=(df[item].values).reshape(-1, 1)
        lin_list_coeff=[]
        lin_list_intercept=[]
        for i in range(0,1):
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0)
            lin_obj=LinearRegression()
            lin_obj.fit(X_train,y_train)
            lin_list_coeff.append(lin_obj.coef_)
            lin_list_intercept.append(lin_obj.intercept_)
        linobj = LinearRegression()
        linobj.coef_=np.array(np.array(lin_list_coeff).mean()).reshape(-1)
        linobj.intercept_=np.array(np.array(lin_list_intercept).mean()).reshape(-1)
        score=linobj.score(X,Y)
        df_lin.loc['fit_obj',item]=linobj
        df_lin.loc['score',item]=score

    # Calculate price bounds
    df_est=pd.DataFrame()
    df_est.rename_axis(index='Datetime')
    df_est['Datetime']=df.index
    df_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_lin.loc['fit_obj',item]
        for datetime in df_est.index:
            est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            df_est.loc[datetime,'{}'.format(item)]=est
    for item in df.columns:
        df_diff=df[item]-df_est[item]
        bounds=3*df_diff.std()
        df_lin.loc['bound',item]=bounds
        
    return df_lin

# %% [markdown]
# Convert rise and fall from % to price (using price change= percent change/100*start price) and display.<br>

# %%
# Call lin_obj(...) to create the price estimation object dataframe
df_norm_price_est_obj=lin_obj(df_norm)
df_price_bounds_dict={}
for item in df_norm.columns:
    df_price_bounds_dict[item]=df_norm_price_est_obj.loc['bound',item]*df_start.loc['start_price',item]/100
df_price_bounds=pd.DataFrame(df_price_bounds_dict,index=['price_bounds'])
df_norm_price_est_obj=df_norm_price_est_obj.append(df_price_bounds)
df_norm_price_est_obj
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexing.py:1678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self.obj[key] = empty_value
#                                                             GLD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.297278
# bound                                                  3.021124
# price_bounds                                            4.96283
#
#                                                             AMD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.148039
# bound                                                 40.607856
# price_bounds                                          42.157654
#
#                                                               M  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.000169
# bound                                                 32.422054
# price_bounds                                           7.444467
#
#                                                               F  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.836035
# bound                                                 22.803529
# price_bounds                                           3.185421
#
#                                                            SOLO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.82977
# bound                                                 21.913321
# price_bounds                                           0.763789
#
#                                                         BTC-USD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.602702
# bound                                                 32.072696
# price_bounds                                        14913.91538
#
#                                                             INO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.786768
# bound                                                 20.900435
# price_bounds                                           1.495949
#
#                                                             CLX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.801761
# bound                                                  4.810528
# price_bounds                                           7.795299
#
#                                                           VWAGY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.496571
# bound                                                  8.446262
# price_bounds                                           2.638097
#
#                                                              KO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.871645
# bound                                                  5.252581
# price_bounds                                           2.788689
#
#                                                              PK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.218058
# bound                                                  8.681536
# price_bounds                                           1.706486
#
#                                                            COST  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.367354
# bound                                                 18.506142
# price_bounds                                          83.257134
#
#                                                            MARA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.470111
# bound                                                 74.945809
# price_bounds                                          26.515452
#
#                                                            GSAT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.893688
# bound                                                 13.443599
# price_bounds                                           0.215904
#
#                                                            FUBO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.831915
# bound                                                  32.92375
# price_bounds                                           8.122618
#
#                                                             WMT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.032157
# bound                                                  6.238652
# price_bounds                                           8.694893
#
#                                                        DOGE-USD  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.776268
# bound                                                 25.959835
# price_bounds                                           0.057374
#
#                                                            ARKQ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.543254
# bound                                                 15.488845
# price_bounds                                          12.180358
#
#                                                            ALTR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.422424
# bound                                                  16.55491
# price_bounds                                          11.805058
#
#                                                            VICE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.685762
# bound                                                  5.187689
# price_bounds                                           1.709496
#
#                                                             AXP  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.253109
# bound                                                  9.059773
# price_bounds                                           15.54992
#
#                                                              AG  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.461048
# bound                                                  19.27515
# price_bounds                                           2.214298
#
#                                                            QCOM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.699073
# bound                                                 27.717733
# price_bounds                                          35.849992
#
#                                                            SPCE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.987019
# bound                                                  6.134733
# price_bounds                                           1.472735
#
#                                                            GNUS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.841901
# bound                                                 15.861331
# price_bounds                                           0.218648
#
#                                                            UUUU  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.099537
# bound                                                 45.429613
# price_bounds                                           3.043557
#
#                                                              DG  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.13909
# bound                                                  8.311151
# price_bounds                                          17.650876
#
#                                                             XHB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.116654
# bound                                                 14.938082
# price_bounds                                          10.958574
#
#                                                             KSS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.065204
# bound                                                 20.168629
# price_bounds                                          10.217284
#
#                                                             IYJ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.109497
# bound                                                  4.492728
# price_bounds                                           4.892483
#
#                                                             MMM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.314259
# bound                                                  3.620882
# price_bounds                                           6.416632
#
#                                                              GE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.524336
# bound                                                  9.012158
# price_bounds                                           9.336455
#
#                                                            GOVT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.316328
# bound                                                  1.727002
# price_bounds                                           0.457163
#
#                                                             UAL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.540031
# bound                                                 10.881924
# price_bounds                                           5.317126
#
#                                                              BA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.36582
# bound                                                  8.655579
# price_bounds                                          19.210104
#
#                                                            POTX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.926555
# bound                                                 12.388357
# price_bounds                                           1.080256
#
#                                                            VEGI  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.454444
# bound                                                  4.455323
# price_bounds                                           1.739914
#
#                                                             BND  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.470549
# bound                                                  1.633647
# price_bounds                                           1.387154
#
#                                                            OTIS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.462197
# bound                                                   3.13953
# price_bounds                                           2.606015
#
#                                                            NCLH  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.715726
# bound                                                  15.37432
# price_bounds                                           4.181969
#
#                                                             TTM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.287269
# bound                                                 24.961359
# price_bounds                                           5.713905
#
#                                                            IDEX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.921193
# bound                                                 14.502861
# price_bounds                                           0.288679
#
#                                                              GM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.003972
# bound                                                 13.368439
# price_bounds                                           7.140885
#
#                                                            NFLX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.583446
# bound                                                 22.411372
# price_bounds                                         135.391692
#
#                                                            AAPL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.80178
# bound                                                 11.450056
# price_bounds                                          16.334566
#
#                                                            ARKK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.829368
# bound                                                  16.51253
# price_bounds                                          18.485909
#
#                                                             SSL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.021356
# bound                                                 22.011288
# price_bounds                                           3.981402
#
#                                                           GOOGL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.05395
# bound                                                  8.705983
# price_bounds                                         240.101433
#
#                                                            PPBT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.731301
# bound                                                 13.957301
# price_bounds                                           0.641408
#
#                                                            AMRS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.853144
# bound                                                 31.684421
# price_bounds                                           4.206582
#
#                                                            PAAS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.288792
# bound                                                 13.499746
# price_bounds                                           3.175931
#
#                                                            TSLA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.133039
# bound                                                 36.482753
# price_bounds                                         283.130791
#
#                                                             VOO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.232447
# bound                                                  6.839345
# price_bounds                                          27.305511
#
#                                                            SOXX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.363998
# bound                                                 17.335159
# price_bounds                                          78.338051
#
#                                                              VT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.000023
# bound                                                  5.299712
# price_bounds                                            5.42456
#
#                                                            GRPN  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.014342
# bound                                                 14.032171
# price_bounds                                           3.258621
#
#                                                           BRK-B  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.762096
# bound                                                  6.503228
# price_bounds                                          18.031891
#
#                                                            LYFT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.824166
# bound                                                 11.984497
# price_bounds                                            6.53221
#
#                                                             IAU  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.303972
# bound                                                  3.025151
# price_bounds                                           1.011399
#
#                                                            RBLX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.00553
# bound                                                 65.593516
# price_bounds                                          50.637538
#
#                                                             IYR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.271083
# bound                                                  7.038705
# price_bounds                                           7.263897
#
#                                                             DIS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.797282
# bound                                                   8.25131
# price_bounds                                          14.414378
#
#                                                            NBEV  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.86665
# bound                                                  19.20435
# price_bounds                                           0.270781
#
#                                                             DIA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.146506
# bound                                                  4.489628
# price_bounds                                          15.363773
#
#                                                             RKT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.717933
# bound                                                 12.156323
# price_bounds                                            1.95267
#
#                                                            NVDA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.144827
# bound                                                 47.315629
# price_bounds                                          99.255566
#
#                                                             QQQ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.011015
# bound                                                 11.372825
# price_bounds                                          41.196335
#
#                                                            SENS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.69642
# bound                                                 19.182783
# price_bounds                                           0.651927
#
#                                                            XPEV  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.036702
# bound                                                 31.029393
# price_bounds                                          11.141104
#
#                                                             VWO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.356658
# bound                                                  3.607221
# price_bounds                                           1.791967
#
#                                                              SQ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.935935
# bound                                                 14.214486
# price_bounds                                          34.817814
#
#                                                            IEHS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.032234
# bound                                                  6.945286
# price_bounds                                           2.940733
#
#                                                             IAK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.422269
# bound                                                  5.534184
# price_bounds                                            4.36451
#
#                                                             VGK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.00002
# bound                                                  5.005197
# price_bounds                                           3.296877
#
# ...
# score                                                  0.911264
# bound                                                   9.31375
# price_bounds                                           2.857226
#
#                                                            HGSH  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.387455
# bound                                                 33.619776
# price_bounds                                           0.527494
#
#                                                            CARR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.19633
# bound                                                 10.908012
# price_bounds                                           5.682362
#
#                                                              EH  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.744161
# bound                                                 24.837706
# price_bounds                                           5.948382
#
#                                                             SLV  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.080146
# bound                                                  8.890905
# price_bounds                                           1.852598
#
#                                                            UBER  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.67358
# bound                                                 12.003204
# price_bounds                                           5.530776
#
#                                                            ARKX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.709783
# bound                                                 10.059315
# price_bounds                                           1.996422
#
#                                                             JNJ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.745084
# bound                                                  3.836926
# price_bounds                                           6.175733
#
#                                                            SKYY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.651097
# bound                                                 12.283329
# price_bounds                                          13.099131
#
#                                                             HON  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.506755
# bound                                                  5.784789
# price_bounds                                          12.452322
#
#                                                            ARKG  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.890619
# bound                                                 11.953866
# price_bounds                                           8.991303
#
#                                                             JPM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.704932
# bound                                                   5.52625
# price_bounds                                           9.010917
#
#                                                            AMZN  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.235125
# bound                                                  12.21407
# price_bounds                                         404.293705
#
#                                                            INDF  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.424725
# bound                                                  6.743313
# price_bounds                                           2.473945
#
#                                                             TSM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.841296
# bound                                                  5.972533
# price_bounds                                           6.690201
#
#                                                            CPRX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.04092
# bound                                                 28.200989
# price_bounds                                           1.520315
#
#                                                             BAC  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.06249
# bound                                                  8.959041
# price_bounds                                            3.80937
#
#                                                             XLK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.267368
# bound                                                 11.389018
# price_bounds                                          17.285894
#
#                                                             AMC  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.832626
# bound                                                 25.806356
# price_bounds                                           9.824996
#
#                                                             QSR  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.377946
# bound                                                  5.884926
# price_bounds                                           3.623209
#
#                                                             RTX  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.006272
# bound                                                   8.39663
# price_bounds                                            7.28922
#
#                                                            JMIA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.929713
# bound                                                 15.913712
# price_bounds                                           2.994801
#
#                                                             GME  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.60664
# bound                                                  35.19209
# price_bounds                                           63.38113
#
#                                                             OSK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.698381
# bound                                                  8.425651
# price_bounds                                           8.798434
#
#                                                            TOPS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.958284
# bound                                                 10.337594
# price_bounds                                           0.153358
#
#                                                             NIO  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.646687
# bound                                                 26.066659
# price_bounds                                            9.16999
#
#                                                            SNAP  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.911691
# bound                                                 14.184874
# price_bounds                                          10.736815
#
#                                                            SNDL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.621186
# bound                                                 18.273747
# price_bounds                                           0.123521
#
#                                                             HRB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.766628
# bound                                                  4.310636
# price_bounds                                           1.081501
#
#                                                            VXRT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.689137
# bound                                                 14.389428
# price_bounds                                           1.100935
#
#                                                           DMLRY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.409548
# bound                                                 17.316424
# price_bounds                                           3.830047
#
#                                                            ZNGA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.067276
# bound                                                 31.762694
# price_bounds                                           2.373944
#
#                                                             VTI  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.014597
# bound                                                  7.246203
# price_bounds                                          16.280004
#
#                                                              MA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.256413
# bound                                                  8.587449
# price_bounds                                          29.956511
#
#                                                               T  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.003777
# bound                                                 13.368153
# price_bounds                                           3.496577
#
#                                                            MRNA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.841095
# bound                                                 16.977868
# price_bounds                                          63.162254
#
#                                                             AAL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.722629
# bound                                                   9.91413
# price_bounds                                           2.071558
#
#                                                            MVIS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.983204
# bound                                                  7.871474
# price_bounds                                           0.890736
#
#                                                             XHS  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.461057
# bound                                                 10.268727
# price_bounds                                          10.769142
#
#                                                            NDAQ  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.260967
# bound                                                 11.937978
# price_bounds                                          23.093866
#
#                                                             DUK  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.728918
# bound                                                  2.756956
# price_bounds                                           2.707209
#
#                                                             PEP  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.958623
# bound                                                  2.750327
# price_bounds                                           4.176479
#
#                                                            CLNE  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.875675
# bound                                                  15.64378
# price_bounds                                           1.309384
#
#                                                            TLRY  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.820779
# bound                                                 22.530663
# price_bounds                                            2.53898
#
#                                                            ABNB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.28803
# bound                                                 17.038643
# price_bounds                                          28.893024
#
#                                                             XES  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.102953
# bound                                                 20.292961
# price_bounds                                          11.238032
#
#                                                            SLVP  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.309463
# bound                                                 14.625449
# price_bounds                                           1.824049
#
#                                                            Mean
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.556192
# bound                                                 25.370997
# price_bounds                                          115.50042

# %% [markdown]
# ### Estimate the price and bounds vs. date using the fit object

# %%
# Function to estimate the price given the price dataframe, fit objects and datetime query
def price_est(df,df_norm_price_est_obj,df_strt,datetime_query):
    df_price_est=pd.DataFrame()
    df_price_est.rename_axis(index='Datetime')
    df_price_est['Datetime']=pd.to_datetime(datetime_query)
    df_price_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_norm_price_est_obj.loc['fit_obj',item]
        for datetime in df_price_est.index:
            norm_price_est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            price_est=norm_price_est*df_strt.loc['start_price',item]/100+df_strt.loc['start_price',item]
            df_price_est.loc[datetime,'{}'.format(item)]=price_est
            df_price_est.loc[datetime,'{}_low'.format(item)]=price_est-(df_norm_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_high'.format(item)]=price_est+(df_norm_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_lo_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_low'.format(item)]].mean()
            df_price_est.loc[datetime,'{}_hi_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_high'.format(item)]].mean()
            df_price_est.loc[datetime,'{}_lo_ratio'.format(item)]=df_price_est.loc[datetime,'{}_low'.format(item)]/price_est
    df_price_est.reindex(df_price_est.index.date)
    df_price_est=df_price_est
    return df_price_est

# %% [markdown]
# ## What is the predicted share price?

# %%
df_price_est=price_est(df_price,df_norm_price_est_obj,df_start,datetime_query)
df_price_est.style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style type="text/css">
# #T_61d69_row0_col0, #T_61d69_row0_col1, #T_61d69_row0_col2, #T_61d69_row0_col3, #T_61d69_row0_col4, #T_61d69_row0_col5, #T_61d69_row0_col6, #T_61d69_row0_col7, #T_61d69_row0_col8, #T_61d69_row0_col9, #T_61d69_row0_col10, #T_61d69_row0_col11, #T_61d69_row0_col12, #T_61d69_row0_col13, #T_61d69_row0_col14, #T_61d69_row0_col15, #T_61d69_row0_col16, #T_61d69_row0_col17, #T_61d69_row0_col18, #T_61d69_row0_col19, #T_61d69_row0_col20, #T_61d69_row0_col21, #T_61d69_row0_col22, #T_61d69_row0_col23, #T_61d69_row0_col24, #T_61d69_row0_col25, #T_61d69_row0_col26, #T_61d69_row0_col27, #T_61d69_row0_col28, #T_61d69_row0_col29, #T_61d69_row0_col35, #T_61d69_row0_col36, #T_61d69_row0_col37, #T_61d69_row0_col38, #T_61d69_row0_col39, #T_61d69_row0_col40, #T_61d69_row0_col41, #T_61d69_row0_col42, #T_61d69_row0_col43, #T_61d69_row0_col44, #T_61d69_row0_col45, #T_61d69_row0_col46, #T_61d69_row0_col47, #T_61d69_row0_col48, #T_61d69_row0_col49, #T_61d69_row0_col50, #T_61d69_row0_col51, #T_61d69_row0_col52, #T_61d69_row0_col53, #T_61d69_row0_col54, #T_61d69_row0_col55, #T_61d69_row0_col56, #T_61d69_row0_col57, #T_61d69_row0_col58, #T_61d69_row0_col59, #T_61d69_row0_col60, #T_61d69_row0_col61, #T_61d69_row0_col62, #T_61d69_row0_col63, #T_61d69_row0_col64, #T_61d69_row0_col65, #T_61d69_row0_col71, #T_61d69_row0_col72, #T_61d69_row0_col73, #T_61d69_row0_col74, #T_61d69_row0_col75, #T_61d69_row0_col76, #T_61
# %% [markdown]
# ## What kind of volatility do the listings have?

# %% [markdown]
# ## How do we generate our investment portfolio?

# %% [markdown]
# ### Estimate the price history along with the bounds and plot the history and estimates for each listing

# %%
# Datetime history query values
datetime_query_start_end=pd.date_range(start=start,end=end)

# %%
# Generate and display estimates (listing, listing_low, listing_high)
df_price_est_start_end=price_est(df_price,df_norm_price_est_obj,df_start,datetime_query_start_end)
df_price_est_start_end.head().style.format("{:.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1549_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >GLD</th>
#       <th class="col_heading level0 col1" >GLD_low</th>
#       <th class="col_heading level0 col2" >GLD_high</th>
#       <th class="col_heading level0 col3" >GLD_lo_mid</th>
#       <th class="col_heading level0 col4" >GLD_hi_mid</th>
#       <th class="col_heading level0 col5" >GLD_lo_ratio</th>
#       <th class="col_heading level0 col6" >AMD</th>
#       <th class="col_heading level0 col7" >AMD_low</th>
#       <th class="col_heading level0 col8" >AMD_high</th>
#       <th class="col_heading level0 col9" >AMD_lo_mid</th>
#       <th class="col_heading level0 col10" >AMD_hi_mid</th>
#       <th class="col_heading level0 col11" >AMD_lo_ratio</th>
#       <th class="col_heading level0 col12" >M</th>
#       <th class="col_heading level0 col13" >M_low</th>
#       <th class="col_heading level0 col14" >M_high</th>
#       <th class="col_heading level0 col15" >M_lo_mid</th>
#       <th class="col_heading level0 col16" >M_hi_mid</th>
#       <th class="col_heading level0 col17" >M_lo_ratio</th>
#       <th class="col_heading level0 col18" >F</th>
#       <th class="col_heading level0 col19" >F_low</th>
#       <th class="col_heading level0 col20" >F_high</th>
#       <th class="col_heading level0 col21" >F_lo_mid</th>
#       <th class="col_heading level0 col22" >F_hi_mid</th>
#       <th class="col_heading level0 col23" >F_lo_ratio</th>
#       <th class="col_heading level0 col24" >SOLO</th>
#       <th class="col_heading level0 col25" >SOLO_low</th>
#       <th class="col_heading level0 col26" >SOLO_high</th>
#       <th class="col_heading level0 col27" >SOLO_lo_mid</th>
#       <th class="col_heading level0 col28" >SOLO_hi_mid</th>
#       <th class="col_heading level0 col29" >SOLO_lo_ratio</th>
#       <th class="col_heading level0 col30" >BTC-USD</th>
#       <th class="col_heading level0 col31" >BTC-USD_low</th>
#       <th class="col_heading level0 col32" >BTC-USD_high</th>
#       <th class="col_heading level0 col33" >BTC-USD_lo_mid</th>
#       <th class="col_heading level0 col34" >BTC-USD_hi_mid</th>
#       <th class="col_heading level0 col35" >BTC-USD_lo_ratio</th>
#       <th class="col_heading level0 col36" >INO</th>
#       <th class="col_heading level0 col37" >INO_low</th>
#       <th class="col_heading level0 col38" >INO_high</th>
#       <th class="col_heading level0 col39" >INO_lo_mid</th>
#       <th class="col_heading level0 col40" >INO_hi_mid</th>
#       <th class="col_heading level0 col41" >INO_lo_ratio</th>
#       <th class="col_heading level0 col42" >CLX</th>
#       <th class="col_heading level0 col43" >CLX_low</th>
#       <th class="col_heading level0 col44" >CLX_high</th>
#       <th class="col_heading level0 col45" >CLX_lo_mid</th>
#       <th class="col_heading level0 col46" >CLX_hi_mid</th>
#       <th class="col_heading level0 col47" >CLX_lo_ratio</th>
#       <th class="col_heading level0 col48" >VWAGY</th>
#       <th class="col_heading level0 col49" >VWAGY_low</th>
#       <th class="col_heading level0 col50" >VWAGY_high</th>
#       <th class="col_heading level0 col51" >VWAGY_lo_mid</th>
#       <th class="col_heading level0 col52" >VWAGY_hi_mid</th>
#       <th class="col_heading level0 col53" >VWAGY_lo_ratio</th>
#       <th class="col_heading level0 col54" >KO</th>
#       <th class="col_heading level0 col55" >KO_low</th>
#       <th class="col_heading level0 col56" >KO_high</th>
#       <th class="col_heading level0 col57" >KO_lo_mid</th>
#       <th class="col_heading level0 col58" >KO_hi_mid</th>
#       <th class="col_heading level0 col59" >KO_lo_ratio</th>
#       <th class="col_heading level0 col60" >PK</th>
#       <th class="col_heading level0 col61" >PK_low</th>
#       <th class="col_heading level0 col62" >PK_high</th>
#       <th class="col_heading level0 col63" >PK_lo_mid</th>
#       <th class="col_heading level0 col64" >PK_hi_mid</th>
#       <th class="col_heading level0 col65" >PK_lo_ratio</th>
#       <th class="col_heading level0 col66" >COST</th>
#       <th class="col_heading level0 col67" >COST_low</th>
#       <th class="col_heading level0 col68" >COST_high</th>
#       <th class="col_heading level0 col69" >COST_lo_mid</th>
#       <th class="col_heading level0 col70" >COST_hi_mid</th>
#       <th class="col_heading level0 col71" >COST_lo_ratio</th>
#       <th class="col_heading level0 col72" >MARA</th>
#       <th class="col_heading level0 col73" >MARA_low</th>
#       <th class="col_heading level0 col74" >MARA_high</th>
#       <th class="col_heading level0 col75" >MARA_lo_mid</th>
#       <th class="col_heading level0 col76" >MARA_hi_mid</th>
#       <th class="col_heading level0 col77" >MARA_lo_ratio</th>
#       <th class="col_heading level0 col78" >GSAT</th>
#       <th class="col_heading level0 col79" >GSAT_low</th>
#       <th class="col_heading level0 col80" >GSAT_high</th>
#       <th class="col_heading level0 col81" >GSAT_lo_mid</th>
#       <th class="col_heading level0 col82" >GSAT_hi_mid</th>
#       <th class="col_heading level0 col83" >GSAT_lo_ratio</th>
#       <th class="col_heading level0 col84" >FUBO</th>
#       <th class="col_heading level0 col85" >FUBO_low</th>
#       <th class="col_heading level0 col86" >FUBO_high</th>
#       <th class="col_heading level0 col87" >FUBO_lo_mid</th>
#       <th class="col_heading level0 col88" >FUBO_hi_mid</th>
#       <th class="col_heading level0 col89" >FUBO_lo_ratio</th>
#       <th class="col_heading level0 col90" >WMT</th>
#       <th class="col_heading level0 col91" >WMT_low</th>
#       <th class="col_heading level0 col92" >WMT_high</th>
#       <th class="col_heading level0 col93" >WMT_lo_mid</th>
#       <th class="col_heading level0 col94" >WMT_hi_mid</th>
#       <th class="col_heading level0 col95" >WMT_lo_ratio</th>
#       <th class="col_heading level0 col96" >DOGE-USD</th>
#       <th class="col_heading level0 col97" >DOGE-USD_low</th>
#       <th class="col_heading level0 col98" >DOGE-USD_high</th>
#       <th class="col_heading level0 col99" >DOGE-USD_lo_mid</th>
#       <th class="col_heading level0 col100" >DOGE-USD_hi_mid</th>
#       <th class="col_heading level0 col101" >DOGE-USD_lo_ratio</th>
#       <th class="col_heading level0 col102" >ARKQ</th>
#       <th class="col_heading level0 col103" >ARKQ_low</th>
#       <th class="col_heading level0 col104" >ARKQ_high</th>
#       <th class="col_heading level0 col105" >ARKQ_lo_mid</th>
#       <th class="col_heading level0 col106" >ARKQ_hi_mid</th>
#       <th class="col_heading level0 col107" >ARKQ_lo_ratio</th>
#       <th class="col_heading level0 col108" >ALTR</th>
#       <th class="col_heading level0 col109" >ALTR_low</th>
#       <th class="col_heading level0 col110" >ALTR_high</th>
#       <th class="col_heading level0 col111" >ALTR_lo_mid</th>
#       <th class="col_heading level0 col112" >ALTR_hi_mid</th>
#       <th class="col_heading level0 col113" >ALTR_lo_ratio</th>
#       <th class="col_heading level0 col114" >VICE</th>
#       <th class="col_heading level0 col115" >VICE_low</th>
#       <th class="col_heading level0 col116" >VICE_high</th>
#       <th class="col_heading level0 col117" >VICE_lo_mid</th>
#       <th class="col_heading level0 col118" >VICE_hi_mid</th>
#       <th class="col_heading level0 col119" >VICE_lo_ratio</th>
#       <th class="col_heading level0 col120" >AXP</th>
#       <th class="col_heading level0 col121" >AXP_low</th>
#       <th class="col_heading level0 col122" >AXP_high</th>
#       <th class="col_heading level0 col123" >AXP_lo_mid</th>
#       <th class="col_heading level0 col124" >AXP_hi_mid</th>
#       <th class="col_heading level0 col125" >AXP_lo_ratio</th>
#       <th class="col_heading level0 col126" >AG</th>
#       <th class="col_heading level0 col127" >AG_low</th>
#       <th class="col_heading level0 col128" >AG_high</th>
#       <th class="col_heading level0 col129" >AG_lo_mid</th>
#       <th class="col_heading level0 col130" >AG_hi_mid</th>
#       <th class="col_heading level0 col131" >AG_lo_ratio</th>
#       <th class="col_heading level0 col132" >QCOM</th>
#       <th class="col_heading leve

# %%
# Plot price vs. Time
num_plot=len(df.columns)
i=1
item = df_price.columns.tolist()[-1]
ax=plt.subplot()
plt.plot(df_price[item])
plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid']])
plt.legend([item,item+'_predicted',item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid'])
plt.ylabel('Share Price [USD]')
plt.xticks(rotation=45)
if  reverse_data=='Y':
    ax.invert_xaxis()
plt.grid(True)
plt.title(item)
i=i+1

# %% [markdown]
# ## Constructing the Portfolio

# %% [markdown]
# In order to balance the investments, we'd want to have the most benefit (reward) while minimizing volatility (risk).<br>
# 1. We can consider 'reward' to be the slope of the linear fit to share price (higher the slope, higher the gain).<br>
# 2. We can consider 'risk' to be the ratio between the price bounds and change in price over the duration of interest <br>
# 3. Hence we can compute a 'returns ratio' = 'reward'/'risk' for each listing; the higher this value, the more this investment is viable. <br>
# 4. Then we can compute the sum of the returns ratios for each listing and divide the returns ratio by the summed value, to determine the "weight" of each investment <br>
# 5. Finally we can multiply the "weight" by the total investment capital (total_investment) to obtain the recommended investment for each listing <br>

# %% [markdown]
# ### Use the Linear Regression object to construct the reward, volatility, returns ratio, weight and suggested investment values

# %%
mean_datetime=df.index.mean()
mean_price_est=price_est(df_price,df_norm_price_est_obj,df_start,[mean_datetime])

# %%
#Remove 'Mean' Columns
col_list=mean_price_est.columns.tolist()
for item in col_list:
    if 'Mean' in item:
        col_list.remove(item)
mean_price_est=mean_price_est.loc[:,col_list]

df_norm_price_est_obj.pop('Mean')
df.pop('Mean')
df_start.pop('Mean')
# Out:
# start_price    455.245879
# Name: Mean, dtype: float64

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
    
df_portfolio=df_norm_price_est_obj.copy()
df_portfolio=df_portfolio.reindex(['lingain','score','price_bound','returns_ratio','weight','suggested_investment'])
df_portfolio=df_portfolio.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_portfolio.columns):
    df_portfolio.loc['lingain',item]=(df_norm_price_est_obj.loc['fit_obj',item].coef_[0])*10**17

# Update the "score" as the line fit score
for item in (df_portfolio.columns):
    df_portfolio.loc['score',item]=1/(df_norm_price_est_obj.loc['score',item])
    
# Calculate risk as price range estimate:
for item in (df_portfolio.columns):
    df_portfolio.loc['price_bound',item]=df_norm_price_est_obj.loc['price_bounds',item]
    
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_portfolio.columns):
    df_portfolio.loc['returns_ratio',item]=(df_portfolio.loc['lingain',item]/
                                            df_portfolio.loc['price_bound',item])

    # Remove those listings with negative returns_ratio since those imply a falling stock
df_price_est_end=price_est(df,df_norm_price_est_obj,df_start,[df.index[-1].strftime('%m/%d/%y')])
for item in df_portfolio.columns:
    item_low_str=item+'_low'
    item_hi_str=item+'_high'
    if df_portfolio.loc['returns_ratio',item]<=0 or df[item].iloc[-1]>=df_price_est_end[item_hi_str].to_numpy()[0] or \
    df[item].iloc[-1]<=df_price_est_end[item_low_str].to_numpy()[0]:
        #if df_portfolio.loc['reward',item]<=201 or df_portfolio.loc['risk',item]>71:
        df_portfolio.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['returns_ratio',item]/df_portfolio.loc['returns_ratio',:].sum()

# Fit weights to linear
index_arr=np.array(list(range(df_portfolio.shape[1])));
val_arr=np.array(df_portfolio.loc['weight',:].astype('float'))
fit=np.polyfit(index_arr,val_arr,deg=1);
fitval=np.polyval(fit,index_arr);
df_portfolio.loc['weight',:]=fitval;
    
# Multiply the weight of each listing by the total investment capital to obtain the recommended investment
for item in (df_portfolio.columns):
    suggested_investment=df_portfolio.loc['weight',item]*total_investment
    if df_portfolio.loc['weight',item] <=0.01:
        df_portfolio.pop(item)
        
df_portfolio.loc['suggested_investment',:]=df_portfolio.loc['weight',:]*total_investment


# Remove negative values
for item in (df_portfolio.columns):
    if df_portfolio.loc['suggested_investment',item] <0:
        df_portfolio.pop(item)

## Sort in descending order #
df_portfolio=df_portfolio.sort_values(by='weight',axis=1,ascending=False);
if reverse_weights=='Y':
    df_portfolio.loc['weight',:]=df_portfolio.loc['weight',:][::-1].tolist()
# ## Sort in descending order #
df_portfolio.loc['suggested_investment',:]=df_portfolio.loc['weight',:]*total_investment
df_portfolio=df_portfolio.sort_values(axis=1,by='weight',ascending=False);


#Recalculate weights and suggested investments##
inv_ratio=df_portfolio.loc['suggested_investment'].sum()/total_investment;
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['weight',item]/inv_ratio
    suggested_investment=df_portfolio.loc['weight',item]*total_investment
    df_portfolio.loc['suggested_investment',item]=suggested_investment

# Display the portfolio dataframe
df_portfolio
# Out:
#                              PEP         DUK           T          MA  \
# Parameters
# lingain               143.258816   48.922796      8.9074   54.570824
# score                   1.043163    1.371896  264.769964    3.899959
# price_bound             4.176479    2.707209    3.496577   29.956511
# returns_ratio          34.301341   18.071301    2.547463    1.821668
# weight                  0.035408    0.034829     0.03425    0.033672
# suggested_investment  247.889142  243.837943  239.786743  235.735544
#
#                              VTI        ZNGA         OSK         XLK  \
# Parameters
# lingain                  9.54382   92.313143  138.743567   74.454466
# score                  68.508874   14.864112    1.431883    3.740157
# price_bound            16.280004    2.373944    8.798434   17.285894
# returns_ratio            0.58623   38.885986    15.76912    4.307238
# weight                  0.033093    0.032514    0.031936    0.031357
# suggested_investment  231.684345  227.633145  223.581946  219.530746
#
#                              BAC        CPRX         TSM         JNJ  \
# Parameters
# lingain                25.030672    63.03712  148.809486   70.987193
# score                   16.00246   24.437992    1.188643     1.34213
# price_bound              3.80937    1.520315    6.690201    6.175733
# returns_ratio           6.570816   41.463188   22.242903   11.494538
# weight                  0.030778      0.0302    0.029621    0.029042
# suggested_investment  215.479547  211.428347  207.377148  203.325948
#
#                             HGSH         JCI        INTC       MSFT  \
# Parameters
# lingain               289.353192   87.382169    8.821424  34.864935
# score                   2.580948    2.964134  109.167184  24.713439
# price_bound             0.527494    7.945648    4.494885  45.597077
# returns_ratio         548.542802   10.997488    1.962547   0.764631
# weight                  0.028464    0.027885    0.027306   0.026728
# suggested_investment  199.274749  195.223549   191.17235  187.12115
#
#                             GPRO        INFY           H         MRO  \
# Parameters
# lingain               101.400655   98.256083  126.313121  217.437052
# score                   6.263075    1.696833    1.819363    1.938379
# price_bound             2.014439    1.701597    8.419942    2.707431
# returns_ratio          50.336908   57.743467   15.001661   80.311205
# weight                  0.026149     0.02557    0.024992    0.024413
# suggested_investment  183.069951  179.018751  174.967552  170.916352
#
#                              PFE         XLE         NOK        GLDG  \
# Parameters
# lingain               386.962293  141.854288   52.833563  137.629213
# score                   1.311834    2.153265    4.121748    8.024362
# price_bound             8.466922    7.339392    0.479829    0.407856
# returns_ratio          45.702827   19.327799  110.109118  337.445316
# weight                  0.023834    0.023256    0.022677    0.022098
# suggested_investment  166.865153  162.813953  158.762754  154.711555
#
#                              SPY         MCD         IAK        IEHS  \
# Parameters
# lingain                40.470557   94.757733   51.200906   13.716837
# score                    4.34056    1.426971    2.368158   31.023181
# price_bound            29.686642   13.929136     4.36451    2.940733
# returns_ratio           1.363258    6.802844   11.731193    4.664427
# weight                   0.02152    0.020941    0.020363    0.019784
# suggested_investment  150.660355  146.609156  142.557956  138.506757
#
#                             XPEV         QQQ        NVDA         DIA  \
# Parameters
# lingain                65.543409   12.988312  210.714547   20.129393
# score                  27.246595   90.787467    6.904793    6.825643
# price_bound            11.141104   41.196335   99.255566   15.363773
# returns_ratio           5.883027    0.315278    2.122949    1.310186
# weight                  0.019205    0.018627    0.018048    0.017469
# suggested_investment  134.455557  130.404358  126.353158  122.301959
#
#                              IYR        RBLX        IAU       BRK-B  \
# Parameters
# lingain                46.451247   52.933712  21.634286   125.95784
# score                   3.688904  180.821483   3.289778    1.312171
# price_bound             7.263897   50.637538   1.011399   18.031891
# returns_ratio           6.394811    1.045345  21.390462    6.985282
# weight                  0.016891    0.016312   0.015733    0.015155
# suggested_investment  118.250759   114.19956  110.14836  106.097161
#
#                             GRPN            VT        SOXX        VOO  \
# Parameters
# lingain                18.317015      0.277119  141.918936  40.730062
# score                  69.726587  42831.813231    2.747268   4.302048
# price_bound             3.258621       5.42456   78.338051  27.305511
# returns_ratio           5.621094      0.051086    1.811622   1.491643
# weight                  0.014576      0.013997    0.013419    0.01284
# suggested_investment  102.045961     97.994762   93.943562  89.892363
#
#                             TSLA        SSL        AAPL
# Parameters
# lingain               154.657019  35.187297  249.203538
# score                    7.51659  46.825115    1.247224
# price_bound           283.130791   3.981402   16.334566
# returns_ratio           0.546239   8.837917   15.256208
# weight                  0.012261   0.011683    0.011104
# suggested_investment   85.841163  81.789964   77.738765

# %%
### PRINT SUM OF SUGGESTED INVESTMENTS #########
df_portfolio.loc['suggested_investment'].sum()
# Out:
# 7001.000000000001

# %%
stock_labels=df_portfolio.columns
values=df_portfolio.loc['suggested_investment',:]
plt.pie(values, labels=stock_labels,radius=3, autopct='%1.0f%%');

# %% [markdown]
# ## Save Portfolio Data

# %%
if save_port=='Y' or save_port==True:
    df_portfolio.sort_values(axis=1,by='weight',ascending=False).to_csv('portfolio.csv')
if save_mean=='Y' or save_mean==True:
    df_price.loc[:,'Mean'].to_csv('mean.csv')

# %% [markdown]
# ## Weighted Mean

# %% [markdown]
# ### Portfolio Weighted Mean

# %%
df_port_weights=df_portfolio.loc['weight',:]

weight_stocks=df_port_weights.index.tolist()
port_data=df_price.loc[:,weight_stocks]

port_weight_data=port_data.copy()
for ticker in port_weight_data.columns:
    port_weight_data.loc[:,ticker]=port_weight_data.loc[:,ticker]*df_port_weights[ticker]
port_weighted_mean_data=port_weight_data.sum(axis=1)
df_port_price_means=df_price.loc[:,'Mean']
df_port_price_means['Weighted_Mean']=port_weighted_mean_data

# %%
## Plot Weighted Mean ##
plt.figure()
plt.plot(df_port_price_means['Weighted_Mean'],'bo')
plt.ylabel('Share Price [USD]')
plt.xticks(rotation=45)
plt.grid(True)
plt.title('Portfolio Weighted_Mean')
# Out:
# Text(0.5, 1.0, 'Portfolio Weighted_Mean')

# %% [markdown]
# ### Saved Portfolio Weighted Mean (read data from 'portfolio.csv')

# %%
df_port_weights=pd.read_csv('portfolio.csv')
df_port_weights.set_index('Parameters',inplace=True)

weight_stocks=df_port_weights.columns.tolist()
port_data=df_price.loc[:,weight_stocks]

avg_weights=df_port_weights.loc['weight',:]
# 2022-02-04  0.358567  1.428623  6.450820  5.266208  11.531812  0.246538
# 2022-02-05  0.360244  1.427188  6.427546  5.260700  11.456301  0.248133
# 2022-02-06  0.361920  1.425753  6.404271  5.255192  11.380790  0.249728
# 2022-02-07  0.363596  1.424318  6.380997  5.249683  11.305279  0.251322
# 2022-02-08  0.365083  1.423297  6.367813  5.247006  11.251139  0.252467
#
#                 AAPL
# 2022-02-04  1.861277
# 2022-02-05  1.862429
# 2022-02-06  1.863582
# 2022-02-07  1.864735
# 2022-02-08  1.867867

# %%
#Calculate Best Fit 
weighted_mean_fit_data=df_price_means['Weighted_Mean'].values;
weighted_mean_fit_index=df_price_means['Weighted_Mean'].index.astype(int);
weighted_mean_fit=np.polyfit(weighted_mean_fit_index,weighted_mean_fit_data,deg=1);
weighted_mean_fitline=np.polyval(weighted_mean_fit_index,weighted_mean_fit);

## Plot Weighted Mean ##
plt.figure()
plt.plot(df_price_means['Weighted_Mean'],'bo')
# plt.plot(weighted_mean_fitline,'r-')
plt.ylabel('Share Price [USD]')
if reverse_data=='Y':
    ax.invert_xaxis()
plt.xticks(rotation=45)
plt.grid(True)
plt.title('Saved Portfolio Weighted_Mean')
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/numpy/lib/polynomial.py:771: RuntimeWarning: overflow encountered in multiply
#   y = y * x + p[i]
# Text(0.5, 1.0, 'Saved Portfolio Weighted_Mean')

# %% [markdown]
# ## Compare with previous

# %%
df_saved=pd.read_csv('portfolio.csv')
df_saved.set_index('Parameters',inplace=True)

# %%
comm_stocks=list(set(df_saved.columns.tolist()).intersection(set(df_portfolio.columns.tolist())))

# %%
weight_diff={}
for i in range(len(comm_stocks)):
    ticker=comm_stocks[i]
    weight_diff[ticker]=(df_portfolio.loc['weight',
                                          ticker]-df_saved.loc['weight',ticker])/df_portfolio.loc['weight',ticker]*100
df_weight_diff=pd.DataFrame(weight_diff,index=['weight_diff'])
print('Sum: {}, Min.: {}, Max.: {}'.format(df_weight_diff.sum(axis=1),df_weight_diff.min(axis=1),df_weight_diff.max(axis=1)))
df_weight_diff.sort_values(axis=1,by='weight_diff').transpose().plot(kind='bar',figsize=(12,8));
# Out:
# Sum: weight_diff    9.935324e-12
# dtype: float64, Min.: weight_diff    0.0
# dtype: float64, Max.: weight_diff    7.275895e-13
# dtype: float64

# %% [markdown]
# ## Lowest Trending

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
df_down=df_norm_price_est_obj
df_down=df_down.reindex(['reward','risk','returns_ratio','weight','price_bound'])
df_down=df_down.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_down.columns):
    df_down.loc['reward',item]=(df_norm_price_est_obj.loc['fit_obj',item].coef_[0])*10**17
    
# Update the "volatility" as the line fit score
for item in (df_down.columns):
    df_down.loc['risk',item]=1/(df_norm_price_est_obj.loc['score',item])
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_down.columns):
    df_down.loc['returns_ratio',item]=(df_down.loc['reward',item]/
                                            df_down.loc['risk',item])
    
# Remove those listings with negative returns_ratio since those imply a falling stock
df_price_est_end=price_est(df,df_norm_price_est_obj,df_start,[df.index[-1].strftime('%m/%d/%y')])
for item in df_down.columns:
    item_low_str=item+'_low'
    item_hi_str=item+'_high'
    if df_down.loc['returns_ratio',item]>=-21 or df[item].iloc[-1]>=df_price_est_end[item_hi_str].to_numpy()[0]:
        if df_down.loc['reward',item]>=-201:
            df_down.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_down.columns):
    df_down.loc['weight',item]=df_down.loc['returns_ratio',item]/df_down.loc['returns_ratio',:].sum()
    
# Update stop loss limit
for item in (df_down.columns):
    df_down.loc['price_bound',item]=df_norm_price_est_obj.loc['price_bounds',item]
    
# Display the portfolio dataframe
df_down.sort_values(axis=1,by='weight',ascending=False).style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ba7e7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >AMRS</th>
#       <th class="col_heading level0 col1" >FUBO</th>
#       <th class="col_heading level0 col2" >MVIS</th>
#       <th class="col_heading level0 col3" >JMIA</th>
#       <th class="col_heading level0 col4" >SPCE</th>
#       <th class="col_heading level0 col5" >SQ</th>
#       <th class="col_heading level0 col6" >AMC</th>
#       <th class="col_heading level0 col7" >TOPS</th>
#       <th class="col_heading level0 col8" >KOSS</th>
#       <th class="col_heading level0 col9" >IDEX</th>
#       <th class="col_heading level0 col10" >GEVO</th>
#       <th class="col_heading level0 col11" >WKHS</th>
#       <th class="col_heading level0 col12" >NBEV</th>
#       <th class="col_heading level0 col13" >SNAP</th>
#       <th class="col_heading level0 col14" >UONE</th>
#       <th class="col_heading level0 col15" >POTX</th>
#       <th class="col_heading level0 col16" >SOLO</th>
#       <th class="col_heading level0 col17" >TWTR</th>
#       <th class="col_heading level0 col18" >TLRY</th>
#       <th class="col_heading level0 col19" >PLTR</th>
#       <th class="col_heading level0 col20" >DOGE-USD</th>
#       <th class="col_heading level0 col21" >CLNE</th>
#       <th class="col_heading level0 col22" >GSAT</th>
#       <th class="col_heading level0 col23" >MARA</th>
#       <th class="col_heading level0 col24" >MRNA</th>
#       <th class="col_heading level0 col25" >INO</th>
#       <th class="col_heading level0 col26" >EH</th>
#       <th class="col_heading level0 col27" >GNUS</th>
#       <th class="col_heading level0 col28" >ARKG</th>
#       <th class="col_heading level0 col29" >ARKK</th>
#       <th class="col_heading level0 col30" >PYPL</th>
#       <th class="col_heading level0 col31" >ACB</th>
#       <th class="col_heading level0 col32" >BETZ</th>
#       <th class="col_heading level0 col33" >GME</th>
#       <th class="col_heading level0 col34" >FCEL</th>
#       <th class="col_heading level0 col35" >BTC-USD</th>
#       <th class="col_heading level0 col36" >NIO</th>
#       <th class="col_heading level0 col37" >MSOS</th>
#       <th class="col_heading level0 col38" >LYFT</th>
#       <th class="col_heading level0 col39" >SENS</th>
#       <th class="col_heading level0 col40" >RIOT</th>
#       <th class="col_heading level0 col41" >NCLH</th>
#       <th class="col_heading level0 col42" >PPBT</th>
#       <th class="col_heading level0 col43" >NFLX</th>
#       <th class="col_heading level0 col44" >VXRT</th>
#       <th class="col_heading level0 col45" >SNDL</th>
#       <th class="col_heading level0 col46" >RKT</th>
#       <th class="col_heading level0 col47" >DIS</th>
#       <th class="col_heading level0 col48" >BB</th>
#       <th class="col_heading level0 col49" >COIN</th>
#       <th class="col_heading level0 col50" >UBER</th>
#       <th class="col_heading level0 col51" >AAL</th>
#       <th class="col_heading level0 col52" >ARKX</th>
#       <th class="col_heading level0 col53" >SKYY</th>
#       <th class="col_heading level0 col54" >ARKQ</th>
#       <th class="col_heading level0 col55" >AG</th>
#       <th class="col_heading level0 col56" >UAL</th>
#       <th class="col_heading level0 col57" >JPM</th>
#       <th class="col_heading level0 col58" >HRB</th>
#       <th class="col_heading level0 col59" >ALTR</th>
#       <th class="col_heading level0 col60" >DMLRY</th>
#       <th class="col_heading level0 col61" >VICE</th>
#       <th class="col_heading level0 col62" >ETH-USD</th>
#       <th class="col_heading level0 col63" >GE</th>
#       <th class="col_heading level0 col64" >DKS</th>
#       <th class="col_heading level0 col65" >XHS</th>
#       <th class="col_heading level0 col66" >VWAGY</th>
#       <th class="col_heading level0 col67" >AM</th>
#       <th class="col_heading level0 col68" >ABNB</th>
#       <th class="col_heading level0 col69" >SBUX</th>
#       <th class="col_heading level0 col70" >SLVP</th>
#       <th class="col_heading level0 col71" >HON</th>
#       <th class="col_heading level0 col72" >PAAS</th>
#       <th class="col_heading level0 col73" >INDF</th>
#       <th class="col_heading level0 col74" >BA</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Parameters</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#       <th class="blank col40" >&nbsp;</th>
#       <th class="blank col41" >&nbsp;</th>
#       <th class="blank col42" >&nbsp;</th>
#       <th class="blank col43" >&nbsp;</th>
#       <th class="blank col44" >&nbsp;</th>
#       <th class="blank col45" >&nbsp;</th>
#       <th class="blank col46" >&nbsp;</th>
#       <th class="blank col47" >&nbsp;</th>
#       <th class="blank col48" >&nbsp;</th>
#       <th class="blank col49" >&nbsp;</th>
#       <th class="blank col50" >&nbsp;</th>
#       <th class="blank col51" >&nbsp;</th>
#       <th class="blank col52" >&nbsp;</th>
#       <th class="blank col53" >&nbsp;</th>
#       <th class="blank col54" >&nbsp;</th>
#       <th class="blank col55" >&nbsp;</th>
#       <th class="blank col56" >&nbsp;</th>
#       <th class="blank col57" >&nbsp;</th>
#       <th class="blank col58" >&nbsp;</th>
#       <th class="blank col59" >&nbsp;</th>
#       <th class="blank col60" >&nbsp;</th>
#       <th class="blank col61" >&nbsp;</th>
#       <th class="blank col62" >&nbsp;</th>
#       <th class="blank col63" >&nbsp;</th>
#       <th class="blank col64" >&nbsp;</th>
#       <th class="blank col65" >&nbsp;</th>
#       <th class="blank col66" >&nbsp;</th>
#       <th class="blank col67" >&nbsp;</th>
#       <th class="blank col68" >&nbsp;</th>
#       <th class="blank col69" >&nbsp;</th>
#       <th class="blank col70" >&nbsp;</th>
#       <th class="blank col71" >&nbsp;</th>
#       <th class="blank col72" >&nbsp;</th>
#       <th class="blank col73" >&nbsp;</th>
#       <th class="blank col74" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba7e7_level0_row0" class="row_heading level0 row0" >reward</th>
#       <td id="T_ba7e7_row0_col0" class="data row0 col0" >-826.43</td>
#       <td id="T_ba7e7_row0_col1" class="data row0 col1" >-792.64</td>
#       <td id="T_ba7e7_row0_col2" class="data row0 col2" >-651.74</td>
#       <td id="T_ba7e7_row0_col3" class="data row0 col3" >-626.32</td>
#       <td id="T_ba7e7_row0_col4" class="data row0 col4" >-578.89</td>
#       <td id="T_ba7e7_row0_col5" class="data row0 col5" >-587.95</td>
#       <td id="T_ba7e7_row0_col6

# %% [markdown]
# ## View Specific Stock(s)

# %%
# Plot Specific price vs. Time
plot_list=['HGSH','SPY','TSLA','INFY','RBLX','DOGE-USD']
num_plot=len(plot_list)
i=1
for item in list(set(plot_list).intersection(df_price.columns.tolist())):
    ax=plt.subplot();
    plt.figure()
    plt.plot(df_price[item])
    plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid']])
    plt.legend([item,item+'_predicted',item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid'])
    plt.ylabel('Share Price [USD]')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.title(item)
    i=i+1
#View specific stock values
df_portfolio.loc[:,
                 list(set(plot_list).intersection(df_portfolio.columns.tolist()))],df_down.loc[:,
                                                                                                    list(set(plot_list).intersection(df_down.columns.tolist()))]
# Out:
# (                            RBLX         SPY        HGSH        TSLA  \
#  Parameters
#  lingain                52.933712   40.470557  289.353192  154.657019
#  score                 180.821483     4.34056    2.580948     7.51659
#  price_bound            50.637538   29.686642    0.527494  283.130791
#  returns_ratio           1.045345    1.363258  548.542802    0.546239
#  weight                  0.016312     0.02152    0.028464    0.012261
#  suggested_investment   114.19956  150.660355  199.274749   85.841163
#
#                              INFY
#  Parameters
#  lingain                98.256083
#  score                   1.696833
#  price_bound             1.701597
#  returns_ratio          57.743467
#  weight                   0.02557
#  suggested_investment  179.018751  ,
#                   DOGE-USD
#  Parameters
#  reward        -523.282836
#  risk             1.288214
#  returns_ratio -406.207948
#  weight           0.020658
#  price_bound      0.057374)
