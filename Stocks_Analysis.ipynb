# %% [markdown]
# # Analyzing Stock Market Data to Build a Portfolio

# %% [markdown]
# ## Project Goal

# %% [markdown]
# ### Analyze share price data from various listings to answer the following questions:

# %% [markdown]
# 1. What kind of Growth % do we expect from the various listings? <br>
# 2. How do the Growth % of the different listings correlate to each other? <br>
# 3. What is the estimated listing share price at a future date (prediction)? <br>
# 4. What kind of volatility do the listings have? <br>
# 5. How can we use our analysis to form a balanced investment portfolio? <br>

# %% [markdown]
# ### Overall Methodology:

# %% [markdown]
# 1. Import and organize data for the various listings <br>
# 2. Make observations about the data <br>
# 3. Use these observations to answer the questions <br>

# %% [markdown]
# ## References

# %% [markdown]
# Share price information obtained from: [Yahoo Finance](https://finance.yahoo.com/) <br>
# Link to Blogpost: [An Investing Newbie's Tryst with Data Science](https://medium.com/@kgraghav/an-investing-newbies-tryst-with-data-science-241737102a6a) <br>

# %% [markdown]
# ## Inputs

# %% [markdown]
# ### Below are the inputs to perform the analysis

# %%
s_list='AAPL FB NVDA TSLA FCAU F AAL UAL INO MVIS'  # List of "listings" to be analyzed
total_investment=10000  # Total investment value in USD
sample_interval ='1d'  # Time interval to fetch data at
start='2019-09-10'  # Start date of interest
end='2020-09-09'  # End period of interest
resample_interval='3d'  # Upsampling/Downsampling interval (determined through trial and error)
datetime_query=['09/21/2020','10/21/2021'] # Datetime query values (for prediction)

# %% [markdown]
# <b>For this analysis, we look at the following listings (from different industries): </b> <br>
# <table style="width:100%">
#   <tr><tr align="Center">
#     <th>Listed Name</th>
#     <th>Company Name</th>
#     <th>Industry</th>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>AAPL</td>
#     <td>Apple</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>FB</td>
#     <td>Facebook</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>NVDA</td>
#     <td>NVDIA</td>
#     <td>Technology</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>TSLA</td>
#     <td>Tesla</td>
#     <td>Auto (Electric)</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>FCAU</td>
#     <td>FCA</td>
#     <td>Auto</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>F</td>
#     <td>Ford</td>
#     <td>Auto</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>AAL</td>
#     <td>American Airlines</td>
#     <td>Airline</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>UAL</td>
#     <td>United Airlines</td>
#     <td>Airline</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>INO</td>
#     <td>Inovio</td>
#     <td>Medical</td>
#   </tr>
#   <tr>
#     <tr align="Center">
#     <td>MVIS</td>
#     <td>Microvision</td>
#     <td>Medical</td>
#   </tr>
# </table>

# %% [markdown]
# ## Import Libraries

# %%
# Python Version
import sys
sys.version
# Out:
# '3.6.11 | packaged by conda-forge | (default, Jul 23 2020, 22:18:32) \n[GCC 7.5.0]'

# %%
#Update python standard libraries install
# !pip install --upgrade pip

# library to for array handling
import numpy as np 

# library for dataframes
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Linear Model
import sklearn as sk

# Math Module
import math

# Matplotlib and associated plotting modules
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# Machine-Learning and analysis modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Module to handle XML and HTML 
! pip install lxml;

#Finance information import (Link in "Yahoo Finance" Markdown Cell in the "References" Section)
# !pip install yfinance;
import yfinance as yf;

print('Libraries imported.')
# Out:
# Requirement already up-to-date: pip in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (20.2.3)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.5.2)
# Requirement already satisfied: yfinance in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.1.54)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: requests>=2.20 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (2.24.0)
# Requirement already satisfied: pandas>=0.24 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.0.5)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.19.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.15.0)
# Libraries imported.

# %% [markdown]
# ## Import Data into DataFrame

# %% [markdown]
# ### Create basic dataframe "df_info" containing all the available stocks information

# %%
# Create list of stock names as specified by the User
s_list=s_list.split(' ')

# %%
# Initialize Basic Dataframe as empty
df_info=pd.DataFrame() 

# Add Shares information for List of stock names
for item in s_list:
    data=yf.Ticker(item)
    df_data=data.history(period=sample_interval,start=start ,end=end )
    df_data=df_data.reset_index()
    df_data['Name']=pd.DataFrame([item for i in range(0,len(df_data))])
    df_info=pd.concat([df_info,df_data])

# Display basic information
df_info.head()
# Out:
#         Date   Open   High    Low  Close     Volume  Dividends  Stock Splits  \
# 0 2019-09-10  52.94  53.66  52.41  53.64  127111600        0.0           0.0
# 1 2019-09-11  53.98  55.38  53.90  55.35  177158400        0.0           0.0
# 2 2019-09-12  55.65  56.05  55.17  55.22  128906800        0.0           0.0
# 3 2019-09-13  54.46  54.66  53.72  54.15  159053200        0.0           0.0
# 4 2019-09-16  53.90  54.49  53.86  54.43   84632400        0.0           0.0
#
#    Name
# 0  AAPL
# 1  AAPL
# 2  AAPL
# 3  AAPL
# 4  AAPL

# %%
# Size of Data:
print('Size of the full dataset is: {} by {}'.format(df_info.shape[0],df_info.shape[1]))
# Out:
# Size of the full dataset is: 2520 by 9

# %% [markdown]
# ## Exploratory Pre-Processing Analysis

# %% [markdown]
# ### Create Dataframe (df) of Opening Price vs. date, which will be the data looked at in this analysis

# %%
# Create new Dataframe of Opening Share Prices
df=pd.DataFrame();
for item in s_list:
    df[['Date',item]]=df_info.loc[df_info['Name']==item,['Date','Open']]
df=df.set_index('Date')
df_price=df
# Display initial few contents of the Dataset
df.tail(10)
# Out:
#               AAPL      FB    NVDA    TSLA   FCAU     F    AAL    UAL    INO  \
# Date
# 2020-08-25  124.70  272.41  505.08  394.98  11.42  7.01  13.69  36.44  11.73
# 2020-08-26  126.18  284.00  511.82  412.00  11.31  6.94  13.11  35.26  12.59
# 2020-08-27  127.14  300.16  511.11  436.09  11.34  6.83  13.43  35.50  12.28
# 2020-08-28  126.01  295.00  506.85  459.02  11.15  6.93  13.59  37.14  11.80
# 2020-08-31  127.58  293.95  527.15  444.61  11.23  6.90  13.60  37.25  12.29
# 2020-09-01  132.76  294.71  539.20  502.14  10.82  6.77  12.86  35.25  11.60
# 2020-09-02  137.59  298.88  588.15  478.99  10.84  6.81  12.94  36.10  11.17
# 2020-09-03  126.91  295.99  553.15  407.23  11.21  6.92  13.40  37.13  10.26
# 2020-09-04  120.07  287.25  511.35  402.81  11.27  6.86  13.65  38.15   9.85
# 2020-09-08  113.95  271.28  469.38  356.00  11.20  6.83  13.36  37.30  10.20
#
#             MVIS
# Date
# 2020-08-25  1.25
# 2020-08-26  1.32
# 2020-08-27  1.56
# 2020-08-28  1.63
# 2020-08-31  1.70
# 2020-09-01  1.56
# 2020-09-02  1.60
# 2020-09-03  1.54
# 2020-09-04  1.47
# 2020-09-08  1.40

# %% [markdown]
# ### Display basic information about this dataset

# %%
# Display basic statistics of the opening prices
# Darker cells denote higher values
df.describe().style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
#     #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col1 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col3 {
#             background-color:  #67a4cc;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col6 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col7 {
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col8 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row1_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col0 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col1 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col2 {
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col5 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col6 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col7 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col8 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col1 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col3 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col5 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col6 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col7 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col8 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col0 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col1 {
#             background-color:  #045687;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col3 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col4 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col5 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col6 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col7 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col8 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row4_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col0 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col1 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col3 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col4 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col5 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col6 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col7 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col8 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_cd1d2360_f4c4_11ea_bec1_ae03ed92aa39row5_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %% [markdown]
# <b> A few notes and observations: </b> </br>
# 1. All values in the "count" row are the same, implying there are no bad values (such as NaNs) <br>
# 2. NVDIA and TESLA have some of the highest price fluctuations in absolute value based on their std. <br>
# 3. The listings looked at in the tech. industry have some of the highest share prices, followed by the airline industry. The Auto industry is generally lower with the exception of Tesla, whose share price is on par with the tech. industry (what's different here?)<br>
# 4. NVDIA and TESLA have seen some of the highest rises in absolute prices over the period <br>
# 5. Inovio (medical industry) has the highest rise in percentage of initial price <br>

# %% [markdown]
# ### Create basic Time plot to look at pertinent information (Opening price)

# %%
# Plot Open price vs. Time
ax= plt.subplot()
for item in df_price.columns:
    plt.plot(df_price[item])

ax.legend(df_price.columns)
plt.ylabel('Share Price [USD]')
ax.grid(True)

# %% [markdown]
# <b>Again a few things to note: </b><br>
# 1. Tech industry stocks seem to follow a similar trend w.r.t. time <br>
# 2. Tech industry stocks are seen to rise steadily. <br>
# 3. All listings had a decline around the 2020-03 to 2020-04 timeframe. <br>
# 4. Tech industry stocks rebounded back much better than the other industry listings after 2020-04. Tesla is the exception which more closely forllows the trends of the Tech. industry <br>

# %% [markdown]
# ## What kind of Growth % do we see with the various listings?

# %% [markdown]
# ### Normalize the opening price to determine Growth % over the period of interest

# %% [markdown]
# Normalize w.r.t. start price (df_start) <br>
# Normalization used: (price-start_price)/start_price*100 to obtain df_norm

# %%
# Normalization Function
def df_normalize(df):
    df_strt=df.iloc[0,:]
    df_norm=(df.iloc[:,:]-df_strt)/df_strt*100
    df_strt=pd.DataFrame(df_strt).transpose()
    df_strt=df_strt.set_axis(['start_price'])
    return [df_norm,df_strt]

# Store Normalized values in DataFrame and display results                          
[df_norm,df_start]=df_normalize(df)
df_norm.head()
# Out:
#                 AAPL        FB      NVDA      TSLA      FCAU         F  \
# Date
# 2019-09-10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2019-09-11  1.964488 -0.522834  2.561378  2.859619 -0.554236  2.391800
# 2019-09-12  5.119003  1.291080  3.914770  7.322357 -0.554236  3.075171
# 2019-09-13  2.871175 -0.058685  1.342207  6.997400  1.346002  4.328018
# 2019-09-16  1.813374 -0.272087 -0.145406  6.585789  0.554236  3.075171
#
#                  AAL       UAL        INO      MVIS
# Date
# 2019-09-10  0.000000  0.000000   0.000000  0.000000
# 2019-09-11  3.133903  0.481651  10.407240 -3.225806
# 2019-09-12  4.950142  1.697248  18.099548  4.838710
# 2019-09-13  6.801994  3.681193  17.647059  1.612903
# 2019-09-16  0.997151  1.261468  15.837104  4.838710

# %%
# Size of Data:
print('Size of the data is: {} by {}'.format(df_norm.shape[0],df_norm.shape[1]))
# Out:
# Size of the data is: 252 by 10

# %%
# Display basic statistics of the normalized prices
# Darker cells denote higher values
df_norm.describe().loc[['count','mean','min','max'],:].style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style  type="text/css" >
#     #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col2 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col3 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col6 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col9 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col1 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col2 {
#             background-color:  #03456c;
#             color:  #f1f1f1;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col3 {
#             background-color:  #034165;
#             color:  #f1f1f1;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col4 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col5 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col6 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col8 {
#             background-color:  #045b8f;
#             color:  #f1f1f1;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row2_col9 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col0 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col1 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col2 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col3 {
#             background-color:  #0872b1;
#             color:  #f1f1f1;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row3_col9 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }</style><table id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >FB</th>        <th class="col_heading level0 col2" >NVDA</th>        <th class="col_heading level0 col3" >TSLA</th>        <th class="col_heading level0 col4" >FCAU</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >AAL</th>        <th class="col_heading level0 col7" >UAL</th>        <th class="col_heading level0 col8" >INO</th>        <th class="col_heading level0 col9" >MVIS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col0" class="data row0 col0" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col1" class="data row0 col1" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col2" class="data row0 col2" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col3" class="data row0 col3" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col4" class="data row0 col4" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col5" class="data row0 col5" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col6" class="data row0 col6" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col7" class="data row0 col7" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col8" class="data row0 col8" >252.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row0_col9" class="data row0 col9" >252.0</td>
#             </tr>
#             <tr>
#                         <th id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col0" class="data row1 col0" >45.7</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col1" class="data row1 col1" >11.6</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col2" class="data row1 col2" >63.0</td>
#                         <td id="T_0eb1086e_f4c5_11ea_bec1_ae03ed92aa39row1_col3" class="data row1 col3" >233.6</td>
#                         <td id="T_0eb1086e_f4c5_11ea_

# %% [markdown]
# ### Plot trends in Normalized values

# %% [markdown]
# Time Plot

# %%
# Display Growth % over time
ax= plt.subplot()
for item in df_norm.columns:
    plt.plot(df_norm[item])

ax.legend(df.columns)
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## How do the price gains of the listings correlate to each other?

# %% [markdown]
# Correlation Matrix

# %%
sns.heatmap(df_norm.corr(),annot=True);

# %%
ax= plt.subplot()
for item in df_norm.columns:
    plt.scatter(df_norm.iloc[:,0],df_norm[item])

ax.legend(df_norm.columns)
plt.xlabel('AAPL Growth %')
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# <b>Observations:</b> <br>
# 1. Best matches between various companies in the tech industry (and Tesla) <br>
# 2. Worst matches between the tech industry and airline industry <br>
# 3. Medical industry has intermediate match with the tech industry and bad match with the airline and auto industry<br>
# 4. Auto and airline industries correlate well with each other <br>

# %% [markdown]
# ### Some general observations and next steps

# %% [markdown]
# 1. Time Data is too transient to determine good (suitably longer term) trends of rise and fall of prices <br>
# 2. To alleviate this, the data is downsampled so that the transients are smoothed out and better estimates can be made for rise and fall trends

# %% [markdown]
# ## General approach to answer the remaining questions:

# %% [markdown]
# 1. Downsample the data to smoothen it and obtain longer term trends in rise and fall of prices <br>
# 2. Use the smoothened data to obtain price rise and price fall information <br>
# 3. Use the standard deviation of the price rise/fall values to determine the price bounds  <br>
# 4. Use the ratio of price bounds and the change in price, to estimate "volatility" <br>
# 5. Create a linear regression fit object for the historical data over the period of analysis <br>
# 6. Estimate the "reward" or slope of price change from the fit object <br>
# 7. Plot the historical data along with the linear fit and price bounds to see how well the historical data falls within these margins <br>
# 8. Estimate the "returns_ratio" as the ratio between the "reward" and "volatility" for each listing <br>
# 9. The amount to invest in each listing is the weighted average of the "returns_ratio" multiplied by the total investment capital <br>

# %% [markdown]
# ### Downsample the data to filter out high frequency changes and determine pertinent trends

# %% [markdown]
# <b> Downsampled normalized data  "df_norm_resampled"</b>

# %%
# Downsample with cubic interpolation
df_norm_resampled=df_norm.resample(resample_interval).interpolate(method='cubic')
df_norm_resampled.head().style.format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >FB</th>        <th class="col_heading level0 col2" >NVDA</th>        <th class="col_heading level0 col3" >TSLA</th>        <th class="col_heading level0 col4" >FCAU</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >AAL</th>        <th class="col_heading level0 col7" >UAL</th>        <th class="col_heading level0 col8" >INO</th>        <th class="col_heading level0 col9" >MVIS</th>    </tr>    <tr>        <th class="index_name level0" >Date</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39level0_row0" class="row_heading level0 row0" >2019-09-10 00:00:00</th>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col0" class="data row0 col0" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col2" class="data row0 col2" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col3" class="data row0 col3" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col4" class="data row0 col4" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col5" class="data row0 col5" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col6" class="data row0 col6" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col7" class="data row0 col7" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col8" class="data row0 col8" >0.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row0_col9" class="data row0 col9" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39level0_row1" class="row_heading level0 row1" >2019-09-13 00:00:00</th>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col0" class="data row1 col0" >2.87</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col1" class="data row1 col1" >-0.06</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col2" class="data row1 col2" >1.34</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col3" class="data row1 col3" >7.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col4" class="data row1 col4" >1.35</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col5" class="data row1 col5" >4.33</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col6" class="data row1 col6" >6.80</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col7" class="data row1 col7" >3.68</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col8" class="data row1 col8" >17.65</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row1_col9" class="data row1 col9" >1.61</td>
#             </tr>
#             <tr>
#                         <th id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39level0_row2" class="row_heading level0 row2" >2019-09-16 00:00:00</th>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col0" class="data row2 col0" >1.81</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col1" class="data row2 col1" >-0.27</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col2" class="data row2 col2" >-0.15</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col3" class="data row2 col3" >6.59</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col4" class="data row2 col4" >0.55</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col5" class="data row2 col5" >3.08</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col6" class="data row2 col6" >1.00</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col7" class="data row2 col7" >1.26</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col8" class="data row2 col8" >15.84</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row2_col9" class="data row2 col9" >4.84</td>
#             </tr>
#             <tr>
#                         <th id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39level0_row3" class="row_heading level0 row3" >2019-09-19 00:00:00</th>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col0" class="data row3 col0" >3.82</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col1" class="data row3 col1" >0.65</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col2" class="data row3 col2" >0.58</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col3" class="data row3 col3" >6.59</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col4" class="data row3 col4" >-0.71</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col5" class="data row3 col5" >2.62</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col6" class="data row3 col6" >1.25</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col7" class="data row3 col7" >3.61</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col8" class="data row3 col8" >13.12</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row3_col9" class="data row3 col9" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39level0_row4" class="row_heading level0 row4" >2019-09-22 00:00:00</th>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col0" class="data row4 col0" >3.38</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col1" class="data row4 col1" >-0.77</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col2" class="data row4 col2" >-1.10</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col3" class="data row4 col3" >1.33</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col4" class="data row4 col4" >-4.29</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col5" class="data row4 col5" >1.05</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col6" class="data row4 col6" >-1.17</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col7" class="data row4 col7" >2.75</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col8" class="data row4 col8" >7.85</td>
#                         <td id="T_d123eab6_f4c4_11ea_bec1_ae03ed92aa39row4_col9" class="data row4 col9" >-4.19</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <b> Downsampled normalized data statistics "df_norm_resampled" </b>

# %%
# Basic downsampled statistics of normalized data
df_norm_resampled.describe().loc[['count','mean','min','max'],:].style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style  type="text/css" >
#     #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col0 {
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col1 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col2 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col3 {
#             background-color:  #0568a3;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col5 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col6 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col9 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col1 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col2 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col3 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col4 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col5 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col6 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col8 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row2_col9 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col0 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col1 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col2 {
#             background-color:  #e1dfed;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col3 {
#             background-color:  #04598c;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col6 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row3_col9 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }</style><table id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >FB</th>        <th class="col_heading level0 col2" >NVDA</th>        <th class="col_heading level0 col3" >TSLA</th>        <th class="col_heading level0 col4" >FCAU</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >AAL</th>        <th class="col_heading level0 col7" >UAL</th>        <th class="col_heading level0 col8" >INO</th>        <th class="col_heading level0 col9" >MVIS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col0" class="data row0 col0" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col1" class="data row0 col1" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col2" class="data row0 col2" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col3" class="data row0 col3" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col4" class="data row0 col4" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col5" class="data row0 col5" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col6" class="data row0 col6" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col7" class="data row0 col7" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col8" class="data row0 col8" >121.0</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row0_col9" class="data row0 col9" >121.0</td>
#             </tr>
#             <tr>
#                         <th id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col0" class="data row1 col0" >45.3</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col1" class="data row1 col1" >11.5</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col2" class="data row1 col2" >62.1</td>
#                         <td id="T_d1435ca2_f4c4_11ea_bec1_ae03ed92aa39row1_col3" class="data row1 col3" >228.8</td>
#                         <td id="T_d1435ca2_f4c4_11ea_

# %% [markdown]
# <b> Downsampled price data </b>

# %%
# Downsample with cubic interpolation
df_resampled=df.resample(resample_interval).interpolate(method='cubic')
df_resampled.head()
# Out:
#                  AAPL          FB        NVDA       TSLA       FCAU         F  \
# Date
# 2019-09-10  52.940000  187.440000  178.810000  46.160000  12.630000  8.780000
# 2019-09-13  54.460000  187.330000  181.210000  49.390000  12.800000  9.160000
# 2019-09-16  53.900000  186.930000  178.550000  49.200000  12.700000  9.050000
# 2019-09-19  54.960000  188.660000  179.840000  49.200000  12.540000  9.010000
# 2019-09-22  54.729047  185.998723  176.844526  46.775952  12.088506  8.872199
#
#                   AAL        UAL       INO      MVIS
# Date
# 2019-09-10  28.080000  87.200000  2.210000  0.620000
# 2019-09-13  29.990000  90.410000  2.600000  0.630000
# 2019-09-16  28.360000  88.300000  2.560000  0.650000
# 2019-09-19  28.430000  90.350000  2.500000  0.620000
# 2019-09-22  27.751935  89.598975  2.383418  0.594005

# %% [markdown]
# <b> Downsampled price data statistics </b>

# %%
# Basic downsampled statistics of share price data
df_resampled.describe().loc[['count','mean','min','max'],:].style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style  type="text/css" >
#     #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col1 {
#             background-color:  #1077b4;
#             color:  #f1f1f1;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col3 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col6 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col7 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col8 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col0 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col1 {
#             background-color:  #045a8d;
#             color:  #f1f1f1;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col3 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col4 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col5 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col6 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col7 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col8 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col0 {
#             background-color:  #d2d3e7;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col1 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col3 {
#             background-color:  #034a74;
#             color:  #f1f1f1;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col4 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col6 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col7 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col8 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >FB</th>        <th class="col_heading level0 col2" >NVDA</th>        <th class="col_heading level0 col3" >TSLA</th>        <th class="col_heading level0 col4" >FCAU</th>        <th class="col_heading level0 col5" >F</th>        <th class="col_heading level0 col6" >AAL</th>        <th class="col_heading level0 col7" >UAL</th>        <th class="col_heading level0 col8" >INO</th>        <th class="col_heading level0 col9" >MVIS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col0" class="data row0 col0" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col1" class="data row0 col1" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col2" class="data row0 col2" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col3" class="data row0 col3" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col4" class="data row0 col4" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col5" class="data row0 col5" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col6" class="data row0 col6" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col7" class="data row0 col7" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col8" class="data row0 col8" >121.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row0_col9" class="data row0 col9" >121.0</td>
#             </tr>
#             <tr>
#                         <th id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39level0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col0" class="data row1 col0" >76.9</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col1" class="data row1 col1" >209.0</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col2" class="data row1 col2" >289.9</td>
#                         <td id="T_d171274a_f4c4_11ea_bec1_ae03ed92aa39row1_col3" class="data row1 col3" >151.8</td>
#                         <td id="T_d171274a_f4c4_11e

# %% [markdown]
# <b>Time plot of filtered price data</b>

# %%
ax= plt.subplot()
for item in df_resampled.columns:
    plt.plot(df_resampled.index,df_resampled[item])

ax.legend(df_resampled.columns)
plt.ylabel('Share Price [USD]')
ax.grid(True)

# %% [markdown]
# We are able to sufficiently capture trends now after the filtering.<br>

# %% [markdown]
# ### Calculate Time, percent and absolute rise and fall of Growth

# %% [markdown]
# 1. "df_norm_resampled_rise_fall" is the dataframe of the normalized rise and fall prices <br>
# 2. "df_norm_resampled_rise_fall_time" is the dataframe of the rise and fall times of the normalized changes <br>
# 3. "df_norm_resampled_rise_fall_prices" is the dataframe of the rise and fall prices, calculated from the normalized values and the start value <br>

# %%
#Function to calculate rise and fall: rise_fall_stat(df,item)
# "item" is a list of columns of the price dataframe
def rise_fall_stat(df,item):
    #Initialize rise and fall arrays
    rise=np.array([])        
    fall=np.array([])
    rise_t=np.array([])        
    fall_t=np.array([])
    # if df[i]-df[i-1] is positive, 
    # add that to rise and add the time delta to rise_time
    # else if negative, add that (absolute) to fall, and add the time delta to fall_time
    # else move to next point
    i=1
    while i<len(df)-1:
        rise_val=0
        fall_val=0
        rise_time=0
        fall_time=0
        try:
            while df.iloc[i]>df.iloc[i-1] and i<len(df)-1:
                rise_val=rise_val+(df.iloc[i]-df.iloc[i-1])
                rise_time=rise_time+((df.index[i]-df.index[i-1]).value)
                i=i+1
            rise=np.append(rise,rise_val)
            rise_t=np.append(rise_t,rise_time)
        except:
            print('{} error at: {}, {}'.format(e,item,i))
        try:
            while df.iloc[i]<df.iloc[i-1] and i<len(df)-1:
                fall_val=fall_val+(df.iloc[i-1]-df.iloc[i])
                fall_time=fall_time+((df.index[i]-df.index[i-1]).value)
                i=i+1
            fall=np.append(fall,fall_val)
            fall_t=np.append(fall_t,fall_time)
        except:
            print('{} error at: {}, {}'.format(e,item,i))
        i=i+1
    # Estimate statistics for rise and fall arrays and create a dataframe for it
    df_rise_fall=pd.DataFrame({'%_rise_mean': [np.mean(rise)],'%_fall_mean': [np.mean(fall)],
                               '%_rise_min': [np.min(rise)],'%_fall_min': [np.min(fall)],
                               '%_rise_max': [np.max(rise)],'%_fall_max': [np.max(fall)],
                               '%_rise_std': [np.std(rise)],'%_fall_std': [np.std(fall)]}).transpose()
    df_rise_fall=df_rise_fall.rename(columns={0:item})
    # Estimate statistics for rise and fall arrays and create a dataframe for it
    df_rise_fall_time=pd.DataFrame({'time_rise_mean': pd.to_timedelta([np.mean(rise_t)]).days,
                                    'time_fall_mean': pd.to_timedelta([np.mean(fall_t)]).days,
                               'time_rise_min': pd.to_timedelta([np.min(rise_t)]).days,
                                    'time_fall_min': pd.to_timedelta([np.min(fall_t)]).days,
                               'time_rise_max': pd.to_timedelta([np.max(rise_t)]).days,
                                    'time_fall_max': pd.to_timedelta([np.max(fall_t)]).days,
                               'time_rise_std': pd.to_timedelta([np.std(rise_t)]).days,
                                    'time_fall_std': pd.to_timedelta([np.std(fall_t)]).days}).transpose()
    df_rise_fall_time=df_rise_fall_time.rename(columns={0:item})
    # Return rise, fall dataframes for price and time
    return [df_rise_fall,df_rise_fall_time]

# %%
# Calculate rise and fall in Growth % (w.r.t. initial price) for each listing using rise_fall_stat(...)
df_norm_resampled_rise_fall=pd.DataFrame()
df_norm_resampled_rise_fall_time=pd.DataFrame()
# for each listing, obtain the rise and fall prices and times:
for name in df_norm_resampled.columns:
    df_norm_resampled_rise_fall=pd.concat([df_norm_resampled_rise_fall,rise_fall_stat(df_norm_resampled[name],name)[0]],axis=1)
    df_norm_resampled_rise_fall_time=pd.concat([df_norm_resampled_rise_fall_time,rise_fall_stat(df_norm_resampled[name],name)[1]],axis=1)

# %%
# Display values for each listing. Darker cells denote larger values
df_norm_resampled_rise_fall.style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style  type="text/css" >
#     #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col0 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col2 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col3 {
#             background-color:  #2383ba;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col6 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row0_col9 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col3 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col4 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col6 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col7 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row1_col9 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col0 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col1 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col2 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col3 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col4 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col5 {
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col6 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col3 {
#             background-color:  #0c74b2;
#             color:  #f1f1f1;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col6 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col7 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row4_col9 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col2 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col3 {
#             background-color:  #a4bcda;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col6 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col7 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2d3949c_f4c4_11ea_bec1_ae03ed92aa39row5_col9 {
#             background-color:  #8bb2d4;
#             color:  #000000;

# %%
# Display values for each listing. Darker cells denote larger values
df_norm_resampled_rise_fall_time.style.background_gradient(axis=1)
# Out:
# <style  type="text/css" >
#     #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col1 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col2 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col5 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col6 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col8 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col1 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col2 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col3 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col5 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col6 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col7 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col8 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row1_col9 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col1 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col2 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col4 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col5 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col6 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col8 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row4_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col0 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col2 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col3 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col5 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col6 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col7 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col8 {
#             background-color:  #358fc0;
#             color:  #000000;
#         }    #T_d2f3ed6e_f4c4_11ea_bec1_ae03ed92aa39row5_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %% [markdown]
# Convert rise and fall from % to price (using price change= percent change/100*start price) and display.<br>

# %%
print('df_start={}'.format(df_start))
df_norm_resampled_rise_fall_prices=pd.DataFrame(df_norm_resampled_rise_fall.values/100*df_start.values)
# set appropriate index axis:
df_norm_resampled_rise_fall_prices=df_norm_resampled_rise_fall_prices.set_axis(
    [index.replace('%','price') for index in df_norm_resampled_rise_fall.index],
                                                 axis=0).set_axis(df_norm_resampled_rise_fall.columns,axis=1)
df_norm_resampled_rise_fall_prices.style.background_gradient(axis=1).format("{:.1f}")
# Out:
# df_start=              AAPL      FB    NVDA   TSLA   FCAU     F    AAL   UAL   INO  \
# start_price  52.94  187.44  178.81  46.16  12.63  8.78  28.08  87.2  2.21
#
#              MVIS
# start_price  0.62
# <style  type="text/css" >
#     #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col0 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col1 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col2 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col4 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col5 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col6 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col7 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col8 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row0_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col0 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col1 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col2 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col4 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col6 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col7 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col8 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row1_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col0 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col1 {
#             background-color:  #1c7fb8;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col2 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col4 {
#             background-color:  #94b6d7;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col5 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col6 {
#             background-color:  #348ebf;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col8 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row3_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col0 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col1 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col2 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col5 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col6 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col7 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col8 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row4_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col0 {
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col1 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col2 {
#             background-color:  #056ead;
#             color:  #f1f1f1;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col5 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col6 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col7 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col8 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_d31346be_f4c4_11ea_bec1_ae03ed92aa39row5_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %% [markdown]
# ### Create a linear regression fit for the data with 3 std. of the maximum of rise and fall to determine the boundaries

# %% [markdown]
# <b> Linear Regression object, score and price boundaries for each listing </b>

# %%
def lin_obj(df):
    df_lin=df.iloc[0:1,:]
    df_lin=df_lin.reindex(['fit_obj','score','price_bounds'])
    for item in df_lin.columns:
        price_bound=np.maximum(df_norm_resampled_rise_fall_prices.loc['price_rise_std',item],
                                  df_norm_resampled_rise_fall_prices.loc['price_fall_std',item])*3
        df_lin.loc['price_bounds',item]=price_bound
        
        # Implement train-test split thrice and fit the data to the average fit ...
        # ... (intercept and coeff.) of the three splits
        X=np.array(pd.to_numeric(df.index)).reshape(-1, 1)
        Y=(df[item].values).reshape(-1, 1)
        lin_list_coeff=[]
        lin_list_intercept=[]
        for i in range(0,2):
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)
            lin_obj=LinearRegression()
            lin_obj.fit(X_train,y_train)
            lin_list_coeff.append(lin_obj.coef_)
            lin_list_intercept.append(lin_obj.intercept_)
        linobj = LinearRegression()
        linobj.coef_=np.array(np.array(lin_list_coeff).mean()).reshape(-1)
        linobj.intercept_=np.array(np.array(lin_list_intercept).mean()).reshape(-1)
        score=linobj.score(X,Y)
        df_lin.loc['fit_obj',item]=linobj
        df_lin.loc['score',item]=score
        df_lin=df_lin.rename_axis(index='')
        
    return df_lin

# %%
# Call lin_obj(...) to create the linear regression object dataframe
df_price_est_obj=lin_obj(df)
df_price_est_obj
# Out:
#                                                            AAPL  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.701419
# price_bounds                                             16.142
#
#                                                              FB  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.448613
# price_bounds                                            32.1444
#
#                                                            NVDA  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.865187
# price_bounds                                            55.2867
#
#                                                            TSLA  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.785131
# price_bounds                                            148.053
#
#                                                            FCAU  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.281734
# price_bounds                                            4.10985
#
#                                                               F  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                   0.46434
# price_bounds                                            1.73986
#
#                                                             AAL  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.719544
# price_bounds                                            8.36513
#
#                                                             UAL  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.754851
# price_bounds                                            33.1044
#
#                                                             INO  \
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.709544
# price_bounds                                            9.98723
#
#                                                            MVIS
#
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.340293
# price_bounds                                           0.850486

# %% [markdown]
# ### Estimate the price and bounds vs. date using the fit object

# %%
# Function to estimate the price given the price dataframe, fit objects and datetime query
def price_est(df,df_price_est_obj,datetime_query):
    df_price_est=pd.DataFrame()
    df_price_est=df_price_est.rename_axis(index='Datetime')
    df_price_est['Datetime']=pd.to_datetime(datetime_query)
    df_price_est=df_price_est.set_index('Datetime')
    for item in df.columns:
        fit_obj=df_price_est_obj.loc['fit_obj',item]
        for datetime in df_price_est.index:
            price_est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            df_price_est.loc[datetime,'{}'.format(item)]=price_est
            df_price_est.loc[datetime,'{}_low'.format(item)]=price_est-(df_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_high'.format(item)]=price_est+(df_price_est_obj.loc['price_bounds',item])
    df_price_est=df_price_est.reindex(df_price_est.index.date)
    df_price_est=df_price_est
    return df_price_est

# %% [markdown]
# ## What is the predicted share price?

# %%
df_price_est=price_est(df,df_price_est_obj,datetime_query)
df_price_est.head().style.background_gradient(axis=1).format("{:.0f}")
# Out:
# <style  type="text/css" >
#     #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col0 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col1 {
#             background-color:  #dad9ea;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col2 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col4 {
#             background-color:  #8bb2d4;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col5 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col6 {
#             background-color:  #045483;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col7 {
#             background-color:  #0569a4;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col9 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col10 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col11 {
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col12 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col13 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col14 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col15 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col16 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col17 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col18 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col19 {
#             background-color:  #faf2f8;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col20 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col21 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col22 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col23 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col24 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col25 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col26 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col27 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col28 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row0_col29 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col0 {
#             background-color:  #c5cce3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col2 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col3 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col4 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col5 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col6 {
#             background-color:  #03476f;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col7 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col8 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col9 {
#             background-color:  #04649d;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col10 {
#             background-color:  #2786bb;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col11 {
#             background-color:  #023f64;
#             color:  #f1f1f1;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col12 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col13 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col14 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col15 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col16 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col17 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col18 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col19 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col20 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col21 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col22 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col23 {
#             background-color:  #f5eef6;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col24 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col25 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col26 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col27 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col28 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_d37461f6_f4c4_11ea_bec1_ae03ed92aa39row1_col29 {
#             background-color:  #

# %% [markdown]
# ## What kind of volatility do the listings have?

# %% [markdown]
# ## How do we generate our investment portfolio?

# %% [markdown]
# ### Estimate the price history along with the bounds and plot the history and estimates for each listing

# %%
# Datetime history query values
datetime_query_start_end=pd.date_range(start=start,end=end)

# %%
# Generate and display estimates (listing, listing_low, listing_high)
df_price_est_start_end=price_est(df,df_price_est_obj,datetime_query_start_end)
df_price_est_start_end.head().style.format("{:.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >AAPL_low</th>        <th class="col_heading level0 col2" >AAPL_high</th>        <th class="col_heading level0 col3" >FB</th>        <th class="col_heading level0 col4" >FB_low</th>        <th class="col_heading level0 col5" >FB_high</th>        <th class="col_heading level0 col6" >NVDA</th>        <th class="col_heading level0 col7" >NVDA_low</th>        <th class="col_heading level0 col8" >NVDA_high</th>        <th class="col_heading level0 col9" >TSLA</th>        <th class="col_heading level0 col10" >TSLA_low</th>        <th class="col_heading level0 col11" >TSLA_high</th>        <th class="col_heading level0 col12" >FCAU</th>        <th class="col_heading level0 col13" >FCAU_low</th>        <th class="col_heading level0 col14" >FCAU_high</th>        <th class="col_heading level0 col15" >F</th>        <th class="col_heading level0 col16" >F_low</th>        <th class="col_heading level0 col17" >F_high</th>        <th class="col_heading level0 col18" >AAL</th>        <th class="col_heading level0 col19" >AAL_low</th>        <th class="col_heading level0 col20" >AAL_high</th>        <th class="col_heading level0 col21" >UAL</th>        <th class="col_heading level0 col22" >UAL_low</th>        <th class="col_heading level0 col23" >UAL_high</th>        <th class="col_heading level0 col24" >INO</th>        <th class="col_heading level0 col25" >INO_low</th>        <th class="col_heading level0 col26" >INO_high</th>        <th class="col_heading level0 col27" >MVIS</th>        <th class="col_heading level0 col28" >MVIS_low</th>        <th class="col_heading level0 col29" >MVIS_high</th>    </tr>    <tr>        <th class="index_name level0" >Datetime</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39level0_row0" class="row_heading level0 row0" >2019-09-10</th>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col0" class="data row0 col0" >51</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col1" class="data row0 col1" >35</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col2" class="data row0 col2" >68</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col3" class="data row0 col3" >172</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col4" class="data row0 col4" >140</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col5" class="data row0 col5" >204</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col6" class="data row0 col6" >138</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col7" class="data row0 col7" >83</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col8" class="data row0 col8" >194</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col9" class="data row0 col9" >-3</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col10" class="data row0 col10" >-151</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col11" class="data row0 col11" >145</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col12" class="data row0 col12" >13</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col13" class="data row0 col13" >9</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col14" class="data row0 col14" >17</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col15" class="data row0 col15" >9</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col16" class="data row0 col16" >7</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col17" class="data row0 col17" >11</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col18" class="data row0 col18" >31</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col19" class="data row0 col19" >23</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col20" class="data row0 col20" >40</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col21" class="data row0 col21" >99</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col22" class="data row0 col22" >66</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col23" class="data row0 col23" >132</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col24" class="data row0 col24" >-1</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col25" class="data row0 col25" >-11</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col26" class="data row0 col26" >9</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col27" class="data row0 col27" >0</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col28" class="data row0 col28" >-0</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row0_col29" class="data row0 col29" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39level0_row1" class="row_heading level0 row1" >2019-09-11</th>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col0" class="data row1 col0" >52</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col1" class="data row1 col1" >35</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col2" class="data row1 col2" >68</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col3" class="data row1 col3" >172</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col4" class="data row1 col4" >140</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col5" class="data row1 col5" >204</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col6" class="data row1 col6" >139</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col7" class="data row1 col7" >84</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col8" class="data row1 col8" >194</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col9" class="data row1 col9" >-2</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col10" class="data row1 col10" >-150</td>
#                         <td id="T_d88b3994_f4c4_11ea_bec1_ae03ed92aa39row1_col11" class="data

# %%
# Plot Open price vs. Time
num_plot=len(df.columns)
i=1
for item in df.columns:
    plt.figure()
    plt.plot(df[item])
    plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high']])
    plt.legend([item,item+'_predicted',item+'_low',item+'_high'])
    plt.ylabel('Share Price [USD]')
    plt.grid(True)
    #plt.ylim(0,700)
    plt.title(item)
    i=i+1

# %% [markdown]
# ## Constructing the Portfolio

# %% [markdown]
# In order to balance the investments, we'd want to have the most benefit (reward) while minimizing volatility (risk).<br>
# 1. We can consider 'reward' to be the slope of the linear fit to share price (higher the slope, higher the gain).<br>
# 2. We can consider 'risk' to be the ratio between the price bounds and change in price over the duration of interest <br>
# 3. Hence we can compute a 'returns ratio' = 'reward'/'risk' for each listing; the higher this value, the more this investment is viable. <br>
# 4. Then we can compute the sum of the returns ratios for each listing and divide the returns ratio by the summed value, to determine the "weight" of each investment <br>
# 5. Finally we can multiply the "weight" by the total investment capital (total_investment) to obtain the recommended investment for each listing <br>

# %% [markdown]
# ### Use the Linear Regression object to construct the reward, volatility, returns ratio, weight and suggested investment values

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
df_portfolio=df_price_est_obj
df_portfolio=df_portfolio.reindex(['reward','risk','returns_ratio','weight','suggested_investment'])
df_portfolio=df_portfolio.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_portfolio.columns):
    df_portfolio.loc['reward',item]=(df_price_est_obj.loc['fit_obj',item].coef_[0])*10**17
    
# Update the "volatility" as the ratio of the price bounds to the absolute net price change over the duration
for item in (df_portfolio.columns):
    df_portfolio.loc['risk',item]=(df_price_est_obj.loc['price_bounds',
                                                              item])/abs(df_price_est_start_end.loc[df_price_est_start_end.index[-1],
                                                                                                 item]-
                                         df_price_est_start_end.loc[df_price_est_start_end.index[0],
                                                                    item])
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_portfolio.columns):
    df_portfolio.loc['returns_ratio',item]=(df_portfolio.loc['reward',item]/
                                            df_portfolio.loc['risk',item])
    
# Remove those listings with negative returns_ratio since those imply a falling stock
for item in df_portfolio.columns:
    if df_portfolio.loc['reward',item]<=0:
        df_portfolio.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['returns_ratio',item]/df_portfolio.loc['returns_ratio',:].sum()

# Multiply the weight of each listing by the total investment capital to obtain the recommended investment
for item in (df_portfolio.columns):
    df_portfolio.loc['suggested_investment',item]=df_portfolio.loc['weight',item]*total_investment

# Display the portfolio dataframe
df_portfolio.style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AAPL</th>        <th class="col_heading level0 col1" >FB</th>        <th class="col_heading level0 col2" >NVDA</th>        <th class="col_heading level0 col3" >TSLA</th>        <th class="col_heading level0 col4" >INO</th>        <th class="col_heading level0 col5" >MVIS</th>    </tr>    <tr>        <th class="index_name level0" >Parameters</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39level0_row0" class="row_heading level0 row0" >reward</th>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row0_col0" class="data row0 col0" >162.79</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row0_col1" class="data row0 col1" >231.45</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row0_col2" class="data row0 col2" >979.58</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row0_col3" class="data row0 col3" >1012.77</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row0_col4" class="data row0 col4" >63.28</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row0_col5" class="data row0 col5" >3.35</td>
#             </tr>
#             <tr>
#                         <th id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39level0_row1" class="row_heading level0 row1" >risk</th>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row1_col0" class="data row1 col0" >0.31</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row1_col1" class="data row1 col1" >0.44</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row1_col2" class="data row1 col2" >0.18</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row1_col3" class="data row1 col3" >0.46</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row1_col4" class="data row1 col4" >0.50</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row1_col5" class="data row1 col5" >0.80</td>
#             </tr>
#             <tr>
#                         <th id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39level0_row2" class="row_heading level0 row2" >returns_ratio</th>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row2_col0" class="data row2 col0" >517.75</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row2_col1" class="data row2 col1" >525.55</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row2_col2" class="data row2 col2" >5473.50</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row2_col3" class="data row2 col3" >2184.78</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row2_col4" class="data row2 col4" >126.46</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row2_col5" class="data row2 col5" >4.16</td>
#             </tr>
#             <tr>
#                         <th id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39level0_row3" class="row_heading level0 row3" >weight</th>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row3_col0" class="data row3 col0" >0.06</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row3_col1" class="data row3 col1" >0.06</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row3_col2" class="data row3 col2" >0.62</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row3_col3" class="data row3 col3" >0.25</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row3_col4" class="data row3 col4" >0.01</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row3_col5" class="data row3 col5" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39level0_row4" class="row_heading level0 row4" >suggested_investment</th>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row4_col0" class="data row4 col0" >586.21</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row4_col1" class="data row4 col1" >595.04</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row4_col2" class="data row4 col2" >6197.21</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row4_col3" class="data row4 col3" >2473.66</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row4_col4" class="data row4 col4" >143.18</td>
#                         <td id="T_dd105562_f4c4_11ea_bec1_ae03ed92aa39row4_col5" class="data row4 col5" >4.71</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### What kind of volatility do the listings have?

# %% [markdown]
#  Refer the "volatility" row, higher the value, greater the volatility

# %% [markdown]
# ### How do we use the data to construct our portfolio?

# %% [markdown]
# Refer the dataframe "df_portfolio"
