# %% [markdown]
# # Analyzing Stock Market Data to Build a Portfolio

# %% [markdown]
# ## Project Goal

# %% [markdown]
# ### Analyze share price data from various listings to answer the following questions:

# %% [markdown]
# 1. What kind of Growth % do we expect from the various listings? <br>
# 2. How do the Growth % of the different listings correlate to each other? <br>
# 3. What is the estimated listing share price at a future date (prediction)? <br>
# 4. What kind of volatility do the listings have? <br>
# 5. How can we use our analysis to form a balanced investment portfolio? <br>

# %% [markdown]
# ### Overall Methodology:

# %% [markdown]
# 1. Import and organize data for the various listings <br>
# 2. Make observations about the data <br>
# 3. Use these observations to answer the questions <br>

# %% [markdown]
# ## References

# %% [markdown]
# Share price information obtained from: [Yahoo Finance](https://finance.yahoo.com/) <br>
# Yahoo Finance library: [yfinance](https://pypi.org/project/yfinance/) <br>

# %% [markdown]
# ## Inputs

# %% [markdown]
# ### Below are the inputs to perform the analysis

# %%
s_list='AM AAPL FB NVDA MSFT PYPL TSLA ZNGA'  # List of "listings" to be analyzed
total_investment=7001  # Total investment value in USD
sample_interval ='1d'  # Time interval to fetch data at
start='11/27/2020'  # Start date of interest
end='12/29/2020'  # End date of interest
datetime_query=['12/30/2020'] # Datetime query values (for prediction)
pricetype='Close' # Open, Close, Low, High

# %% [markdown]
# ## Import Libraries

# %%
# Python Version
import sys
sys.version
# Out:
# '3.6.12 | packaged by conda-forge | (default, Dec  9 2020, 00:36:02) \n[GCC 9.3.0]'

# %%
#Update python standard libraries install
# !pip install --upgrade pip

# library to for array handling
import numpy as np 

# library for dataframes
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Linear Model
import sklearn as sk

# List Functions module
# !pip install listfun
from listfun import Listoper as lst

# Math Module
import math

# Matplotlib and associated plotting modules
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

import seaborn as sns

# Machine-Learning and analysis modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

! pip install expsolver;
from expsolver import Solver as solve

# Module to handle XML and HTML 
! pip install lxml;

#Finance information import (Link in "Yahoo Finance" Markdown Cell in the "References" Section)
# !pip install yfinance;
import yfinance as yf;

print('Libraries imported.')
# Out:
# Requirement already satisfied: pip in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (20.3.3)
# Requirement already satisfied: listfun in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.2)
# Requirement already satisfied: expsolver in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5)
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.2)
# Requirement already satisfied: yfinance in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.1.55)
# Requirement already satisfied: pandas>=0.24 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.1.5)
# Requirement already satisfied: requests>=2.20 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (2.25.0)
# Requirement already satisfied: lxml>=4.5.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: multitasking>=0.0.7 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from yfinance) (1.19.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from pandas>=0.24->yfinance) (2020.4)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Libraries imported.

# %% [markdown]
# ## Import Data into DataFrame

# %%
end=pd.to_datetime(end)
#start=end-pd.to_timedelta(start)
start=pd.to_datetime(start)
print('Start: {}, End: {}'.format(start,end))
# Out:
# Start: 2020-11-27 00:00:00, End: 2020-12-29 00:00:00

# %% [markdown]
# ### Create basic dataframe "df_info" containing all the available stocks information

# %%
# Create list of stock names as specified by the User
s_list=s_list.split(' ')

# %%
# Initialize Basic Dataframe as empty
df_info=pd.DataFrame() 

# Add Shares information for List of stock names
for item in s_list:
    data=yf.Ticker(item)
    df_data=data.history(period=sample_interval,start=start ,end=end )
    df_data=df_data.reset_index()
    df_data['Name']=pd.DataFrame([item for i in range(0,len(df_data))])
    df_info=pd.concat([df_info,df_data])
    

# Display basic information
df_info.head()
# Out:
#         Date  Open   High   Low  Close   Volume  Dividends  Stock Splits Name
# 0 2020-11-27  7.11  7.230  6.96   6.97  1942700        0.0             0   AM
# 1 2020-11-30  7.00  7.140  6.68   6.74  6180500        0.0             0   AM
# 2 2020-12-01  6.91  6.990  6.56   6.71  4219800        0.0             0   AM
# 3 2020-12-02  6.71  7.215  6.66   6.97  5154200        0.0             0   AM
# 4 2020-12-03  7.08  7.305  6.91   7.27  6597800        0.0             0   AM

# %%
# Size of Data:
print('Size of the full dataset is: {} by {}'.format(df_info.shape[0],df_info.shape[1]))
# Out:
# Size of the full dataset is: 168 by 9

# %% [markdown]
# ## Exploratory Pre-Processing Analysis

# %% [markdown]
# ### Create Dataframe (df) of Relevant share Price vs. date, which will be the data looked at in this analysis

# %%
# Create new Dataframe of relevant Share Prices
datevalues=df_info['Date'].sort_values().drop_duplicates().tolist()
df=pd.DataFrame(index=datevalues,columns=s_list)
for item in s_list:
    df_item=df_info[df_info['Name']==item]
    for ind in df.index.tolist():
    #df[['Date',item]]=df_info.loc[df_info['Name']==item,['Date',pricetype]]
        try:
            df.loc[ind,item]=df_item.loc[df_item['Date']==ind,pricetype].values[0]
        except:
            pass
    df[item].fillna(method='bfill',inplace=True)
    df[item].fillna(method='ffill',inplace=True)

df_price=df
# Display initial few contents of the Dataset
df.tail(10)
# Out:
#               AM        AAPL          FB        NVDA        MSFT        PYPL  \
# 2020-12-14  7.89  121.779999  274.190002  532.349976  214.199997  220.789993
# 2020-12-15  8.22  127.879997  275.549988  534.419983  214.130005  221.600006
# 2020-12-16  7.96  127.809998  275.670013  529.700012  219.279999  230.199997
# 2020-12-17  8.13  128.699997  274.480011  533.650024  219.419998  235.509995
# 2020-12-18  8.28  126.660004  276.399994  530.880005  218.589996  236.449997
# 2020-12-21  8.24  128.229996  272.790009  533.289978  222.589996  237.720001
# 2020-12-22  8.41  131.880005  267.089996  531.130005  223.940002  243.490005
# 2020-12-23  8.44  130.960007  268.109985  520.369995  221.020004  239.440002
# 2020-12-24  8.38  131.970001  267.399994  519.750000  222.750000  238.639999
# 2020-12-28  7.69  136.690002  277.000000  516.000000  224.960007  235.729996
#
#                   TSLA  ZNGA
# 2020-12-14  639.830017  8.71
# 2020-12-15  633.250000  9.12
# 2020-12-16  622.770020  9.52
# 2020-12-17  655.900024  9.61
# 2020-12-18  695.000000  9.94
# 2020-12-21  649.859985  9.87
# 2020-12-22  640.340027  9.99
# 2020-12-23  645.979980  9.93
# 2020-12-24  661.770020  9.91
# 2020-12-28  663.690002  9.73

# %% [markdown]
# ### Display basic information about this dataset

# %%
# Display basic statistics of the opening prices
# Darker cells denote higher values
df.describe().style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# #T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col0,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col1,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col2,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col3,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col4,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col5,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col6,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col7,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col0,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col7,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow2_col0,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow2_col7,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow3_col0,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow3_col7,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow4_col0,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow4_col7,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow5_col0,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow5_col7,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow6_col0,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow6_col7,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow7_col0,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow7_col7{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col1{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col2{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col3{
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col4{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col5,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow4_col4,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow4_col5{
#             background-color:  #afc1dd;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col6,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow2_col6,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow3_col6,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow4_col6,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow5_col6,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow6_col6,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow7_col6{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow2_col1{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow2_col2{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow2_col3{
#             background-color:  #d3d4e7;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow2_col4{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow2_col5{
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow3_col1{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow3_col2{
#             background-color:  #83afd3;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow3_col3{
#             background-color:  #03517e;
#             color:  #f1f1f1;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow3_col4,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow3_col5{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow4_col1{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow4_col2{
#             background-color:  #88b1d4;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow4_col3{
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow5_col1,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow6_col1,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow7_col1{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow5_col2{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow5_col3{
#             background-color:  #046097;
#             color:  #f1f1f1;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow5_col4,#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow6_col4{
#             background-color:  #b5c4df;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow5_col5{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow6_col2{
#             background-color:  #93b5d6;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow6_col3{
#             background-color:  #04639b;
#             color:  #f1f1f1;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow6_col5{
#             background-color:  #adc1dd;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow7_col2{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow7_col3{
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow7_col4{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow7_col5{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }</style><table id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AAPL</th>        <th class="col_heading level0 col2" >FB</th>        <th class="col_heading level0 col3" >NVDA</th>        <th class="col_heading level0 col4" >MSFT</th>        <th class="col_heading level0 col5" >PYPL</th>        <th class="col_heading level0 col6" >TSLA</th>        <th class="col_heading level0 col7" >ZNGA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7dlevel0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col0" class="data row0 col0" >21.00</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col1" class="data row0 col1" >21.00</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col2" class="data row0 col2" >21.00</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col3" class="data row0 col3" >21.00</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col4" class="data row0 col4" >21.00</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col5" class="data row0 col5" >21.00</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col6" class="data row0 col6" >21.00</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow0_col7" class="data row0 col7" >21.00</td>
#             </tr>
#             <tr>
#                         <th id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7dlevel0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col0" class="data row1 col0" >7.81</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col1" class="data row1 col1" >125.46</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col2" class="data row1 col2" >276.98</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col3" class="data row1 col3" >530.38</td>
#                         <td id="T_3ef86582_49be_11eb_a7a5_9a0ec9855e7drow1_col4" class="data row1 col4" >216.96</td>

# %% [markdown]
# ### Create basic Time plot to look at pertinent information

# %%
# Plot Open price vs. Time
ax= plt.subplot()
for item in df_price.columns:
    plt.plot(df_price[item])

plt.xticks(rotation=45)
ax.legend(df_price.columns)
plt.ylabel('Share Price [USD]')
ax.grid(True)

# %% [markdown]
# ## What kind of Growth % do we see with the various listings?

# %% [markdown]
# ### Normalize the opening price to determine Growth % over the period of interest

# %% [markdown]
# Normalize w.r.t. start price (df_start) <br>
# Normalization used: (price-start_price)/start_price*100 to obtain df_norm

# %%
# Normalization Function
def df_normalize(df):
    df_strt=df.iloc[0,:]
    df_norm=(df.iloc[:,:]-df_strt)/df_strt*100
    df_strt=pd.DataFrame(df_strt).transpose()
    df_strt.set_axis(['start_price'],axis=0,inplace=True)
    return [df_norm,df_strt]

# Store Normalized values in DataFrame and display results                          
[df_norm,df_start]=df_normalize(df)
df_norm.head()
# Out:
#                   AM      AAPL        FB      NVDA      MSFT      PYPL  \
# 2020-11-27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-11-30 -3.299857  2.109964 -0.302364  1.057592 -0.538953  1.291450
# 2020-12-01 -3.730269  5.257745  3.146032  0.970866  0.455332  2.436252
# 2020-12-02  0.000000  5.566520  3.495192  2.135924  0.065046  0.553478
# 2020-12-03  4.304164  5.446442  1.454234  1.045967 -0.459969  1.490134
#
#                 TSLA      ZNGA
# 2020-11-27  0.000000  0.000000
# 2020-11-30 -3.100252  0.243019
# 2020-12-01 -0.170718  0.121509
# 2020-12-02 -2.891970  1.093562
# 2020-12-03  1.300873  2.308634

# %%
df_start
# Out:
#                AM        AAPL          FB        NVDA        MSFT        PYPL  \
# start_price  6.97  116.589996  277.809998  530.293335  215.229996  211.389999
#
#                   TSLA  ZNGA
# start_price  585.76001  8.23

# %%
# Size of Data:
print('Size of the data is: {} by {}'.format(df_norm.shape[0],df_norm.shape[1]))
# Out:
# Size of the data is: 21 by 8

# %%
# Display basic statistics of the normalized prices
# Darker cells denote higher values
df_norm.describe().loc[['count','mean','min','max'],:].style.background_gradient(axis=1).format("{:.1f}")
# Out:
# <style  type="text/css" >
# #T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col0,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col1,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col2,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col3,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col4,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col5,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col6,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col7,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col2,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col2,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col3{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col0,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col1,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col7,#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col7{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col1{
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col3{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col4{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col5{
#             background-color:  #71a8ce;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col6{
#             background-color:  #4c99c5;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col7{
#             background-color:  #045f95;
#             color:  #f1f1f1;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col0{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col3{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col4{
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col5{
#             background-color:  #034b76;
#             color:  #f1f1f1;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col6{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col0{
#             background-color:  #023c5f;
#             color:  #f1f1f1;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col1{
#             background-color:  #056ba7;
#             color:  #f1f1f1;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col4{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col5{
#             background-color:  #2484ba;
#             color:  #000000;
#         }#T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col6{
#             background-color:  #045e93;
#             color:  #f1f1f1;
#         }</style><table id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AAPL</th>        <th class="col_heading level0 col2" >FB</th>        <th class="col_heading level0 col3" >NVDA</th>        <th class="col_heading level0 col4" >MSFT</th>        <th class="col_heading level0 col5" >PYPL</th>        <th class="col_heading level0 col6" >TSLA</th>        <th class="col_heading level0 col7" >ZNGA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7dlevel0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col0" class="data row0 col0" >21.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col1" class="data row0 col1" >21.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col2" class="data row0 col2" >21.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col3" class="data row0 col3" >21.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col4" class="data row0 col4" >21.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col5" class="data row0 col5" >21.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col6" class="data row0 col6" >21.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow0_col7" class="data row0 col7" >21.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7dlevel0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col0" class="data row1 col0" >12.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col1" class="data row1 col1" >7.6</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col2" class="data row1 col2" >-0.3</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col3" class="data row1 col3" >0.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col4" class="data row1 col4" >0.8</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col5" class="data row1 col5" >5.9</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col6" class="data row1 col6" >6.8</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow1_col7" class="data row1 col7" >10.1</td>
#             </tr>
#             <tr>
#                         <th id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7dlevel0_row2" class="row_heading level0 row2" >min</th>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col0" class="data row2 col0" >-3.7</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col1" class="data row2 col1" >0.0</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col2" class="data row2 col2" >-3.9</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col3" class="data row2 col3" >-2.7</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col4" class="data row2 col4" >-2.2</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col5" class="data row2 col5" >-0.3</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col6" class="data row2 col6" >-3.1</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow2_col7" class="data row2 col7" >0.0</td>
#             </tr>
#             <tr>
#                         <th id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7dlevel0_row3" class="row_heading level0 row3" >max</th>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col0" class="data row3 col0" >21.1</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col1" class="data row3 col1" >17.2</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col2" class="data row3 col2" >3.5</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col3" class="data row3 col3" >2.6</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col4" class="data row3 col4" >4.5</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col5" class="data row3 col5" >15.2</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col6" class="data row3 col6" >18.6</td>
#                         <td id="T_3fd9fd08_49be_11eb_a7a5_9a0ec9855e7drow3_col7" class="data row3 col7" >21.4</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Plot trends in Normalized values

# %% [markdown]
# Time Plot

# %%
# Display Growth % over time
ax= plt.subplot()
for item in df_norm.columns:
    plt.plot(df_norm[item])

plt.xticks(rotation=45)
ax.legend(df.columns)
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## How do the price gains of the listings correlate to each other?

# %% [markdown]
# Correlation Matrix

# %%
sns.heatmap(df_norm.corr());

# %%
ax= plt.subplot()
for item in df_norm.columns:
    plt.scatter(df_norm.iloc[:,0],df_norm[item])

ax.legend(df_norm.columns)
plt.xlabel('AAPL Growth %')
plt.ylabel('Growth %')
ax.grid(True)

# %% [markdown]
# ## Calculate percent and absolute estimate and bounds of Growth

# %% [markdown]
# ### Create a linear regression fit for the data with thrice the standard dev. of obs.-est. to determine the boundaries

# %% [markdown]
# <b> Linear Regression object, score and price boundaries for each listing </b>

# %%
def lin_obj(df):
    df_lin=df.iloc[0:1,:]
    df_lin.reindex(['fit_obj','score','bound'])
    df_lin.drop(index=df_lin.index[0],inplace=True)
    for item in df_lin.columns:
        # ... (intercept and coeff.) of the fits
        X=np.array(pd.to_numeric(df.index)).reshape(-1, 1)
        Y=(df[item].values).reshape(-1, 1)
        lin_list_coeff=[]
        lin_list_intercept=[]
        for i in range(0,1):
            X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0)
            lin_obj=LinearRegression()
            lin_obj.fit(X_train,y_train)
            lin_list_coeff.append(lin_obj.coef_)
            lin_list_intercept.append(lin_obj.intercept_)
        linobj = LinearRegression()
        linobj.coef_=np.array(np.array(lin_list_coeff).mean()).reshape(-1)
        linobj.intercept_=np.array(np.array(lin_list_intercept).mean()).reshape(-1)
        score=linobj.score(X,Y)
        df_lin.loc['fit_obj',item]=linobj
        df_lin.loc['score',item]=score

    # Calculate price bounds
    df_est=pd.DataFrame()
    df_est.rename_axis(index='Datetime')
    df_est['Datetime']=df.index
    df_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_lin.loc['fit_obj',item]
        for datetime in df_est.index:
            est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            df_est.loc[datetime,'{}'.format(item)]=est
    for item in df.columns:
        df_diff=df[item]-df_est[item]
        bounds=3*df_diff.std()
        df_lin.loc['bound',item]=bounds
        
    return df_lin

# %% [markdown]
# Convert rise and fall from % to price (using price change= percent change/100*start price) and display.<br>

# %%
# Call lin_obj(...) to create the price estimation object dataframe
df_price_est_obj=lin_obj(df_norm)
df_price_bounds_dict={}
for item in df_norm.columns:
    df_price_bounds_dict[item]=df_price_est_obj.loc['bound',item]*df_start.loc['start_price',item]/100
df_price_bounds=pd.DataFrame(df_price_bounds_dict,index=['price_bounds'])
df_price_est_obj=df_price_est_obj.append(df_price_bounds)
df_price_est_obj
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                              AM  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.601788
# bound                                                   15.8131
# price_bounds                                            1.10217
#
#                                                            AAPL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.833547
# bound                                                   5.06709
# price_bounds                                            5.90772
#
#                                                              FB  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.515158
# bound                                                   4.33997
# price_bounds                                            12.0569
#
#                                                            NVDA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.277698
# bound                                                   4.05655
# price_bounds                                            21.5116
#
#                                                            MSFT  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.577173
# bound                                                   3.75103
# price_bounds                                            8.07335
#
#                                                            PYPL  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.780783
# bound                                                   7.43833
# price_bounds                                            15.7239
#
#                                                            TSLA  \
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                     0.671
# bound                                                   9.98637
# price_bounds                                            58.4962
#
#                                                            ZNGA
# fit_obj       LinearRegression(copy_X=True, fit_intercept=Tr...
# score                                                  0.857742
# bound                                                   8.95874
# price_bounds                                           0.737305

# %% [markdown]
# ### Estimate the price and bounds vs. date using the fit object

# %%
# Function to estimate the price given the price dataframe, fit objects and datetime query
def price_est(df,df_price_est_obj,df_strt,datetime_query):
    df_price_est=pd.DataFrame()
    df_price_est.rename_axis(index='Datetime')
    df_price_est['Datetime']=pd.to_datetime(datetime_query)
    df_price_est.set_index('Datetime',inplace=True)
    for item in df.columns:
        fit_obj=df_price_est_obj.loc['fit_obj',item]
        for datetime in df_price_est.index:
            norm_price_est=fit_obj.predict(np.array(datetime.value).reshape(-1,1))
            price_est=norm_price_est*df_strt.loc['start_price',item]/100+df_strt.loc['start_price',item]
            df_price_est.loc[datetime,'{}'.format(item)]=price_est
            df_price_est.loc[datetime,'{}_low'.format(item)]=price_est-(df_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_high'.format(item)]=price_est+(df_price_est_obj.loc['price_bounds',item])
            df_price_est.loc[datetime,'{}_lo_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_low'.format(item)]].mean()
            df_price_est.loc[datetime,'{}_hi_mid'.format(item)]=df_price_est.loc[datetime,['{}'.format(item),
                                                                                         '{}_high'.format(item)]].mean()
    df_price_est.reindex(df_price_est.index.date)
    df_price_est=df_price_est
    return df_price_est

# %% [markdown]
# ## What is the predicted share price?

# %%
df_price_est=price_est(df,df_price_est_obj,df_start,datetime_query)
df_price_est.head().style.background_gradient(axis=1).format("{:.0f}")
# Out:
# <style  type="text/css" >
# #T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col0,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col1,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col2,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col3,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col4,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col35,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col36,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col38{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col5{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col6{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col7{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col8{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col9{
#             background-color:  #e0deed;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col10{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col11{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col12{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col13,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col27{
#             background-color:  #b0c2de;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col14{
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col15{
#             background-color:  #187cb6;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col16{
#             background-color:  #2484ba;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col17{
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col18{
#             background-color:  #1e80b8;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col19{
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col20{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col21{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col22{
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col23{
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col24{
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col25{
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col26{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col28{
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col29{
#             background-color:  #b4c4df;
#             color:  #000000;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col30{
#             background-color:  #034d79;
#             color:  #f1f1f1;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col31{
#             background-color:  #046096;
#             color:  #f1f1f1;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col32{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col33{
#             background-color:  #04588a;
#             color:  #f1f1f1;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col34{
#             background-color:  #034369;
#             color:  #f1f1f1;
#         }#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col37,#T_4252371c_49be_11eb_a7a5_9a0ec9855e7drow0_col39{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }</style><table id="T_4252371c_49be_11eb_a7a5_9a0ec9855e7d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AM_low</th>        <th class="col_heading level0 col2" >AM_high</th>        <th class="col_heading level0 col3" >AM_lo_mid</th>        <th class="col_heading level0 col4" >AM_hi_mid</th>        <th class="col_heading level0 col5" >AAPL</th>        <th class="col_heading level0 col6" >AAPL_low</th>        <th class="col_heading level0 col7" >AAPL_high</th>        <th class="col_heading level0 col8" >AAPL_lo_mid</th>        <th class="col_heading level0 col9" >AAPL_hi_mid</th>        <th class="col_heading level0 col10" >FB</th>        <th class="col_heading level0 col11" >FB_low</th>        <th class="col_heading level0 col12" >FB_high</th>        <th class="col_heading level0 col13" >FB_lo_mid</th>        <th class="col_heading level0 col14" >FB_hi_mid</th>        <th class="col_heading level0 col15" >NVDA</th>        <th class="col_heading level0 col16" >NVDA_low</th>        <th class="col_heading level0 col17" >NVDA_high</th>        <th class="col_heading level0 col18" >NVDA_lo_mid</th>        <th class="col_heading level0 col19" >NVDA_hi_mid</th>        <th class="col_heading level0 col20" >MSFT</th>        <th class="col_heading level0 col21" >MSFT_low</th>        <th class="col_heading level0 col22" >MSFT_high</th>        <th class="col_heading level0 col23" >MSFT_lo_mid</th>        <th class="col_heading level0 col24" >MSFT_hi_mid</th>        <th class="col_heading level0 col25" >PYPL</th>        <th class="col_heading level0 col26" >PYPL_low</th>        <th class="col_heading level0 col27" >PYPL_high</th>        <th class="col_heading level0 col28" >PYPL_lo_mid</th>        <th class="col_heading level0 col29" >PYPL_hi_mid</th>        <th class="col_heading level0 col30" >TSLA</th>        <th class="col_heading level0 col31" >TSLA_low</th>        <th class="col_heading level0 col32" >TSLA_high</th>        <th class="col_heading level0 col33" >TSLA_lo_mid</th>        <th class="col_heading level0 col34" >TSLA_hi_mid</th>        <th class="col_heading level0 col35" >ZNGA</th>        <th class="col_heading level0 col36" >ZNGA_low</th>        <th class="col_heading level0 col37" >ZNGA_high</th>        <th class="col_heading level0 col38" >ZNGA_lo_mid</th>        <th class="col_heading level0 col39" >ZNGA_hi_mid</th>    </tr>    <tr>        <th class="index_name level0" >Datetime</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>

# %% [markdown]
# ## What kind of volatility do the listings have?

# %% [markdown]
# ## How do we generate our investment portfolio?

# %% [markdown]
# ### Estimate the price history along with the bounds and plot the history and estimates for each listing

# %%
# Datetime history query values
datetime_query_start_end=pd.date_range(start=start,end=end)

# %%
# Generate and display estimates (listing, listing_low, listing_high)
df_price_est_start_end=price_est(df,df_price_est_obj,df_start,datetime_query_start_end)
df_price_est_start_end.head().style.format("{:.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >AM</th>        <th class="col_heading level0 col1" >AM_low</th>        <th class="col_heading level0 col2" >AM_high</th>        <th class="col_heading level0 col3" >AM_lo_mid</th>        <th class="col_heading level0 col4" >AM_hi_mid</th>        <th class="col_heading level0 col5" >AAPL</th>        <th class="col_heading level0 col6" >AAPL_low</th>        <th class="col_heading level0 col7" >AAPL_high</th>        <th class="col_heading level0 col8" >AAPL_lo_mid</th>        <th class="col_heading level0 col9" >AAPL_hi_mid</th>        <th class="col_heading level0 col10" >FB</th>        <th class="col_heading level0 col11" >FB_low</th>        <th class="col_heading level0 col12" >FB_high</th>        <th class="col_heading level0 col13" >FB_lo_mid</th>        <th class="col_heading level0 col14" >FB_hi_mid</th>        <th class="col_heading level0 col15" >NVDA</th>        <th class="col_heading level0 col16" >NVDA_low</th>        <th class="col_heading level0 col17" >NVDA_high</th>        <th class="col_heading level0 col18" >NVDA_lo_mid</th>        <th class="col_heading level0 col19" >NVDA_hi_mid</th>        <th class="col_heading level0 col20" >MSFT</th>        <th class="col_heading level0 col21" >MSFT_low</th>        <th class="col_heading level0 col22" >MSFT_high</th>        <th class="col_heading level0 col23" >MSFT_lo_mid</th>        <th class="col_heading level0 col24" >MSFT_hi_mid</th>        <th class="col_heading level0 col25" >PYPL</th>        <th class="col_heading level0 col26" >PYPL_low</th>        <th class="col_heading level0 col27" >PYPL_high</th>        <th class="col_heading level0 col28" >PYPL_lo_mid</th>        <th class="col_heading level0 col29" >PYPL_hi_mid</th>        <th class="col_heading level0 col30" >TSLA</th>        <th class="col_heading level0 col31" >TSLA_low</th>        <th class="col_heading level0 col32" >TSLA_high</th>        <th class="col_heading level0 col33" >TSLA_lo_mid</th>        <th class="col_heading level0 col34" >TSLA_hi_mid</th>        <th class="col_heading level0 col35" >ZNGA</th>        <th class="col_heading level0 col36" >ZNGA_low</th>        <th class="col_heading level0 col37" >ZNGA_high</th>        <th class="col_heading level0 col38" >ZNGA_lo_mid</th>        <th class="col_heading level0 col39" >ZNGA_hi_mid</th>    </tr>    <tr>        <th class="index_name level0" >Datetime</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7dlevel0_row0" class="row_heading level0 row0" >2020-11-27 00:00:00</th>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col0" class="data row0 col0" >7</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col1" class="data row0 col1" >6</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col2" class="data row0 col2" >8</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col3" class="data row0 col3" >6</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col4" class="data row0 col4" >8</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col5" class="data row0 col5" >118</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col6" class="data row0 col6" >112</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col7" class="data row0 col7" >124</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col8" class="data row0 col8" >115</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col9" class="data row0 col9" >121</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col10" class="data row0 col10" >284</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col11" class="data row0 col11" >272</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col12" class="data row0 col12" >296</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col13" class="data row0 col13" >278</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col14" class="data row0 col14" >290</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col15" class="data row0 col15" >538</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col16" class="data row0 col16" >516</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col17" class="data row0 col17" >559</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col18" class="data row0 col18" >527</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col19" class="data row0 col19" >549</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col20" class="data row0 col20" >212</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col21" class="data row0 col21" >204</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col22" class="data row0 col22" >220</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col23" class="data row0 col23" >208</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col24" class="data row0 col24" >216</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col25" class="data row0 col25" >207</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col26" class="data row0 col26" >192</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col27" class="data row0 col27" >223</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col28" class="data row0 col28" >199</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col29" class="data row0 col29" >215</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col30" class="data row0 col30" >579</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col31" class="data row0 col31" >521</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col32" class="data row0 col32" >638</td>
#                         <td id="T_43c3b094_49be_11eb_a7a5_9a0ec9855e7drow0_col33" class="data row0 col33" >550</td>
#                         <td id="T_43c3b094_49be_11eb_a7a

# %%
# Plot Open price vs. Time
num_plot=len(df.columns)
i=1
for item in df.columns:
    plt.figure()
    plt.plot(df_price[item])
    plt.plot(df_price_est_start_end[[item,item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid']])
    plt.legend([item,item+'_predicted',item+'_low',item+'_high',item+'_lo_mid',item+'_hi_mid'])
    plt.ylabel('Share Price [USD]')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.title(item)
    i=i+1

# %% [markdown]
# ## Constructing the Portfolio

# %% [markdown]
# In order to balance the investments, we'd want to have the most benefit (reward) while minimizing volatility (risk).<br>
# 1. We can consider 'reward' to be the slope of the linear fit to share price (higher the slope, higher the gain).<br>
# 2. We can consider 'risk' to be the ratio between the price bounds and change in price over the duration of interest <br>
# 3. Hence we can compute a 'returns ratio' = 'reward'/'risk' for each listing; the higher this value, the more this investment is viable. <br>
# 4. Then we can compute the sum of the returns ratios for each listing and divide the returns ratio by the summed value, to determine the "weight" of each investment <br>
# 5. Finally we can multiply the "weight" by the total investment capital (total_investment) to obtain the recommended investment for each listing <br>

# %% [markdown]
# ### Use the Linear Regression object to construct the reward, volatility, returns ratio, weight and suggested investment values

# %%
# Initialize the portfolio dataframe df_portfolio and update the index suitably
df_portfolio=df_price_est_obj
df_portfolio=df_portfolio.reindex(['reward','risk','returns_ratio','weight','suggested_investment'])
df_portfolio=df_portfolio.rename_axis(index='Parameters')

# Update "reward" using the slope of the line fit (multiplied by a suitable factor for display)
for item in (df_portfolio.columns):
    df_portfolio.loc['reward',item]=(df_price_est_obj.loc['fit_obj',item].coef_[0])*10**17
    
# Update the "volatility" as the percent price bound
for item in (df_portfolio.columns):
    df_portfolio.loc['risk',item]=(df_price_est_obj.loc['bound',item])
                                         
# Update the returns ratio as the ratio between the "reward" and "volatility"
for item in (df_portfolio.columns):
    df_portfolio.loc['returns_ratio',item]=(df_portfolio.loc['reward',item]/
                                            df_portfolio.loc['risk',item])
    
# Remove those listings with negative returns_ratio since those imply a falling stock
df_price_est_end=price_est(df,df_price_est_obj,df_start,[df.index[-1].strftime('%m/%d/%y')])
for item in df_portfolio.columns:
    item_low_str=item+'_low'
    if df_portfolio.loc['reward',item]<=0 or df[item].iloc[-1]<=df_price_est_end[item_low_str].to_numpy()[0]:
        df_portfolio.pop(item)
        
# Obtain the weighted average of the returns ratio for each listing
for item in (df_portfolio.columns):
    df_portfolio.loc['weight',item]=df_portfolio.loc['returns_ratio',item]/df_portfolio.loc['returns_ratio',:].sum()

# Multiply the weight of each listing by the total investment capital to obtain the recommended investment
for item in (df_portfolio.columns):
    df_portfolio.loc['suggested_investment',item]=df_portfolio.loc['weight',item]*total_investment

# Display the portfolio dataframe
df_portfolio.sort_values(axis=1,by='weight',ascending=False).style.background_gradient(axis=1).format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ZNGA</th>        <th class="col_heading level0 col1" >AAPL</th>        <th class="col_heading level0 col2" >PYPL</th>        <th class="col_heading level0 col3" >TSLA</th>        <th class="col_heading level0 col4" >AM</th>        <th class="col_heading level0 col5" >MSFT</th>    </tr>    <tr>        <th class="index_name level0" >Parameters</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7dlevel0_row0" class="row_heading level0 row0" >reward</th>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow0_col0" class="data row0 col0" >954.31</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow0_col1" class="data row0 col1" >491.90</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow0_col2" class="data row0 col2" >608.99</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow0_col3" class="data row0 col3" >618.69</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow0_col4" class="data row0 col4" >843.31</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow0_col5" class="data row0 col5" >190.12</td>
#             </tr>
#             <tr>
#                         <th id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7dlevel0_row1" class="row_heading level0 row1" >risk</th>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow1_col0" class="data row1 col0" >8.96</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow1_col1" class="data row1 col1" >5.07</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow1_col2" class="data row1 col2" >7.44</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow1_col3" class="data row1 col3" >9.99</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow1_col4" class="data row1 col4" >15.81</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow1_col5" class="data row1 col5" >3.75</td>
#             </tr>
#             <tr>
#                         <th id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7dlevel0_row2" class="row_heading level0 row2" >returns_ratio</th>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow2_col0" class="data row2 col0" >106.52</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow2_col1" class="data row2 col1" >97.08</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow2_col2" class="data row2 col2" >81.87</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow2_col3" class="data row2 col3" >61.95</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow2_col4" class="data row2 col4" >53.33</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow2_col5" class="data row2 col5" >50.68</td>
#             </tr>
#             <tr>
#                         <th id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7dlevel0_row3" class="row_heading level0 row3" >weight</th>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow3_col0" class="data row3 col0" >0.24</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow3_col1" class="data row3 col1" >0.22</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow3_col2" class="data row3 col2" >0.18</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow3_col3" class="data row3 col3" >0.14</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow3_col4" class="data row3 col4" >0.12</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow3_col5" class="data row3 col5" >0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7dlevel0_row4" class="row_heading level0 row4" >suggested_investment</th>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow4_col0" class="data row4 col0" >1651.97</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow4_col1" class="data row4 col1" >1505.51</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow4_col2" class="data row4 col2" >1269.67</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow4_col3" class="data row4 col3" >960.78</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow4_col4" class="data row4 col4" >827.04</td>
#                         <td id="T_4820b27c_49be_11eb_a7a5_9a0ec9855e7drow4_col5" class="data row4 col5" >786.02</td>
#             </tr>
#     </tbody></table>

# %%
stock_labels=df_portfolio.columns
values=df_portfolio.loc['suggested_investment',:]
plt.pie(values, labels=stock_labels,radius=1.5, autopct='%1.0f%%');

# %%
df_portfolio.to_csv('portfolio.csv')

# %% [markdown]
# ### What kind of volatility do the listings have?

# %% [markdown]
#  Refer the "volatility" row, higher the value, greater the volatility

# %% [markdown]
# ### How do we use the data to construct our portfolio?

# %% [markdown]
# Refer the dataframe "df_portfolio"
